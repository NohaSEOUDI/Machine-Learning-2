# %% [markdown]
# # 0-Installation des libraire et mise en palce de google drive

# %%
# !pip install pyyaml h5py #pour sauvegarder le modèle
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.8/dist-packages (6.0)
# Requirement already satisfied: h5py in /usr/local/lib/python3.8/dist-packages (3.1.0)
# Requirement already satisfied: numpy>=1.17.5 in /usr/local/lib/python3.8/dist-packages (from h5py) (1.21.6)

# %%
# Importation des différentes librairies utiles pour le notebook
#Pour ignorer les warning.
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

# librairies générales
import pickle 
import pandas as pd
import numpy as np
import string
import time
import base64
import re
import sys
import copy
import random
from numpy import mean
from numpy import std
from numpy.random import randint


# librairie affichage
import matplotlib.pyplot as plt
from matplotlib import pyplot
import seaborn as sns
import plotly.graph_objs as go
import plotly.offline as py
from PIL import Image

#Sklearn
from sklearn.metrics import confusion_matrix
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import StratifiedKFold, train_test_split
from sklearn.pipeline import Pipeline
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score

# TensorFlow et keras
import keras
import tensorflow as tf
from keras import layers
from keras import models
from keras import optimizers
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import to_categorical,img_to_array, load_img #from keras.preprocessing.image import img_to_array, load_img
from tensorflow.keras.optimizers import SGD,Adam
from tensorflow.keras.applications.resnet50 import ResNet50
from keras.callbacks import ModelCheckpoint, EarlyStopping
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import BatchNormalization
from keras.preprocessing import image
from keras.applications.vgg16 import VGG16
from tqdm import tqdm
from keras.models import load_model
from keras.models import Model
from sklearn.model_selection import KFold
from keras.layers import Dense
import os  #pour accéder aux fonctionnalité systèmes
import sys 
from os import listdir
from os.path import isfile, join
import cv2  # Library to solve computer vision problems
import glob  # = global is used to return all file paths that match a specific patter


from numpy import expand_dims
from numpy import zeros
from numpy import ones
from numpy import vstack
from keras.layers import Reshape
from keras.layers import Conv2DTranspose
from keras.layers import LeakyReLU
from keras.layers import Dropout
from tensorflow.keras.layers import Dense, BatchNormalization
from keras.models import load_model

# %%
# pour monter son Google Drive local
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
my_local_drive='/content/gdrive/My Drive'

# Ajout du path pour les librairies, fonctions et données
sys.path.append(my_local_drive)
# Se positionner sur le répertoire associé
# %cd $my_local_drive

# %pwd
# Out:
# /content/gdrive/My Drive
# '/content/gdrive/My Drive'

# %%
plt.savefig('GanImages/'+'GanImagesFox/'+'generated_plot_FoxCNN_withGan001.png')

# %% [markdown]
# #1- Récupération des jeux de données

# %%
#pour télécharger le zip file 
# !wget https://www.lirmm.fr/~poncelet/Ressources/Tiger-Fox-Elephant.zip
# Out:
# --2022-12-05 07:47:04--  https://www.lirmm.fr/~poncelet/Ressources/Tiger-Fox-Elephant.zip
# Resolving www.lirmm.fr (www.lirmm.fr)... 193.49.104.251
# Connecting to www.lirmm.fr (www.lirmm.fr)|193.49.104.251|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 7605545 (7.3M) [application/zip]
# Saving to: ‘Tiger-Fox-Elephant.zip.2’
#
# Tiger-Fox-Elephant. 100%[===================>]   7.25M  4.00MB/s    in 1.8s
#
# 2022-12-05 07:47:07 (4.00 MB/s) - ‘Tiger-Fox-Elephant.zip.2’ saved [7605545/7605545]

# %%
import zipfile
with zipfile.ZipFile("Tiger-Fox-Elephant.zip","r") as zip_ref:
    zip_ref.extractall("Data_Project")

# %% [markdown]
# #2-GAN

# %% [markdown]
# ##Générateur

# %%
def create_generator(latent_dim=100):
  model = Sequential()
	# 1/4 de l'image (7x7) * nombre d'images possibles
  n_nodes = 256 * 31 * 31
  model.add(Dense(n_nodes, use_bias=False, input_dim=latent_dim))
  model.add(BatchNormalization())
  model.add(LeakyReLU(alpha=0.2))
  model.add(Reshape((31, 31, 256)))
  # upsample to 14x14
  model.add(Conv2DTranspose(128, (5,5), use_bias=False, strides=(2,2), padding='same'))
  model.add(BatchNormalization()) 		
  model.add(LeakyReLU(alpha=0.2))
  # upsample to 28x28
  model.add(Conv2DTranspose(128, (5,5), use_bias=False, strides=(2,2), padding='same'))
  model.add(BatchNormalization())
  model.add(LeakyReLU(alpha=0.2))
  model.add(Conv2D(3, (5,5), use_bias=False, activation='tanh', padding='same'))
  opt = Adam(learning_rate=0.0002, beta_1=0.5)
  model.compile(loss='binary_crossentropy', optimizer=opt, metrics=['accuracy'])
  return model

# %%
generator_model = create_generator()
generator_model.summary()
# Out:
# Model: "sequential_17"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_12 (Dense)            (None, 246016)            24601600
#
#  batch_normalization_15 (Bat  (None, 246016)           984064
#  chNormalization)
#
#  leaky_re_lu_29 (LeakyReLU)  (None, 246016)            0
#
#  reshape_5 (Reshape)         (None, 31, 31, 256)       0
#
#  conv2d_transpose_10 (Conv2D  (None, 62, 62, 128)      819200
#  Transpose)
#
#  batch_normalization_16 (Bat  (None, 62, 62, 128)      512
#  chNormalization)
#
#  leaky_re_lu_30 (LeakyReLU)  (None, 62, 62, 128)       0
#
#  conv2d_transpose_11 (Conv2D  (None, 124, 124, 128)    409600
#  Transpose)
#
#  batch_normalization_17 (Bat  (None, 124, 124, 128)    512
#  chNormalization)
#
#  leaky_re_lu_31 (LeakyReLU)  (None, 124, 124, 128)     0
#
#  conv2d_19 (Conv2D)          (None, 124, 124, 3)       9600
#
# =================================================================
# Total params: 26,825,088
# Trainable params: 26,332,544
# Non-trainable params: 492,544
# _________________________________________________________________

# %%
latent_dim=100
noise = tf.random.normal([1,latent_dim]) # (1,100)
generated_image = generator_model (noise, training=False) ##On passe le vecteur(image) à la générateur
plt.imshow(generated_image[0, :, :, 0])

# %% [markdown]
# ##Discriminateur

# %%
def create_discriminator():
  model = Sequential()
  model.add(Conv2D(64, (5,5), strides=(2, 2), padding='same', input_shape=[124,124,3]))
  model.add(LeakyReLU(alpha=0.2))
  model.add(Dropout(0.3))
  model.add(Conv2D(128, (5,5), strides=(2, 2), padding='same'))
  model.add(LeakyReLU(alpha=0.2))
  model.add(Dropout(0.3))
  model.add(Flatten())
  model.add(Dense(1, activation='sigmoid'))
  opt = Adam(learning_rate=0.0002, beta_1=0.5)
  model.compile(loss='binary_crossentropy', optimizer=opt, metrics=['accuracy'])
  return model

# %%
model_discriminator=create_discriminator()
model_discriminator.summary()
# Out:
# Model: "sequential_18"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_20 (Conv2D)          (None, 62, 62, 64)        4864
#
#  leaky_re_lu_32 (LeakyReLU)  (None, 62, 62, 64)        0
#
#  dropout_14 (Dropout)        (None, 62, 62, 64)        0
#
#  conv2d_21 (Conv2D)          (None, 31, 31, 128)       204928
#
#  leaky_re_lu_33 (LeakyReLU)  (None, 31, 31, 128)       0
#
#  dropout_15 (Dropout)        (None, 31, 31, 128)       0
#
#  flatten_7 (Flatten)         (None, 123008)            0
#
#  dense_13 (Dense)            (None, 1)                 123009
#
# =================================================================
# Total params: 332,801
# Trainable params: 332,801
# Non-trainable params: 0
# _________________________________________________________________

# %%
discriminator_model = create_discriminator()
prediction = discriminator_model(generated_image)
print(prediction)
# Out:
# tf.Tensor([[0.4998915]], shape=(1, 1), dtype=float32)

# %%
 IMG_SIZE=124
 COLUMNS = 16
 """
 Téléchargement de jeux d'entrainement 
 @Param path_data: le chemin vers notre répertoire de données 
 @Param list_classes: la liste de nom de classe volue
 @Return training_data
 """
 def create_training_data(path_data, list_classes):  
  training_data=[]   #Tableau de retour 
  for classes in list_classes: # tiger et tiger_negative
      path = os.path.join(path_data, classes)
      class_num = list_classes.index(classes)
      for img in os.listdir(path):
        try:
          img_array = cv2.imread(os.path.join(path,img), cv2.IMREAD_UNCHANGED)
          new_array = cv2.resize(img_array, (IMG_SIZE, IMG_SIZE))  
          training_data.append([new_array, class_num])  # on remplit notre tableau 
        except Exception as e:
          pass  
  return training_data   

 """
 Creation de jeux d'entrainement 
 @Param path_data: le chemin vers notre répertoire de données 
 @Param list_classes: la liste de nom de classe volue
 @Return X,y
 """ 
 def create_X_y (path_data, list_classes):
      # récupération des données
      training_data = create_training_data(path_data, list_classes)
      # tri des données
      random.shuffle(training_data)
      # création de X et y
      X=[]
      y=[]
      for features, label in training_data:
        X.append(features)
        y.append(label)
      X=np.array(X).reshape(-1,IMG_SIZE, IMG_SIZE, 3)  #-1 The new shape should be compatible with the original shape.  
      y=np.array(y)
      return X,y 

 """
 Nettoyage de données : conversion en foat et normalisation 
 @Param xtrain 
 @Param xtest
 @Return xtrain_norm, xtest_norm
 """ 
 def clean_data(x): 
    # convertion d'entier en float
    xtrain_norm = x.astype('float32')
    # normalisation entre 0 et 1
    xtrain_norm = xtrain_norm / 255.0
    return xtrain_norm 

 """
 Affichage de données : 
 @Param X 
 @Param y
 """ 
 def plot_examples(X,y):
  plt.figure(figsize=(25,25))
  for i in range(10):
    plt.subplot(4,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    # cv2 lit, met les images en BGR et matplotlib lit du RGB
    #X[i] = cv2.cvtColor(X[i], cv2.COLOR_BGR2RGB)
    X[i]=X[i].astype('float32')
    plt.imshow(X[i],cmap=plt.cm.binary)  
    plt.xlabel('classe ' + str(y[i]))

# %%
# Création d'un faux jeu de données 
# elles seront labélisées avec 0

def generate_fake_samples(nb_images):
  # generation de nombres aléatoires entre 0 et 1
  # attention ici on simplifie en mettant la taille de l'image
  # normalement il faut prendre latent_dim
  X = np.random.rand(3* 124 * 124 * nb_images)
  # reshape en images grises
  X = X.reshape((nb_images, 124, 124, 3))
  # mettre 0 comme label de classe
  y = zeros((nb_images, 1))
  return X, y

# %%
##Ici on génére 10 images 
X_f,y_f= generate_fake_samples(10)

# %%
print(X_f.shape)
print(y_f.shape)
# Out:
# (10, 124, 124, 3)
# (10, 1)

# %%
plot_examples(X_f, y_f)

# %%
# Creation d'un jeu de données de vraies images
# les vraies images sont labélisées avec 1
def generate_real_samples(dataset, nb_images):  ##pour nous 100 max
	# tirage aléatoire
	ix = randint(0, dataset.shape[0], nb_images)
	# sélection des images
	X = dataset[ix]
	# mettre 1 comme label de classe
	y = ones((nb_images, 1))
	return X, y

# %%
my_path = "Data_Project/Tiger-Fox-Elephant/"
my_classes = ['fox']
X, y = create_X_y(my_path, my_classes) 
X = X.astype('float32')/255.0

# %%
 # Normalize the images to [-1, 1]
X.shape
# Out:
# (100, 124, 124, 3)

# %%
X_r,y_r = generate_real_samples(X, 10)

# %%
print(X_r.shape)
print(y_r.shape)
# Out:
# (10, 124, 124, 3)
# (10, 1)

# %%
plot_examples(X_r, y_r)

# %%
# train the discriminator model
def train_discriminator(model, dataset, epochs=100, batchsize=20):
  # on constitue un jeu de données de batchsize/2 images réelles et images fausses
  half_batch = int(batchsize / 2)
  # boucler sur les epochs
  for i in range(epochs):
    # sélection d'images réelles
    X_real, y_real = generate_real_samples(dataset, half_batch) # (X, nb_image) ==>  images de tigre réel
    # mettre à jour le discriminateur avec les images réelles
    _, real_acc = model.train_on_batch(X_real, y_real)  ## il s'entraine sur les réel 

		# generation de fausses images 
    X_fake, y_fake = generate_fake_samples(half_batch) #(nb_images) ==>
		# mise à jour du discriminateur avec de fausses images 
    _, fake_acc = model.train_on_batch(X_fake, y_fake) 

		# Affichage des résultats pour l'accuracy des vraies et des fausses
    print('>%d accuracy_real=%.0f%% accuracy_fake=%.0f%%' % (i+1, real_acc*100, fake_acc*100))

# %%
X.shape
# Out:
# (100, 124, 124, 3)

# %%
##a modifier
epochs= 15
# lancement de l'entrainement du discriminateur
train_discriminator(discriminator_model, X, epochs)
# Out:
# >1 accuracy_real=40% accuracy_fake=0%
# >2 accuracy_real=100% accuracy_fake=0%
# >3 accuracy_real=30% accuracy_fake=50%
# >4 accuracy_real=0% accuracy_fake=100%
# >5 accuracy_real=0% accuracy_fake=90%
# >6 accuracy_real=10% accuracy_fake=100%
# >7 accuracy_real=10% accuracy_fake=100%
# >8 accuracy_real=10% accuracy_fake=100%
# >9 accuracy_real=0% accuracy_fake=100%
# >10 accuracy_real=0% accuracy_fake=100%
# >11 accuracy_real=0% accuracy_fake=100%
# >12 accuracy_real=0% accuracy_fake=100%
# >13 accuracy_real=0% accuracy_fake=100%
# >14 accuracy_real=0% accuracy_fake=100%
# >15 accuracy_real=0% accuracy_fake=100%

# %% [markdown]
# Constructuion du Gan

# %%
def create_gan(generator_model, discriminator_model):
  # mettre les poids du discriminateur non entrable
  discriminator_model.trainable = False
  # un seul modele qui regroupe 
  model = Sequential()
  # ajout du générateur
  model.add(generator_model)
  # ajout du discriminateur
  model.add(discriminator_model)

  opt = Adam(learning_rate=0.0003, beta_1=0.5)
  model.compile(loss='binary_crossentropy', optimizer=opt)
  return model

# %% [markdown]
# #3- GAN final

# %%
#latent_dim = 100

# creation du générateur
#generator_model = create_generator(latent_dim)
# creation du discriminateur
#discriminator_model = create_discriminator()

# creation du gan
gan_model = create_gan(generator_model, discriminator_model)

gan_model.summary()
# Out:
# Model: "sequential_20"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential_17 (Sequential)  (None, 124, 124, 3)       26825088
#
#  sequential_19 (Sequential)  (None, 1)                 332801
#
# =================================================================
# Total params: 27,157,889
# Trainable params: 26,332,544
# Non-trainable params: 825,345
# _________________________________________________________________

# %%
# Généer des données, un vecteur aléatoire 
def generate_latent_points (latent_dim, nb_images): #(100, 100)
  X_input = np.random.randn(latent_dim* nb_images)
  X_input = X_input.reshape(nb_images, latent_dim)
  return X_input

# %%
X_input = generate_latent_points(100,100)

# %%
X_input.shape
# Out:
# (100, 100)

# %%
#il générer des images fausses 
#def generate_fake_samples_for_generator(generator_model, latent_dim, nb_images): #(model , 100, 100)
  # generation des points = vecteur 
 # X_input = generate_latent_points (latent_dim,nb_images)
  # prediction de la sortie du générateur
 # X = generator_model.predict(X_input)
 # X = ((X - 127.5) / 127.5 ).astype(np.uint8)
  # A ce niveau on considère que les images sont fausses
  # donc on met 0 comme label. 
 # y = zeros((nb_images, 1))
 # return X, y

# %%
#il générer des images fausses 
def generate_fake_samples_for_generator(generator_model, latent_dim, nb_images): #(model , 100, 100)
  # generation des points = vecteur 
  X_input = generate_latent_points (latent_dim,nb_images)
  # prediction de la sortie du générateur
  X = generator_model.predict(X_input)
  #X = ((X - 127.5) / 127.5 ).astype(np.uint8)
  # A ce niveau on considère que les images sont fausses
  # donc on met 0 comme label. 
  y = zeros((nb_images, 1))
  return X, y   ###image générer par le générateur 

#Pour sauvgarder et afficher les images générer dont l'objectif est à partir de points latent de prédire le résultat,
def plot_and_save_generatedimages(generated_images, epoch, nb_images=10): #(image générer, 15, 10 )
	# Affichage des images
  generated_images = generated_images/2 + 0.5  # con entre 0 et 1
  plt.figure(figsize=(35,35))
  for i in range(25):
    pyplot.subplot(5, 5, 1 + i)
    pyplot.axis('off')
    pyplot.imshow(cv2.cvtColor(generated_images[i], cv2.COLOR_BGR2RGB))#,cmap=plt.cm.binary)
	# sauvegarde de l'image
  filename = 'generated_plot_FoxCNN_withGan%03d.png' % (epoch+1)
  fileDir = 'GanImages/GanImagesFox/'
  pyplot.savefig(fileDir+filename)
  pyplot.close()
 


def evaluate_model (dataset, epoch, generator_model, discriminator_model, latent_dim, nb_images=100, save_model=False):
  # récupération de vraies images pour le discriminateur
  X_real, y_real = generate_real_samples(dataset, nb_images)
  # Evaluation de l'accuracy pour le discriminateur
  _, acc_real = discriminator_model.evaluate(X_real, y_real, verbose=0)

  # génération de fausses images pour le générateur et donc le gan
  X_fake, y_fake = generate_fake_samples_for_generator(generator_model, latent_dim, nb_images)
  # Evaluation du discriminateur avec des fausses images
  _, acc_fake = discriminator_model.evaluate(X_fake, y_fake, verbose=0)

  print ('Accuracy réelle : %.0f%%, fausse : %.0f%%' % (acc_real*100, acc_fake*100))
  
  plot_and_save_generatedimages(X_fake, epoch)
  if save_model==True:
    # sauvegarde du generateur pour un autre usage
    filename = 'generator_model_FoxGan%03d.h5' % (epoch + 1)
    generator_model.save(filename)

# %%
# train the generator and discriminator
def train(generator_model, discriminator_model, gan_model, dataset, latent_dim, epochs=10, batchsize=100):
  # Pour déterminer combien il y aura de batchs analysés à chaque epoch
  batches_per_epoch = int(dataset.shape[0] / batchsize) #100/5 = 20 

  # pour récupérer le même nombre d'images fausses et vraies
  half_batch = int(batchsize / 2) #20/2 =  10 

  for i in range(epochs): #pour 100 tour
    # parcours des batches pour chaque pas d'epoch
    for j in range(batches_per_epoch): # 20 tour

      #----- PARTIE DISCRIMINATOR----- r
      ##X,y = Real + fake 
      #tirage aléatoire de half_batch images vraies
      X_real, y_real = generate_real_samples(dataset, half_batch)  #( X, 10) il prends 10 images au pif 
      # generation de half_size fausses images
      X_fake, y_fake = generate_fake_samples_for_generator(generator_model, latent_dim, half_batch) #genére 10 images fake 
      # vstack permet de concaténer les vraies et fausses images dans X (resp. dans y)
      # on aurait pu utiliser np.concatenate (np.concatenate([X_real, X_fake]))
      X, y = vstack((X_real, X_fake)), vstack((y_real, y_fake))

      # la ligne suivante permet au discriminateur de mettre à jour ses poids
      # attention dans le GAN il ne peut pas aprendre donc il ne peut le faire qu'ici
      discriminator_loss,_  = discriminator_model.train_on_batch(X, y) ##il s'entraine sur les vrai et les fausses 

      #------- PARTIE GENERATOR -------- ET DONC DE L'ENTREE DU GAN
      # Création des points comme entrée du générateur 
      # 
      X_for_gan = generate_latent_points(latent_dim, batchsize)
      # On met un 1 pour les labels des fausses images pour faire croire au discriminateur
      # qu'il s'agit de vraies images
      y_for_gan = ones((batchsize, 1)) #(10,1)

      # mise à jour des poids du générateur par propagation de l'esseur du discriminateur 
      gan_loss = gan_model.train_on_batch(X_for_gan, y_for_gan)
			# Affichage des loss
      print('epoch %d - batch %d/%d, discriminator_loss=%.3f, generator_loss=%.3f'%(i+1, j+1, batches_per_epoch, discriminator_loss, gan_loss))

    # Toutes les 20 epochs evaluation du modèle et sauvegarde du générateur
    if i==1 or i % 20==0:
        evaluate_model (dataset, i, generator_model, discriminator_model, latent_dim)

# %%
latent_dim = 100
epochs= 2000
batchsize= 20 #10
# Creation du discriminateur
discriminator_model = create_discriminator()
# Creation du generateur
generator_model = create_generator(latent_dim)
# Creation du GAN
gan_model = create_gan(generator_model, discriminator_model)
# Chargement des données
my_path = "Data_Project/Tiger-Fox-Elephant/"
my_classes = ['fox']
X, y = create_X_y(my_path, my_classes) 
X = clean_data(X)
dataset = X

# train model
train(generator_model, discriminator_model, gan_model, dataset, latent_dim, epochs,batchsize)
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
# 1/1 [==============================] - 0s 15ms/step
# epoch 1505 - batch 5/5, discriminator_loss=0.176, generator_loss=0.293
# 1/1 [==============================] - 0s 15ms/step
# epoch 1506 - batch 1/5, discriminator_loss=0.137, generator_loss=0.450
# 1/1 [==============================] - 0s 16ms/step
# epoch 1506 - batch 2/5, discriminator_loss=0.139, generator_loss=0.408
# 1/1 [==============================] - 0s 15ms/step
# epoch 1506 - batch 3/5, discriminator_loss=0.120, generator_loss=1.378
# 1/1 [==============================] - 0s 15ms/step
# epoch 1506 - batch 4/5, discriminator_loss=0.064, generator_loss=2.499
# 1/1 [==============================] - 0s 15ms/step
# epoch 1506 - batch 5/5, discriminator_loss=0.133, generator_loss=0.314
# 1/1 [==============================] - 0s 15ms/step
# epoch 1507 - batch 1/5, discriminator_loss=0.073, generator_loss=0.182
# 1/1 [==============================] - 0s 15ms/step
# epoch 1507 - batch 2/5, discriminator_loss=0.182, generator_loss=0.649
# 1/1 [==============================] - 0s 16ms/step
# epoch 1507 - batch 3/5, discriminator_loss=0.071, generator_loss=0.831
# 1/1 [==============================] - 0s 19ms/step
# epoch 1507 - batch 4/5, discriminator_loss=0.157, generator_loss=0.664
# 1/1 [==============================] - 0s 15ms/step
# epoch 1507 - batch 5/5, discriminator_loss=0.208, generator_loss=2.208
# 1/1 [==============================] - 0s 19ms/step
# epoch 1508 - batch 1/5, discriminator_loss=0.039, generator_loss=2.739
# 1/1 [==============================] - 0s 19ms/step
# epoch 1508 - batch 2/5, discriminator_loss=0.067, generator_loss=1.436
# 1/1 [==============================] - 0s 19ms/step
# epoch 1508 - batch 3/5, discriminator_loss=0.178, generator_loss=0.317
# 1/1 [==============================] - 0s 16ms/step
# epoch 1508 - batch 4/5, discriminator_loss=0.230, generator_loss=2.965
# 1/1 [==============================] - 0s 15ms/step
# epoch 1508 - batch 5/5, discriminator_loss=0.097, generator_loss=2.578
# 1/1 [==============================] - 0s 15ms/step
# epoch 1509 - batch 1/5, discriminator_loss=0.140, generator_loss=2.517
# 1/1 [==============================] - 0s 17ms/step
# epoch 1509 - batch 2/5, discriminator_loss=0.094, generator_loss=1.906
# 1/1 [==============================] - 0s 20ms/step
# epoch 1509 - batch 3/5, discriminator_loss=0.261, generator_loss=0.635
# 1/1 [==============================] - 0s 16ms/step
# epoch 1509 - batch 4/5, discriminator_loss=0.219, generator_loss=5.084
# 1/1 [==============================] - 0s 18ms/step
# epoch 1509 - batch 5/5, discriminator_loss=0.209, generator_loss=3.209
# 1/1 [==============================] - 0s 23ms/step
# epoch 1510 - batch 1/5, discriminator_loss=0.074, generator_loss=1.670
# 1/1 [==============================] - 0s 18ms/step
# epoch 1510 - batch 2/5, discriminator_loss=0.165, generator_loss=1.020
# 1/1 [==============================] - 0s 16ms/step
# epoch 1510 - batch 3/5, discriminator_loss=0.171, generator_loss=3.250
# 1/1 [==============================] - 0s 17ms/step
# epoch 1510 - batch 4/5, discriminator_loss=0.203, generator_loss=2.153
# 1/1 [==============================] - 0s 17ms/step
# epoch 1510 - batch 5/5, discriminator_loss=0.154, generator_loss=2.978
# 1/1 [==============================] - 0s 15ms/step
# epoch 1511 - batch 1/5, discriminator_loss=0.101, generator_loss=2.564
# 1/1 [==============================] - 0s 15ms/step
# epoch 1511 - batch 2/5, discriminator_loss=0.120, generator_loss=1.368
# 1/1 [==============================] - 0s 17ms/step
# epoch 1511 - batch 3/5, discriminator_loss=0.171, generator_loss=2.715
# 1/1 [==============================] - 0s 19ms/step
# epoch 1511 - batch 4/5, discriminator_loss=0.248, generator_loss=0.566
# 1/1 [==============================] - 0s 15ms/step
# epoch 1511 - batch 5/5, discriminator_loss=0.264, generator_loss=4.939
# 1/1 [==============================] - 0s 17ms/step
# epoch 1512 - batch 1/5, discriminator_loss=0.198, generator_loss=4.374
# 1/1 [==============================] - 0s 18ms/step
# epoch 1512 - batch 2/5, discriminator_loss=0.223, generator_loss=0.427
# 1/1 [==============================] - 0s 17ms/step
# epoch 1512 - batch 3/5, discriminator_loss=0.318, generator_loss=4.374
# 1/1 [==============================] - 0s 15ms/step
# epoch 1512 - batch 4/5, discriminator_loss=0.148, generator_loss=3.555
# 1/1 [==============================] - 0s 17ms/step
# epoch 1512 - batch 5/5, discriminator_loss=0.359, generator_loss=1.660
# 1/1 [==============================] - 0s 18ms/step
# epoch 1513 - batch 1/5, discriminator_loss=0.251, generator_loss=3.430
# 1/1 [==============================] - 0s 17ms/step
# epoch 1513 - batch 2/5, discriminator_loss=0.055, generator_loss=4.215
# 1/1 [==============================] - 0s 15ms/step
# epoch 1513 - batch 3/5, discriminator_loss=1.227, generator_loss=0.764
# 1/1 [==============================] - 0s 16ms/step
# epoch 1513 - batch 4/5, discriminator_loss=0.695, generator_loss=23.487
# 1/1 [==============================] - 0s 16ms/step
# epoch 1513 - batch 5/5, discriminator_loss=2.073, generator_loss=0.026
# 1/1 [==============================] - 0s 16ms/step
# epoch 1514 - batch 1/5, discriminator_loss=0.409, generator_loss=0.918
# 1/1 [==============================] - 0s 15ms/step
# epoch 1514 - batch 2/5, discriminator_loss=0.401, generator_loss=0.186
# 1/1 [==============================] - 0s 17ms/step
# epoch 1514 - batch 3/5, discriminator_loss=0.220, generator_loss=0.000
# 1/1 [==============================] - 0s 22ms/step
# epoch 1514 - batch 4/5, discriminator_loss=0.854, generator_loss=0.854
# 1/1 [==============================] - 0s 14ms/step
# epoch 1514 - batch 5/5, discriminator_loss=0.464, generator_loss=0.313
# 1/1 [==============================] - 0s 15ms/step
# epoch 1515 - batch 1/5, discriminator_loss=1.905, generator_loss=0.001
# 1/1 [==============================] - 0s 18ms/step
# epoch 1515 - batch 2/5, discriminator_loss=0.001, generator_loss=0.000
# 1/1 [==============================] - 0s 17ms/step
# epoch 1515 - batch 3/5, discriminator_loss=0.008, generator_loss=0.000
# 1/1 [==============================] - 0s 16ms/step
# epoch 1515 - batch 4/5, discriminator_loss=0.016, generator_loss=0.000
# 1/1 [==============================] - 0s 15ms/step
# epoch 1515 - batch 5/5, discriminator_loss=0.040, generator_loss=0.000
# 1/1 [==============================] - 0s 15ms/step
# epoch 1516 - batch 1/5, discriminator_loss=0.008, generator_loss=0.013
# 1/1 [==============================] - 0s 16ms/step
# epoch 1516 - batch 2/5, discriminator_loss=0.022, generator_loss=0.000
# 1/1 [==============================] - 0s 17ms/step
# epoch 1516 - batch 3/5, discriminator_loss=0.004, generator_loss=0.004
# 1/1 [==============================] - 0s 15ms/step
# epoch 1516 - batch 4/5, discriminator_loss=0.003, generator_loss=0.001
# 1/1 [==============================] - 0s 16ms/step
# epoch 1516 - batch 5/5, discriminator_loss=0.040, generator_loss=0.056
# 1/1 [==============================] - 0s 22ms/step
# epoch 1517 - batch 1/5, discriminator_loss=0.018, generator_loss=0.331
# 1/1 [==============================] - 0s 15ms/step
# epoch 1517 - batch 2/5, discriminator_loss=0.024, generator_loss=0.000
# 1/1 [==============================] - 0s 19ms/step
# epoch 1517 - batch 3/5, discriminator_loss=0.018, generator_loss=0.000
# 1/1 [==============================] - 0s 16ms/step
# epoch 1517 - batch 4/5, discriminator_loss=0.009, generator_loss=0.000
# 1/1 [==============================] - 0s 15ms/step
# epoch 1517 - batch 5/5, discriminator_loss=0.012, generator_loss=0.000
# 1/1 [==============================] - 0s 19ms/step
# epoch 1518 - batch 1/5, discriminator_loss=0.014, generator_loss=0.000
# 1/1 [==============================] - 0s 15ms/step
# epoch 1518 - batch 2/5, discriminator_loss=0.002, generator_loss=0.000
# 1/1 [==============================] - 0s 15ms/step
# epoch 1518 - batch 3/5, discriminator_loss=0.009, generator_loss=0.001
# 1/1 [==============================] - 0s 15ms/step
# epoch 1518 - batch 4/5, discriminator_loss=0.039, generator_loss=0.001
# 1/1 [==============================] - 0s 17ms/step
# epoch 1518 - batch 5/5, discriminator_loss=0.003, generator_loss=0.000
# 1/1 [==============================] - 0s 15ms/step
# epoch 1519 - batch 1/5, discriminator_loss=0.023, generator_loss=0.002
# 1/1 [==============================] - 0s 16ms/step
# epoch 1519 - batch 2/5, discriminator_loss=0.006, generator_loss=0.000
# 1/1 [==============================] - 0s 17ms/step
# epoch 1519 - batch 3/5, discriminator_loss=0.003, generator_loss=0.002
# 1/1 [==============================] - 0s 17ms/step
# epoch 1519 - batch 4/5, discriminator_loss=0.079, generator_loss=0.000
# 1/1 [==============================] - 0s 17ms/step
# epoch 1519 - batch 5/5, discriminator_loss=0.025, generator_loss=0.000
# 1/1 [==============================] - 0s 15ms/step
# epoch 1520 - batch 1/5, discriminator_loss=0.086, generator_loss=0.001
# 1/1 [==============================] - 0s 15ms/step
# epoch 1520 - batch 2/5, discriminator_loss=0.004, generator_loss=0.012
# 1/1 [==============================] - 0s 16ms/step
# epoch 1520 - batch 3/5, discriminator_loss=0.014, generator_loss=0.004
# 1/1 [==============================] - 0s 19ms/step
# epoch 1520 - batch 4/5, discriminator_loss=0.007, generator_loss=0.021
# 1/1 [==============================] - 0s 20ms/step
# epoch 1520 - batch 5/5, discriminator_loss=0.005, generator_loss=0.001
# 1/1 [==============================] - 0s 16ms/step
# epoch 1521 - batch 1/5, discriminator_loss=0.009, generator_loss=0.003
# 1/1 [==============================] - 0s 15ms/step
# epoch 1521 - batch 2/5, discriminator_loss=0.021, generator_loss=0.003
# 1/1 [==============================] - 0s 15ms/step
# epoch 1521 - batch 3/5, discriminator_loss=0.007, generator_loss=0.000
# 1/1 [==============================] - 0s 15ms/step
# epoch 1521 - batch 4/5, discriminator_loss=0.007, generator_loss=0.002
# 1/1 [==============================] - 0s 18ms/step
# epoch 1521 - batch 5/5, discriminator_loss=0.020, generator_loss=0.001
# 4/4 [==============================] - 0s 59ms/step
# Accuracy réelle : 100%, fausse : 100%
# 1/1 [==============================] - 0s 15ms/step
# epoch 1522 - batch 1/5, discriminator_loss=0.028, generator_loss=0.007
# 1/1 [==============================] - 0s 15ms/step
# epoch 1522 - batch 2/5, discriminator_loss=0.002, generator_loss=0.013
# 1/1 [==============================] - 0s 17ms/step
# epoch 1522 - batch 3/5, discriminator_loss=0.027, generator_loss=0.056
# 1/1 [==============================] - 0s 17ms/step
# epoch 1522 - batch 4/5, discriminator_loss=0.013, generator_loss=0.180
# 1/1 [==============================] - 0s 15ms/step
# epoch 1522 - batch 5/5, discriminator_loss=0.010, generator_loss=0.002
# 1/1 [==============================] - 0s 15ms/step
# epoch 1523 - batch 1/5, discriminator_loss=0.005, generator_loss=0.003
# 1/1 [==============================] - 0s 17ms/step
# epoch 1523 - batch 2/5, discriminator_loss=0.009, generator_loss=0.005
# 1/1 [==============================] - 0s 25ms/step
# epoch 1523 - batch 3/5, discriminator_loss=0.011, generator_loss=0.098
# 1/1 [==============================] - 0s 15ms/step
# epoch 1523 - batch 4/5, discriminator_loss=0.100, generator_loss=0.001
# 1/1 [==============================] - 0s 15ms/step
# epoch 1523 - batch 5/5, discriminator_loss=0.037, generator_loss=0.001
# 1/1 [==============================] - 0s 16ms/step
# epoch 1524 - batch 1/5, discriminator_loss=0.105, generator_loss=0.323
# 1/1 [==============================] - 0s 16ms/step
# epoch 1524 - batch 2/5, discriminator_loss=0.061, generator_loss=0.537
# 1/1 [==============================] - 0s 18ms/step
# epoch 1524 - batch 3/5, discriminator_loss=0.005, generator_loss=0.253
# 1/1 [==============================] - 0s 17ms/step
# epoch 1524 - batch 4/5, discriminator_loss=0.017, generator_loss=0.147
# 1/1 [==============================] - 0s 18ms/step
# epoch 1524 - batch 5/5, discriminator_loss=0.078, generator_loss=0.076
# 1/1 [==============================] - 0s 19ms/step
# epoch 1525 - batch 1/5, discriminator_loss=0.014, generator_loss=0.000
# 1/1 [==============================] - 0s 17ms/step
# epoch 1525 - batch 2/5, discriminator_loss=0.064, generator_loss=0.002
# 1/1 [==============================] - 0s 17ms/step
# epoch 1525 - batch 3/5, discriminator_loss=0.008, generator_loss=0.016
# 1/1 [==============================] - 0s 15ms/step
# epoch 1525 - batch 4/5, discriminator_loss=0.004, generator_loss=0.013
# 1/1 [==============================] - 0s 15ms/step
# epoch 1525 - batch 5/5, discriminator_loss=0.030, generator_loss=0.000
# 1/1 [==============================] - 0s 15ms/step
# epoch 1526 - batch 1/5, discriminator_loss=0.164, generator_loss=0.001
# 1/1 [==============================] - 0s 16ms/step
# epoch 1526 - batch 2/5, discriminator_loss=0.021, generator_loss=0.005
# 1/1 [==============================] - 0s 15ms/step
# epoch 1526 - batch 3/5, discriminator_loss=0.031, generator_loss=0.001
# 1/1 [==============================] - 0s 18ms/step
# epoch 1526 - batch 4/5, discriminator_loss=0.013, generator_loss=0.001
# 1/1 [==============================] - 0s 17ms/step
# epoch 1526 - batch 5/5, discriminator_loss=0.004, generator_loss=0.000
# 1/1 [==============================] - 0s 17ms/step
# epoch 1527 - batch 1/5, discriminator_loss=0.063, generator_loss=0.000
# 1/1 [==============================] - 0s 16ms/step
# epoch 1527 - batch 2/5, discriminator_loss=0.006, generator_loss=0.007
# 1/1 [==============================] - 0s 15ms/step
# epoch 1527 - batch 3/5, discriminator_loss=0.039, generator_loss=0.001
# 1/1 [==============================] - 0s 24ms/step
# epoch 1527 - batch 4/5, discriminator_loss=0.164, generator_loss=0.021
# 1/1 [==============================] - 0s 15ms/step
# epoch 1527 - batch 5/5, discriminator_loss=0.968, generator_loss=3.805
# 1/1 [==============================] - 0s 15ms/step
# epoch 1528 - batch 1/5, discriminator_loss=1.336, generator_loss=0.073
# 1/1 [==============================] - 0s 14ms/step
# epoch 1528 - batch 2/5, discriminator_loss=0.147, generator_loss=0.001
# 1/1 [==============================] - 0s 16ms/step
# epoch 1528 - batch 3/5, discriminator_loss=0.237, generator_loss=0.005
# 1/1 [==============================] - 0s 15ms/step
# epoch 1528 - batch 4/5, discriminator_loss=0.090, generator_loss=0.091
# 1/1 [==============================] - 0s 15ms/step
# epoch 1528 - batch 5/5, discriminator_loss=0.193, generator_loss=0.012
# 1/1 [==============================] - 0s 23ms/step
# epoch 1529 - batch 1/5, discriminator_loss=0.359, generator_loss=0.017
# 1/1 [==============================] - 0s 16ms/step
# epoch 1529 - batch 2/5, discriminator_loss=0.170, generator_loss=0.004
# 1/1 [==============================] - 0s 14ms/step
# epoch 1529 - batch 3/5, discriminator_loss=0.245, generator_loss=0.009
# 1/1 [==============================] - 0s 16ms/step
# epoch 1529 - batch 4/5, discriminator_loss=0.100, generator_loss=0.034
# 1/1 [==============================] - 0s 16ms/step
# epoch 1529 - batch 5/5, discriminator_loss=0.176, generator_loss=0.013
# 1/1 [==============================] - 0s 15ms/step
# epoch 1530 - batch 1/5, discriminator_loss=0.191, generator_loss=0.002
# 1/1 [==============================] - 0s 14ms/step
# epoch 1530 - batch 2/5, discriminator_loss=0.178, generator_loss=0.022
# 1/1 [==============================] - 0s 17ms/step
# epoch 1530 - batch 3/5, discriminator_loss=0.162, generator_loss=0.132
# 1/1 [==============================] - 0s 16ms/step
# epoch 1530 - batch 4/5, discriminator_loss=0.067, generator_loss=0.242
# 1/1 [==============================] - 0s 15ms/step
# epoch 1530 - batch 5/5, discriminator_loss=0.078, generator_loss=0.065
# 1/1 [==============================] - 0s 15ms/step
# epoch 1531 - batch 1/5, discriminator_loss=0.050, generator_loss=0.052
# 1/1 [==============================] - 0s 18ms/step
# epoch 1531 - batch 2/5, discriminator_loss=0.094, generator_loss=0.010
# 1/1 [==============================] - 0s 16ms/step
# epoch 1531 - batch 3/5, discriminator_loss=0.102, generator_loss=0.016
# 1/1 [==============================] - 0s 15ms/step
# epoch 1531 - batch 4/5, discriminator_loss=0.080, generator_loss=0.071
# 1/1 [==============================] - 0s 15ms/step
# epoch 1531 - batch 5/5, discriminator_loss=0.134, generator_loss=0.540
# 1/1 [==============================] - 0s 21ms/step
# epoch 1532 - batch 1/5, discriminator_loss=0.119, generator_loss=0.283
# 1/1 [==============================] - 0s 15ms/step
# epoch 1532 - batch 2/5, discriminator_loss=0.151, generator_loss=0.162
# 1/1 [==============================] - 0s 15ms/step
# epoch 1532 - batch 3/5, discriminator_loss=0.064, generator_loss=0.054
# 1/1 [==============================] - 0s 19ms/step
# epoch 1532 - batch 4/5, discriminator_loss=0.104, generator_loss=0.183
# 1/1 [==============================] - 0s 15ms/step
# epoch 1532 - batch 5/5, discriminator_loss=0.045, generator_loss=0.043
# 1/1 [==============================] - 0s 15ms/step
# epoch 1533 - batch 1/5, discriminator_loss=0.066, generator_loss=0.086
# 1/1 [==============================] - 0s 23ms/step
# epoch 1533 - batch 2/5, discriminator_loss=0.217, generator_loss=0.232
# 1/1 [==============================] - 0s 14ms/step
# epoch 1533 - batch 3/5, discriminator_loss=0.263, generator_loss=0.283
# 1/1 [==============================] - 0s 17ms/step
# epoch 1533 - batch 4/5, discriminator_loss=0.108, generator_loss=0.367
# 1/1 [==============================] - 0s 15ms/step
# epoch 1533 - batch 5/5, discriminator_loss=0.076, generator_loss=0.551
# 1/1 [==============================] - 0s 15ms/step
# epoch 1534 - batch 1/5, discriminator_loss=0.070, generator_loss=0.228
# 1/1 [==============================] - 0s 15ms/step
# epoch 1534 - batch 2/5, discriminator_loss=0.084, generator_loss=0.284
# 1/1 [==============================] - 0s 15ms/step
# epoch 1534 - batch 3/5, discriminator_loss=0.125, generator_loss=0.330
# 1/1 [==============================] - 0s 17ms/step
# epoch 1534 - batch 4/5, discriminator_loss=0.071, generator_loss=0.325
# 1/1 [==============================] - 0s 14ms/step
# epoch 1534 - batch 5/5, discriminator_loss=0.042, generator_loss=0.261
# 1/1 [==============================] - 0s 15ms/step
# epoch 1535 - batch 1/5, discriminator_loss=0.183, generator_loss=0.378
# 1/1 [==============================] - 0s 15ms/step
# epoch 1535 - batch 2/5, discriminator_loss=0.106, generator_loss=0.419
# 1/1 [==============================] - 0s 16ms/step
# epoch 1535 - batch 3/5, discriminator_loss=0.123, generator_loss=0.083
# 1/1 [==============================] - 0s 15ms/step
# epoch 1535 - batch 4/5, discriminator_loss=0.089, generator_loss=0.204
# 1/1 [==============================] - 0s 15ms/step
# epoch 1535 - batch 5/5, discriminator_loss=0.110, generator_loss=0.445
# 1/1 [==============================] - 0s 16ms/step
# epoch 1536 - batch 1/5, discriminator_loss=0.082, generator_loss=0.286
# 1/1 [==============================] - 0s 15ms/step
# epoch 1536 - batch 2/5, discriminator_loss=0.042, generator_loss=0.132
# 1/1 [==============================] - 0s 17ms/step
# epoch 1536 - batch 3/5, discriminator_loss=0.148, generator_loss=0.232
# 1/1 [==============================] - 0s 15ms/step
# epoch 1536 - batch 4/5, discriminator_loss=0.182, generator_loss=0.452
# 1/1 [==============================] - 0s 17ms/step
# epoch 1536 - batch 5/5, discriminator_loss=0.170, generator_loss=0.744
# 1/1 [==============================] - 0s 18ms/step
# epoch 1537 - batch 1/5, discriminator_loss=0.097, generator_loss=1.868
# 1/1 [==============================] - 0s 16ms/step
# epoch 1537 - batch 2/5, discriminator_loss=0.052, generator_loss=1.711
# 1/1 [==============================] - 0s 23ms/step
# epoch 1537 - batch 3/5, discriminator_loss=0.100, generator_loss=1.367
# 1/1 [==============================] - 0s 22ms/step
# epoch 1537 - batch 4/5, discriminator_loss=0.144, generator_loss=0.913
# 1/1 [==============================] - 0s 18ms/step
# epoch 1537 - batch 5/5, discriminator_loss=0.076, generator_loss=2.100
# 1/1 [==============================] - 0s 16ms/step
# epoch 1538 - batch 1/5, discriminator_loss=0.077, generator_loss=2.402
# 1/1 [==============================] - 0s 15ms/step
# epoch 1538 - batch 2/5, discriminator_loss=0.079, generator_loss=4.011
# 1/1 [==============================] - 0s 16ms/step
# epoch 1538 - batch 3/5, discriminator_loss=0.187, generator_loss=2.871
# 1/1 [==============================] - 0s 15ms/step
# epoch 1538 - batch 4/5, discriminator_loss=0.145, generator_loss=2.000
# 1/1 [==============================] - 0s 18ms/step
# epoch 1538 - batch 5/5, discriminator_loss=0.159, generator_loss=1.499
# 1/1 [==============================] - 0s 16ms/step
# epoch 1539 - batch 1/5, discriminator_loss=0.319, generator_loss=1.120
# 1/1 [==============================] - 0s 15ms/step
# epoch 1539 - batch 2/5, discriminator_loss=0.181, generator_loss=1.896
# 1/1 [==============================] - 0s 15ms/step
# epoch 1539 - batch 3/5, discriminator_loss=0.120, generator_loss=1.994
# 1/1 [==============================] - 0s 15ms/step
# epoch 1539 - batch 4/5, discriminator_loss=0.142, generator_loss=3.724
# 1/1 [==============================] - 0s 15ms/step
# epoch 1539 - batch 5/5, discriminator_loss=0.040, generator_loss=3.314
# 1/1 [==============================] - 0s 15ms/step
# epoch 1540 - batch 1/5, discriminator_loss=0.095, generator_loss=3.283
# 1/1 [==============================] - 0s 17ms/step
# epoch 1540 - batch 2/5, discriminator_loss=0.143, generator_loss=4.872
# 1/1 [==============================] - 0s 17ms/step
# epoch 1540 - batch 3/5, discriminator_loss=0.083, generator_loss=5.079
# 1/1 [==============================] - 0s 17ms/step
# epoch 1540 - batch 4/5, discriminator_loss=0.042, generator_loss=6.065
# 1/1 [==============================] - 0s 17ms/step
# epoch 1540 - batch 5/5, discriminator_loss=0.736, generator_loss=0.889
# 1/1 [==============================] - 0s 23ms/step
# epoch 1541 - batch 1/5, discriminator_loss=0.176, generator_loss=0.112
# 1/1 [==============================] - 0s 21ms/step
# epoch 1541 - batch 2/5, discriminator_loss=0.362, generator_loss=1.852
# 1/1 [==============================] - 0s 15ms/step
# epoch 1541 - batch 3/5, discriminator_loss=0.455, generator_loss=0.887
# 1/1 [==============================] - 0s 16ms/step
# epoch 1541 - batch 4/5, discriminator_loss=0.173, generator_loss=2.330
# 1/1 [==============================] - 0s 15ms/step
# epoch 1541 - batch 5/5, discriminator_loss=0.392, generator_loss=3.067
# 4/4 [==============================] - 0s 60ms/step
# Accuracy réelle : 91%, fausse : 97%
# 1/1 [==============================] - 0s 16ms/step
# epoch 1542 - batch 1/5, discriminator_loss=0.106, generator_loss=2.955
# 1/1 [==============================] - 0s 15ms/step
# epoch 1542 - batch 2/5, discriminator_loss=0.036, generator_loss=2.926
# 1/1 [==============================] - 0s 20ms/step
# epoch 1542 - batch 3/5, discriminator_loss=0.109, generator_loss=1.398
# 1/1 [==============================] - 0s 16ms/step
# epoch 1542 - batch 4/5, discriminator_loss=0.186, generator_loss=2.053
# 1/1 [==============================] - 0s 15ms/step
# epoch 1542 - batch 5/5, discriminator_loss=0.142, generator_loss=2.190
# 1/1 [==============================] - 0s 15ms/step
# epoch 1543 - batch 1/5, discriminator_loss=0.040, generator_loss=2.468
# 1/1 [==============================] - 0s 16ms/step
# epoch 1543 - batch 2/5, discriminator_loss=0.144, generator_loss=1.822
# 1/1 [==============================] - 0s 16ms/step
# epoch 1543 - batch 3/5, discriminator_loss=0.122, generator_loss=1.686
# 1/1 [==============================] - 0s 15ms/step
# epoch 1543 - batch 4/5, discriminator_loss=0.230, generator_loss=1.217
# 1/1 [==============================] - 0s 15ms/step
# epoch 1543 - batch 5/5, discriminator_loss=0.118, generator_loss=1.763
# 1/1 [==============================] - 0s 16ms/step
# epoch 1544 - batch 1/5, discriminator_loss=0.146, generator_loss=2.268
# 1/1 [==============================] - 0s 15ms/step
# epoch 1544 - batch 2/5, discriminator_loss=0.110, generator_loss=1.907
# 1/1 [==============================] - 0s 18ms/step
# epoch 1544 - batch 3/5, discriminator_loss=0.120, generator_loss=1.744
# 1/1 [==============================] - 0s 16ms/step
# epoch 1544 - batch 4/5, discriminator_loss=0.092, generator_loss=2.118
# 1/1 [==============================] - 0s 15ms/step
# epoch 1544 - batch 5/5, discriminator_loss=0.279, generator_loss=1.752
# 1/1 [==============================] - 0s 15ms/step
# epoch 1545 - batch 1/5, discriminator_loss=0.144, generator_loss=1.817
# 1/1 [==============================] - 0s 17ms/step
# epoch 1545 - batch 2/5, discriminator_loss=0.155, generator_loss=1.016
# 1/1 [==============================] - 0s 17ms/step
# epoch 1545 - batch 3/5, discriminator_loss=0.146, generator_loss=1.107
# 1/1 [==============================] - 0s 15ms/step
# epoch 1545 - batch 4/5, discriminator_loss=0.338, generator_loss=3.443
# 1/1 [==============================] - 0s 16ms/step
# epoch 1545 - batch 5/5, discriminator_loss=0.342, generator_loss=1.080
# 1/1 [==============================] - 0s 18ms/step
# epoch 1546 - batch 1/5, discriminator_loss=0.163, generator_loss=0.430
# 1/1 [==============================] - 0s 16ms/step
# epoch 1546 - batch 2/5, discriminator_loss=0.253, generator_loss=1.403
# 1/1 [==============================] - 0s 17ms/step
# epoch 1546 - batch 3/5, discriminator_loss=0.154, generator_loss=2.181
# 1/1 [==============================] - 0s 16ms/step
# epoch 1546 - batch 4/5, discriminator_loss=0.143, generator_loss=1.999
# 1/1 [==============================] - 0s 15ms/step
# epoch 1546 - batch 5/5, discriminator_loss=0.175, generator_loss=0.815
# 1/1 [==============================] - 0s 16ms/step
# epoch 1547 - batch 1/5, discriminator_loss=0.118, generator_loss=0.450
# 1/1 [==============================] - 0s 17ms/step
# epoch 1547 - batch 2/5, discriminator_loss=0.148, generator_loss=0.756
# 1/1 [==============================] - 0s 22ms/step
# epoch 1547 - batch 3/5, discriminator_loss=0.191, generator_loss=1.456
# 1/1 [==============================] - 0s 15ms/step
# epoch 1547 - batch 4/5, discriminator_loss=0.085, generator_loss=2.215
# 1/1 [==============================] - 0s 15ms/step
# epoch 1547 - batch 5/5, discriminator_loss=0.220, generator_loss=0.998
# 1/1 [==============================] - 0s 19ms/step
# epoch 1548 - batch 1/5, discriminator_loss=0.191, generator_loss=1.339
# 1/1 [==============================] - 0s 17ms/step
# epoch 1548 - batch 2/5, discriminator_loss=0.112, generator_loss=0.987
# 1/1 [==============================] - 0s 15ms/step
# epoch 1548 - batch 3/5, discriminator_loss=0.135, generator_loss=0.485
# 1/1 [==============================] - 0s 17ms/step
# epoch 1548 - batch 4/5, discriminator_loss=0.045, generator_loss=0.127
# 1/1 [==============================] - 0s 20ms/step
# epoch 1548 - batch 5/5, discriminator_loss=0.048, generator_loss=0.225
# 1/1 [==============================] - 0s 16ms/step
# epoch 1549 - batch 1/5, discriminator_loss=0.083, generator_loss=1.073
# 1/1 [==============================] - 0s 17ms/step
# epoch 1549 - batch 2/5, discriminator_loss=0.039, generator_loss=1.733
# 1/1 [==============================] - 0s 17ms/step
# epoch 1549 - batch 3/5, discriminator_loss=0.068, generator_loss=1.487
# 1/1 [==============================] - 0s 19ms/step
# epoch 1549 - batch 4/5, discriminator_loss=0.032, generator_loss=0.323
# 1/1 [==============================] - 0s 15ms/step
# epoch 1549 - batch 5/5, discriminator_loss=0.101, generator_loss=0.854
# 1/1 [==============================] - 0s 17ms/step
# epoch 1550 - batch 1/5, discriminator_loss=0.126, generator_loss=2.057
# 1/1 [==============================] - 0s 15ms/step
# epoch 1550 - batch 2/5, discriminator_loss=0.156, generator_loss=1.737
# 1/1 [==============================] - 0s 17ms/step
# epoch 1550 - batch 3/5, discriminator_loss=0.178, generator_loss=0.272
# 1/1 [==============================] - 0s 15ms/step
# epoch 1550 - batch 4/5, discriminator_loss=0.078, generator_loss=0.293
# 1/1 [==============================] - 0s 15ms/step
# epoch 1550 - batch 5/5, discriminator_loss=0.097, generator_loss=0.863
# 1/1 [==============================] - 0s 15ms/step
# epoch 1551 - batch 1/5, discriminator_loss=0.081, generator_loss=1.305
# 1/1 [==============================] - 0s 17ms/step
# epoch 1551 - batch 2/5, discriminator_loss=0.157, generator_loss=0.664
# 1/1 [==============================] - 0s 16ms/step
# epoch 1551 - batch 3/5, discriminator_loss=0.082, generator_loss=0.907
# 1/1 [==============================] - 0s 15ms/step
# epoch 1551 - batch 4/5, discriminator_loss=0.157, generator_loss=3.553
# 1/1 [==============================] - 0s 16ms/step
# epoch 1551 - batch 5/5, discriminator_loss=0.354, generator_loss=0.649
# 1/1 [==============================] - 0s 16ms/step
# epoch 1552 - batch 1/5, discriminator_loss=0.095, generator_loss=0.513
# 1/1 [==============================] - 0s 16ms/step
# epoch 1552 - batch 2/5, discriminator_loss=0.188, generator_loss=1.774
# 1/1 [==============================] - 0s 17ms/step
# epoch 1552 - batch 3/5, discriminator_loss=0.200, generator_loss=2.993
# 1/1 [==============================] - 0s 15ms/step
# epoch 1552 - batch 4/5, discriminator_loss=0.186, generator_loss=1.818
# 1/1 [==============================] - 0s 17ms/step
# epoch 1552 - batch 5/5, discriminator_loss=0.164, generator_loss=2.303
# 1/1 [==============================] - 0s 16ms/step
# epoch 1553 - batch 1/5, discriminator_loss=0.188, generator_loss=1.422
# 1/1 [==============================] - 0s 18ms/step
# epoch 1553 - batch 2/5, discriminator_loss=0.050, generator_loss=1.375
# 1/1 [==============================] - 0s 15ms/step
# epoch 1553 - batch 3/5, discriminator_loss=0.168, generator_loss=3.436
# 1/1 [==============================] - 0s 15ms/step
# epoch 1553 - batch 4/5, discriminator_loss=0.654, generator_loss=4.369
# 1/1 [==============================] - 0s 17ms/step
# epoch 1553 - batch 5/5, discriminator_loss=0.114, generator_loss=4.468
# 1/1 [==============================] - 0s 17ms/step
# epoch 1554 - batch 1/5, discriminator_loss=0.259, generator_loss=2.831
# 1/1 [==============================] - 0s 16ms/step
# epoch 1554 - batch 2/5, discriminator_loss=0.209, generator_loss=3.402
# 1/1 [==============================] - 0s 15ms/step
# epoch 1554 - batch 3/5, discriminator_loss=0.196, generator_loss=5.488
# 1/1 [==============================] - 0s 18ms/step
# epoch 1554 - batch 4/5, discriminator_loss=0.316, generator_loss=1.296
# 1/1 [==============================] - 0s 17ms/step
# epoch 1554 - batch 5/5, discriminator_loss=0.376, generator_loss=0.512
# 1/1 [==============================] - 0s 15ms/step
# epoch 1555 - batch 1/5, discriminator_loss=0.506, generator_loss=3.248
# 1/1 [==============================] - 0s 15ms/step
# epoch 1555 - batch 2/5, discriminator_loss=0.176, generator_loss=4.656
# 1/1 [==============================] - 0s 15ms/step
# epoch 1555 - batch 3/5, discriminator_loss=0.367, generator_loss=2.035
# 1/1 [==============================] - 0s 26ms/step
# epoch 1555 - batch 4/5, discriminator_loss=0.481, generator_loss=1.818
# 1/1 [==============================] - 0s 15ms/step
# epoch 1555 - batch 5/5, discriminator_loss=0.296, generator_loss=3.302
# 1/1 [==============================] - 0s 21ms/step
# epoch 1556 - batch 1/5, discriminator_loss=0.295, generator_loss=5.259
# 1/1 [==============================] - 0s 15ms/step
# epoch 1556 - batch 2/5, discriminator_loss=0.578, generator_loss=3.125
# 1/1 [==============================] - 0s 16ms/step
# epoch 1556 - batch 3/5, discriminator_loss=0.545, generator_loss=0.395
# 1/1 [==============================] - 0s 15ms/step
# epoch 1556 - batch 4/5, discriminator_loss=0.318, generator_loss=0.841
# 1/1 [==============================] - 0s 24ms/step
# epoch 1556 - batch 5/5, discriminator_loss=0.199, generator_loss=1.402
# 1/1 [==============================] - 0s 15ms/step
# epoch 1557 - batch 1/5, discriminator_loss=0.316, generator_loss=0.872
# 1/1 [==============================] - 0s 18ms/step
# epoch 1557 - batch 2/5, discriminator_loss=0.243, generator_loss=0.783
# 1/1 [==============================] - 0s 20ms/step
# epoch 1557 - batch 3/5, discriminator_loss=0.223, generator_loss=1.215
# 1/1 [==============================] - 0s 27ms/step
# epoch 1557 - batch 4/5, discriminator_loss=0.175, generator_loss=0.631
# 1/1 [==============================] - 0s 15ms/step
# epoch 1557 - batch 5/5, discriminator_loss=0.156, generator_loss=0.341
# 1/1 [==============================] - 0s 15ms/step
# epoch 1558 - batch 1/5, discriminator_loss=0.150, generator_loss=1.113
# 1/1 [==============================] - 0s 18ms/step
# epoch 1558 - batch 2/5, discriminator_loss=0.271, generator_loss=1.767
# 1/1 [==============================] - 0s 15ms/step
# epoch 1558 - batch 3/5, discriminator_loss=0.157, generator_loss=1.252
# 1/1 [==============================] - 0s 17ms/step
# epoch 1558 - batch 4/5, discriminator_loss=0.157, generator_loss=2.020
# 1/1 [==============================] - 0s 15ms/step
# epoch 1558 - batch 5/5, discriminator_loss=0.226, generator_loss=0.025
# 1/1 [==============================] - 0s 15ms/step
# epoch 1559 - batch 1/5, discriminator_loss=0.228, generator_loss=0.134
# 1/1 [==============================] - 0s 15ms/step
# epoch 1559 - batch 2/5, discriminator_loss=0.198, generator_loss=0.371
# 1/1 [==============================] - 0s 20ms/step
# epoch 1559 - batch 3/5, discriminator_loss=0.298, generator_loss=0.810
# 1/1 [==============================] - 0s 17ms/step
# epoch 1559 - batch 4/5, discriminator_loss=0.173, generator_loss=0.578
# 1/1 [==============================] - 0s 15ms/step
# epoch 1559 - batch 5/5, discriminator_loss=0.169, generator_loss=0.542
# 1/1 [==============================] - 0s 17ms/step
# epoch 1560 - batch 1/5, discriminator_loss=0.089, generator_loss=0.740
# 1/1 [==============================] - 0s 15ms/step
# epoch 1560 - batch 2/5, discriminator_loss=0.263, generator_loss=0.173
# 1/1 [==============================] - 0s 16ms/step
# epoch 1560 - batch 3/5, discriminator_loss=0.108, generator_loss=0.128
# 1/1 [==============================] - 0s 15ms/step
# epoch 1560 - batch 4/5, discriminator_loss=0.161, generator_loss=0.158
# 1/1 [==============================] - 0s 15ms/step
# epoch 1560 - batch 5/5, discriminator_loss=0.186, generator_loss=0.291
# 1/1 [==============================] - 0s 16ms/step
# epoch 1561 - batch 1/5, discriminator_loss=0.173, generator_loss=0.355
# 1/1 [==============================] - 0s 16ms/step
# epoch 1561 - batch 2/5, discriminator_loss=0.157, generator_loss=0.279
# 1/1 [==============================] - 0s 16ms/step
# epoch 1561 - batch 3/5, discriminator_loss=0.180, generator_loss=0.543
# 1/1 [==============================] - 0s 18ms/step
# epoch 1561 - batch 4/5, discriminator_loss=0.136, generator_loss=0.191
# 1/1 [==============================] - 0s 18ms/step
# epoch 1561 - batch 5/5, discriminator_loss=0.111, generator_loss=0.057
# 4/4 [==============================] - 0s 59ms/step
# Accuracy réelle : 100%, fausse : 100%
# 1/1 [==============================] - 0s 16ms/step
# epoch 1562 - batch 1/5, discriminator_loss=0.098, generator_loss=0.008
# 1/1 [==============================] - 0s 15ms/step
# epoch 1562 - batch 2/5, discriminator_loss=0.071, generator_loss=0.008
# 1/1 [==============================] - 0s 17ms/step
# epoch 1562 - batch 3/5, discriminator_loss=0.063, generator_loss=0.017
# 1/1 [==============================] - 0s 17ms/step
# epoch 1562 - batch 4/5, discriminator_loss=0.061, generator_loss=0.016
# 1/1 [==============================] - 0s 15ms/step
# epoch 1562 - batch 5/5, discriminator_loss=0.120, generator_loss=0.007
# 1/1 [==============================] - 0s 16ms/step
# epoch 1563 - batch 1/5, discriminator_loss=0.066, generator_loss=0.006
# 1/1 [==============================] - 0s 17ms/step
# epoch 1563 - batch 2/5, discriminator_loss=0.044, generator_loss=0.004
# 1/1 [==============================] - 0s 17ms/step
# epoch 1563 - batch 3/5, discriminator_loss=0.070, generator_loss=0.005
# 1/1 [==============================] - 0s 16ms/step
# epoch 1563 - batch 4/5, discriminator_loss=0.061, generator_loss=0.025
# 1/1 [==============================] - 0s 15ms/step
# epoch 1563 - batch 5/5, discriminator_loss=0.037, generator_loss=0.005
# 1/1 [==============================] - 0s 15ms/step
# epoch 1564 - batch 1/5, discriminator_loss=0.126, generator_loss=0.011
# 1/1 [==============================] - 0s 16ms/step
# epoch 1564 - batch 2/5, discriminator_loss=0.058, generator_loss=0.007
# 1/1 [==============================] - 0s 15ms/step
# epoch 1564 - batch 3/5, discriminator_loss=0.079, generator_loss=0.012
# 1/1 [==============================] - 0s 15ms/step
# epoch 1564 - batch 4/5, discriminator_loss=0.088, generator_loss=0.013
# 1/1 [==============================] - 0s 16ms/step
# epoch 1564 - batch 5/5, discriminator_loss=0.053, generator_loss=0.011
# 1/1 [==============================] - 0s 15ms/step
# epoch 1565 - batch 1/5, discriminator_loss=0.020, generator_loss=0.035
# 1/1 [==============================] - 0s 18ms/step
# epoch 1565 - batch 2/5, discriminator_loss=0.069, generator_loss=0.009
# 1/1 [==============================] - 0s 19ms/step
# epoch 1565 - batch 3/5, discriminator_loss=0.120, generator_loss=0.003
# 1/1 [==============================] - 0s 19ms/step
# epoch 1565 - batch 4/5, discriminator_loss=0.082, generator_loss=0.004
# 1/1 [==============================] - 0s 16ms/step
# epoch 1565 - batch 5/5, discriminator_loss=0.054, generator_loss=0.018
# 1/1 [==============================] - 0s 19ms/step
# epoch 1566 - batch 1/5, discriminator_loss=0.031, generator_loss=0.016
# 1/1 [==============================] - 0s 20ms/step
# epoch 1566 - batch 2/5, discriminator_loss=0.059, generator_loss=0.031
# 1/1 [==============================] - 0s 20ms/step
# epoch 1566 - batch 3/5, discriminator_loss=0.084, generator_loss=0.010
# 1/1 [==============================] - 0s 18ms/step
# epoch 1566 - batch 4/5, discriminator_loss=0.047, generator_loss=0.006
# 1/1 [==============================] - 0s 17ms/step
# epoch 1566 - batch 5/5, discriminator_loss=0.052, generator_loss=0.023
# 1/1 [==============================] - 0s 16ms/step
# epoch 1567 - batch 1/5, discriminator_loss=0.078, generator_loss=0.034
# 1/1 [==============================] - 0s 16ms/step
# epoch 1567 - batch 2/5, discriminator_loss=0.047, generator_loss=0.024
# 1/1 [==============================] - 0s 15ms/step
# epoch 1567 - batch 3/5, discriminator_loss=0.033, generator_loss=0.040
# 1/1 [==============================] - 0s 18ms/step
# epoch 1567 - batch 4/5, discriminator_loss=0.038, generator_loss=0.014
# 1/1 [==============================] - 0s 20ms/step
# epoch 1567 - batch 5/5, discriminator_loss=0.024, generator_loss=0.010
# 1/1 [==============================] - 0s 16ms/step
# epoch 1568 - batch 1/5, discriminator_loss=0.035, generator_loss=0.079
# 1/1 [==============================] - 0s 15ms/step
# epoch 1568 - batch 2/5, discriminator_loss=0.031, generator_loss=0.021
# 1/1 [==============================] - 0s 15ms/step
# epoch 1568 - batch 3/5, discriminator_loss=0.049, generator_loss=0.004
# 1/1 [==============================] - 0s 15ms/step
# epoch 1568 - batch 4/5, discriminator_loss=0.025, generator_loss=0.007
# 1/1 [==============================] - 0s 15ms/step
# epoch 1568 - batch 5/5, discriminator_loss=0.017, generator_loss=0.009
# 1/1 [==============================] - 0s 15ms/step
# epoch 1569 - batch 1/5, discriminator_loss=0.105, generator_loss=0.017
# 1/1 [==============================] - 0s 15ms/step
# epoch 1569 - batch 2/5, discriminator_loss=0.064, generator_loss=0.003
# 1/1 [==============================] - 0s 15ms/step
# epoch 1569 - batch 3/5, discriminator_loss=0.038, generator_loss=0.031
# 1/1 [==============================] - 0s 16ms/step
# epoch 1569 - batch 4/5, discriminator_loss=0.074, generator_loss=0.072
# 1/1 [==============================] - 0s 15ms/step
# epoch 1569 - batch 5/5, discriminator_loss=0.019, generator_loss=0.033
# 1/1 [==============================] - 0s 17ms/step
# epoch 1570 - batch 1/5, discriminator_loss=0.063, generator_loss=0.039
# 1/1 [==============================] - 0s 15ms/step
# epoch 1570 - batch 2/5, discriminator_loss=0.047, generator_loss=0.029
# 1/1 [==============================] - 0s 15ms/step
# epoch 1570 - batch 3/5, discriminator_loss=0.064, generator_loss=0.074
# 1/1 [==============================] - 0s 15ms/step
# epoch 1570 - batch 4/5, discriminator_loss=0.067, generator_loss=0.027
# 1/1 [==============================] - 0s 19ms/step
# epoch 1570 - batch 5/5, discriminator_loss=0.080, generator_loss=0.009
# 1/1 [==============================] - 0s 17ms/step
# epoch 1571 - batch 1/5, discriminator_loss=0.058, generator_loss=0.039
# 1/1 [==============================] - 0s 16ms/step
# epoch 1571 - batch 2/5, discriminator_loss=0.062, generator_loss=0.134
# 1/1 [==============================] - 0s 15ms/step
# epoch 1571 - batch 3/5, discriminator_loss=0.032, generator_loss=0.042
# 1/1 [==============================] - 0s 15ms/step
# epoch 1571 - batch 4/5, discriminator_loss=0.054, generator_loss=0.110
# 1/1 [==============================] - 0s 15ms/step
# epoch 1571 - batch 5/5, discriminator_loss=0.078, generator_loss=0.060
# 1/1 [==============================] - 0s 16ms/step
# epoch 1572 - batch 1/5, discriminator_loss=0.027, generator_loss=0.025
# 1/1 [==============================] - 0s 16ms/step
# epoch 1572 - batch 2/5, discriminator_loss=0.065, generator_loss=0.055
# 1/1 [==============================] - 0s 16ms/step
# epoch 1572 - batch 3/5, discriminator_loss=0.031, generator_loss=0.033
# 1/1 [==============================] - 0s 15ms/step
# epoch 1572 - batch 4/5, discriminator_loss=0.035, generator_loss=0.016
# 1/1 [==============================] - 0s 17ms/step
# epoch 1572 - batch 5/5, discriminator_loss=0.037, generator_loss=0.028
# 1/1 [==============================] - 0s 17ms/step
# epoch 1573 - batch 1/5, discriminator_loss=0.056, generator_loss=0.060
# 1/1 [==============================] - 0s 16ms/step
# epoch 1573 - batch 2/5, discriminator_loss=0.062, generator_loss=0.067
# 1/1 [==============================] - 0s 16ms/step
# epoch 1573 - batch 3/5, discriminator_loss=0.022, generator_loss=0.035
# 1/1 [==============================] - 0s 19ms/step
# epoch 1573 - batch 4/5, discriminator_loss=0.025, generator_loss=0.097
# 1/1 [==============================] - 0s 17ms/step
# epoch 1573 - batch 5/5, discriminator_loss=0.038, generator_loss=0.233
# 1/1 [==============================] - 0s 18ms/step
# epoch 1574 - batch 1/5, discriminator_loss=0.033, generator_loss=0.128
# 1/1 [==============================] - 0s 15ms/step
# epoch 1574 - batch 2/5, discriminator_loss=0.049, generator_loss=0.094
# 1/1 [==============================] - 0s 17ms/step
# epoch 1574 - batch 3/5, discriminator_loss=0.059, generator_loss=0.062
# 1/1 [==============================] - 0s 15ms/step
# epoch 1574 - batch 4/5, discriminator_loss=0.049, generator_loss=0.059
# 1/1 [==============================] - 0s 18ms/step
# epoch 1574 - batch 5/5, discriminator_loss=0.051, generator_loss=0.091
# 1/1 [==============================] - 0s 17ms/step
# epoch 1575 - batch 1/5, discriminator_loss=0.052, generator_loss=0.113
# 1/1 [==============================] - 0s 16ms/step
# epoch 1575 - batch 2/5, discriminator_loss=0.023, generator_loss=0.340
# 1/1 [==============================] - 0s 15ms/step
# epoch 1575 - batch 3/5, discriminator_loss=0.051, generator_loss=0.353
# 1/1 [==============================] - 0s 18ms/step
# epoch 1575 - batch 4/5, discriminator_loss=0.235, generator_loss=0.000
# 1/1 [==============================] - 0s 16ms/step
# epoch 1575 - batch 5/5, discriminator_loss=0.668, generator_loss=0.068
# 1/1 [==============================] - 0s 17ms/step
# epoch 1576 - batch 1/5, discriminator_loss=0.252, generator_loss=0.216
# 1/1 [==============================] - 0s 16ms/step
# epoch 1576 - batch 2/5, discriminator_loss=0.109, generator_loss=0.180
# 1/1 [==============================] - 0s 16ms/step
# epoch 1576 - batch 3/5, discriminator_loss=0.064, generator_loss=0.039
# 1/1 [==============================] - 0s 17ms/step
# epoch 1576 - batch 4/5, discriminator_loss=0.092, generator_loss=0.307
# 1/1 [==============================] - 0s 18ms/step
# epoch 1576 - batch 5/5, discriminator_loss=0.032, generator_loss=0.442
# 1/1 [==============================] - 0s 18ms/step
# epoch 1577 - batch 1/5, discriminator_loss=0.015, generator_loss=0.456
# 1/1 [==============================] - 0s 16ms/step
# epoch 1577 - batch 2/5, discriminator_loss=0.017, generator_loss=0.434
# 1/1 [==============================] - 0s 16ms/step
# epoch 1577 - batch 3/5, discriminator_loss=0.014, generator_loss=0.579
# 1/1 [==============================] - 0s 25ms/step
# epoch 1577 - batch 4/5, discriminator_loss=0.037, generator_loss=0.868
# 1/1 [==============================] - 0s 22ms/step
# epoch 1577 - batch 5/5, discriminator_loss=0.122, generator_loss=0.040
# 1/1 [==============================] - 0s 15ms/step
# epoch 1578 - batch 1/5, discriminator_loss=0.048, generator_loss=0.021
# 1/1 [==============================] - 0s 19ms/step
# epoch 1578 - batch 2/5, discriminator_loss=0.038, generator_loss=0.032
# 1/1 [==============================] - 0s 18ms/step
# epoch 1578 - batch 3/5, discriminator_loss=0.034, generator_loss=0.167
# 1/1 [==============================] - 0s 17ms/step
# epoch 1578 - batch 4/5, discriminator_loss=0.011, generator_loss=0.530
# 1/1 [==============================] - 0s 16ms/step
# epoch 1578 - batch 5/5, discriminator_loss=0.017, generator_loss=1.090
# 1/1 [==============================] - 0s 16ms/step
# epoch 1579 - batch 1/5, discriminator_loss=0.010, generator_loss=0.847
# 1/1 [==============================] - 0s 30ms/step
# epoch 1579 - batch 2/5, discriminator_loss=0.071, generator_loss=0.270
# 1/1 [==============================] - 0s 15ms/step
# epoch 1579 - batch 3/5, discriminator_loss=0.035, generator_loss=0.199
# 1/1 [==============================] - 0s 18ms/step
# epoch 1579 - batch 4/5, discriminator_loss=0.046, generator_loss=0.102
# 1/1 [==============================] - 0s 16ms/step
# epoch 1579 - batch 5/5, discriminator_loss=0.011, generator_loss=0.122
# 1/1 [==============================] - 0s 15ms/step
# epoch 1580 - batch 1/5, discriminator_loss=0.058, generator_loss=0.204
# 1/1 [==============================] - 0s 16ms/step
# epoch 1580 - batch 2/5, discriminator_loss=0.018, generator_loss=0.109
# 1/1 [==============================] - 0s 16ms/step
# epoch 1580 - batch 3/5, discriminator_loss=0.350, generator_loss=0.001
# 1/1 [==============================] - 0s 16ms/step
# epoch 1580 - batch 4/5, discriminator_loss=0.252, generator_loss=1.109
# 1/1 [==============================] - 0s 15ms/step
# epoch 1580 - batch 5/5, discriminator_loss=0.039, generator_loss=3.220
# 1/1 [==============================] - 0s 16ms/step
# epoch 1581 - batch 1/5, discriminator_loss=0.051, generator_loss=3.938
# 1/1 [==============================] - 0s 17ms/step
# epoch 1581 - batch 2/5, discriminator_loss=0.019, generator_loss=1.429
# 1/1 [==============================] - 0s 15ms/step
# epoch 1581 - batch 3/5, discriminator_loss=0.261, generator_loss=0.368
# 1/1 [==============================] - 0s 16ms/step
# epoch 1581 - batch 4/5, discriminator_loss=0.108, generator_loss=0.519
# 1/1 [==============================] - 0s 18ms/step
# epoch 1581 - batch 5/5, discriminator_loss=0.265, generator_loss=2.199
# 4/4 [==============================] - 0s 59ms/step
# Accuracy réelle : 92%, fausse : 94%
# 1/1 [==============================] - 0s 16ms/step
# epoch 1582 - batch 1/5, discriminator_loss=0.102, generator_loss=2.455
# 1/1 [==============================] - 0s 23ms/step
# epoch 1582 - batch 2/5, discriminator_loss=0.439, generator_loss=0.177
# 1/1 [==============================] - 0s 17ms/step
# epoch 1582 - batch 3/5, discriminator_loss=0.599, generator_loss=5.071
# 1/1 [==============================] - 0s 16ms/step
# epoch 1582 - batch 4/5, discriminator_loss=0.219, generator_loss=3.387
# 1/1 [==============================] - 0s 16ms/step
# epoch 1582 - batch 5/5, discriminator_loss=0.097, generator_loss=0.574
# 1/1 [==============================] - 0s 21ms/step
# ...
# 1/1 [==============================] - 0s 16ms/step
# epoch 1975 - batch 2/5, discriminator_loss=0.250, generator_loss=0.315
# 1/1 [==============================] - 0s 16ms/step
# epoch 1975 - batch 3/5, discriminator_loss=0.215, generator_loss=0.192
# 1/1 [==============================] - 0s 14ms/step
# epoch 1975 - batch 4/5, discriminator_loss=0.206, generator_loss=1.358
# 1/1 [==============================] - 0s 20ms/step
# epoch 1975 - batch 5/5, discriminator_loss=0.079, generator_loss=1.975
# 1/1 [==============================] - 0s 15ms/step
# epoch 1976 - batch 1/5, discriminator_loss=0.358, generator_loss=0.452
# 1/1 [==============================] - 0s 16ms/step
# epoch 1976 - batch 2/5, discriminator_loss=0.203, generator_loss=0.967
# 1/1 [==============================] - 0s 18ms/step
# epoch 1976 - batch 3/5, discriminator_loss=0.177, generator_loss=1.059
# 1/1 [==============================] - 0s 15ms/step
# epoch 1976 - batch 4/5, discriminator_loss=0.319, generator_loss=0.441
# 1/1 [==============================] - 0s 17ms/step
# epoch 1976 - batch 5/5, discriminator_loss=0.076, generator_loss=0.613
# 1/1 [==============================] - 0s 15ms/step
# epoch 1977 - batch 1/5, discriminator_loss=0.108, generator_loss=1.130
# 1/1 [==============================] - 0s 15ms/step
# epoch 1977 - batch 2/5, discriminator_loss=0.130, generator_loss=0.495
# 1/1 [==============================] - 0s 14ms/step
# epoch 1977 - batch 3/5, discriminator_loss=0.262, generator_loss=0.149
# 1/1 [==============================] - 0s 19ms/step
# epoch 1977 - batch 4/5, discriminator_loss=0.203, generator_loss=0.205
# 1/1 [==============================] - 0s 17ms/step
# epoch 1977 - batch 5/5, discriminator_loss=0.167, generator_loss=0.182
# 1/1 [==============================] - 0s 18ms/step
# epoch 1978 - batch 1/5, discriminator_loss=0.101, generator_loss=0.253
# 1/1 [==============================] - 0s 15ms/step
# epoch 1978 - batch 2/5, discriminator_loss=0.280, generator_loss=0.394
# 1/1 [==============================] - 0s 17ms/step
# epoch 1978 - batch 3/5, discriminator_loss=0.182, generator_loss=0.128
# 1/1 [==============================] - 0s 14ms/step
# epoch 1978 - batch 4/5, discriminator_loss=0.103, generator_loss=0.056
# 1/1 [==============================] - 0s 16ms/step
# epoch 1978 - batch 5/5, discriminator_loss=0.297, generator_loss=0.476
# 1/1 [==============================] - 0s 15ms/step
# epoch 1979 - batch 1/5, discriminator_loss=0.425, generator_loss=0.766
# 1/1 [==============================] - 0s 18ms/step
# epoch 1979 - batch 2/5, discriminator_loss=0.162, generator_loss=0.236
# 1/1 [==============================] - 0s 15ms/step
# epoch 1979 - batch 3/5, discriminator_loss=0.125, generator_loss=0.354
# 1/1 [==============================] - 0s 16ms/step
# epoch 1979 - batch 4/5, discriminator_loss=0.191, generator_loss=0.176
# 1/1 [==============================] - 0s 15ms/step
# epoch 1979 - batch 5/5, discriminator_loss=0.161, generator_loss=0.374
# 1/1 [==============================] - 0s 15ms/step
# epoch 1980 - batch 1/5, discriminator_loss=0.149, generator_loss=0.384
# 1/1 [==============================] - 0s 15ms/step
# epoch 1980 - batch 2/5, discriminator_loss=0.299, generator_loss=2.071
# 1/1 [==============================] - 0s 19ms/step
# epoch 1980 - batch 3/5, discriminator_loss=0.307, generator_loss=0.754
# 1/1 [==============================] - 0s 18ms/step
# epoch 1980 - batch 4/5, discriminator_loss=0.099, generator_loss=0.314
# 1/1 [==============================] - 0s 17ms/step
# epoch 1980 - batch 5/5, discriminator_loss=0.209, generator_loss=0.659
# 1/1 [==============================] - 0s 18ms/step
# epoch 1981 - batch 1/5, discriminator_loss=0.247, generator_loss=1.758
# 1/1 [==============================] - 0s 17ms/step
# epoch 1981 - batch 2/5, discriminator_loss=0.224, generator_loss=0.645
# 1/1 [==============================] - 0s 16ms/step
# epoch 1981 - batch 3/5, discriminator_loss=0.055, generator_loss=0.341
# 1/1 [==============================] - 0s 15ms/step
# epoch 1981 - batch 4/5, discriminator_loss=0.200, generator_loss=1.100
# 1/1 [==============================] - 0s 15ms/step
# epoch 1981 - batch 5/5, discriminator_loss=0.104, generator_loss=1.096
# 4/4 [==============================] - 0s 60ms/step
# Accuracy réelle : 74%, fausse : 100%
# 1/1 [==============================] - 0s 24ms/step
# epoch 1982 - batch 1/5, discriminator_loss=0.238, generator_loss=0.280
# 1/1 [==============================] - 0s 15ms/step
# epoch 1982 - batch 2/5, discriminator_loss=0.204, generator_loss=0.882
# 1/1 [==============================] - 0s 16ms/step
# epoch 1982 - batch 3/5, discriminator_loss=0.191, generator_loss=1.009
# 1/1 [==============================] - 0s 18ms/step
# epoch 1982 - batch 4/5, discriminator_loss=0.138, generator_loss=0.495
# 1/1 [==============================] - 0s 16ms/step
# epoch 1982 - batch 5/5, discriminator_loss=0.235, generator_loss=0.689
# 1/1 [==============================] - 0s 18ms/step
# epoch 1983 - batch 1/5, discriminator_loss=0.113, generator_loss=0.274
# 1/1 [==============================] - 0s 17ms/step
# epoch 1983 - batch 2/5, discriminator_loss=0.229, generator_loss=0.150
# 1/1 [==============================] - 0s 18ms/step
# epoch 1983 - batch 3/5, discriminator_loss=0.227, generator_loss=0.175
# 1/1 [==============================] - 0s 16ms/step
# epoch 1983 - batch 4/5, discriminator_loss=0.290, generator_loss=0.094
# 1/1 [==============================] - 0s 20ms/step
# epoch 1983 - batch 5/5, discriminator_loss=0.234, generator_loss=0.560
# 1/1 [==============================] - 0s 15ms/step
# epoch 1984 - batch 1/5, discriminator_loss=0.079, generator_loss=0.820
# 1/1 [==============================] - 0s 15ms/step
# epoch 1984 - batch 2/5, discriminator_loss=0.073, generator_loss=0.788
# 1/1 [==============================] - 0s 17ms/step
# epoch 1984 - batch 3/5, discriminator_loss=0.361, generator_loss=0.189
# 1/1 [==============================] - 0s 14ms/step
# epoch 1984 - batch 4/5, discriminator_loss=0.181, generator_loss=1.712
# 1/1 [==============================] - 0s 18ms/step
# epoch 1984 - batch 5/5, discriminator_loss=0.151, generator_loss=1.982
# 1/1 [==============================] - 0s 21ms/step
# epoch 1985 - batch 1/5, discriminator_loss=0.145, generator_loss=2.918
# 1/1 [==============================] - 0s 17ms/step
# epoch 1985 - batch 2/5, discriminator_loss=0.159, generator_loss=1.851
# 1/1 [==============================] - 0s 19ms/step
# epoch 1985 - batch 3/5, discriminator_loss=0.227, generator_loss=0.372
# 1/1 [==============================] - 0s 15ms/step
# epoch 1985 - batch 4/5, discriminator_loss=0.560, generator_loss=3.290
# 1/1 [==============================] - 0s 15ms/step
# epoch 1985 - batch 5/5, discriminator_loss=0.234, generator_loss=2.413
# 1/1 [==============================] - 0s 15ms/step
# epoch 1986 - batch 1/5, discriminator_loss=0.403, generator_loss=0.477
# 1/1 [==============================] - 0s 15ms/step
# epoch 1986 - batch 2/5, discriminator_loss=0.256, generator_loss=2.202
# 1/1 [==============================] - 0s 19ms/step
# epoch 1986 - batch 3/5, discriminator_loss=0.205, generator_loss=2.067
# 1/1 [==============================] - 0s 15ms/step
# epoch 1986 - batch 4/5, discriminator_loss=0.280, generator_loss=0.871
# 1/1 [==============================] - 0s 14ms/step
# epoch 1986 - batch 5/5, discriminator_loss=0.179, generator_loss=1.980
# 1/1 [==============================] - 0s 15ms/step
# epoch 1987 - batch 1/5, discriminator_loss=0.179, generator_loss=3.506
# 1/1 [==============================] - 0s 18ms/step
# epoch 1987 - batch 2/5, discriminator_loss=0.189, generator_loss=2.647
# 1/1 [==============================] - 0s 15ms/step
# epoch 1987 - batch 3/5, discriminator_loss=0.280, generator_loss=2.306
# 1/1 [==============================] - 0s 15ms/step
# epoch 1987 - batch 4/5, discriminator_loss=0.186, generator_loss=5.704
# 1/1 [==============================] - 0s 16ms/step
# epoch 1987 - batch 5/5, discriminator_loss=0.214, generator_loss=3.734
# 1/1 [==============================] - 0s 17ms/step
# epoch 1988 - batch 1/5, discriminator_loss=0.032, generator_loss=2.385
# 1/1 [==============================] - 0s 15ms/step
# epoch 1988 - batch 2/5, discriminator_loss=0.221, generator_loss=1.990
# 1/1 [==============================] - 0s 15ms/step
# epoch 1988 - batch 3/5, discriminator_loss=0.126, generator_loss=3.111
# 1/1 [==============================] - 0s 15ms/step
# epoch 1988 - batch 4/5, discriminator_loss=0.298, generator_loss=0.950
# 1/1 [==============================] - 0s 15ms/step
# epoch 1988 - batch 5/5, discriminator_loss=0.605, generator_loss=1.440
# 1/1 [==============================] - 0s 18ms/step
# epoch 1989 - batch 1/5, discriminator_loss=0.341, generator_loss=1.297
# 1/1 [==============================] - 0s 16ms/step
# epoch 1989 - batch 2/5, discriminator_loss=0.227, generator_loss=0.441
# 1/1 [==============================] - 0s 14ms/step
# epoch 1989 - batch 3/5, discriminator_loss=0.374, generator_loss=2.186
# 1/1 [==============================] - 0s 17ms/step
# epoch 1989 - batch 4/5, discriminator_loss=0.811, generator_loss=0.130
# 1/1 [==============================] - 0s 15ms/step
# epoch 1989 - batch 5/5, discriminator_loss=0.448, generator_loss=0.686
# 1/1 [==============================] - 0s 15ms/step
# epoch 1990 - batch 1/5, discriminator_loss=0.341, generator_loss=0.356
# 1/1 [==============================] - 0s 19ms/step
# epoch 1990 - batch 2/5, discriminator_loss=0.230, generator_loss=1.146
# 1/1 [==============================] - 0s 14ms/step
# epoch 1990 - batch 3/5, discriminator_loss=0.086, generator_loss=1.437
# 1/1 [==============================] - 0s 15ms/step
# epoch 1990 - batch 4/5, discriminator_loss=0.093, generator_loss=1.326
# 1/1 [==============================] - 0s 23ms/step
# epoch 1990 - batch 5/5, discriminator_loss=0.274, generator_loss=1.009
# 1/1 [==============================] - 0s 15ms/step
# epoch 1991 - batch 1/5, discriminator_loss=0.176, generator_loss=1.270
# 1/1 [==============================] - 0s 15ms/step
# epoch 1991 - batch 2/5, discriminator_loss=0.407, generator_loss=0.365
# 1/1 [==============================] - 0s 15ms/step
# epoch 1991 - batch 3/5, discriminator_loss=0.311, generator_loss=0.446
# 1/1 [==============================] - 0s 14ms/step
# epoch 1991 - batch 4/5, discriminator_loss=0.269, generator_loss=1.628
# 1/1 [==============================] - 0s 17ms/step
# epoch 1991 - batch 5/5, discriminator_loss=0.136, generator_loss=1.340
# 1/1 [==============================] - 0s 16ms/step
# epoch 1992 - batch 1/5, discriminator_loss=0.235, generator_loss=0.677
# 1/1 [==============================] - 0s 15ms/step
# epoch 1992 - batch 2/5, discriminator_loss=0.364, generator_loss=0.081
# 1/1 [==============================] - 0s 15ms/step
# epoch 1992 - batch 3/5, discriminator_loss=0.552, generator_loss=0.604
# 1/1 [==============================] - 0s 16ms/step
# epoch 1992 - batch 4/5, discriminator_loss=0.179, generator_loss=0.708
# 1/1 [==============================] - 0s 28ms/step
# epoch 1992 - batch 5/5, discriminator_loss=0.333, generator_loss=0.458
# 1/1 [==============================] - 0s 17ms/step
# epoch 1993 - batch 1/5, discriminator_loss=0.276, generator_loss=0.245
# 1/1 [==============================] - 0s 15ms/step
# epoch 1993 - batch 2/5, discriminator_loss=0.113, generator_loss=0.421
# 1/1 [==============================] - 0s 15ms/step
# epoch 1993 - batch 3/5, discriminator_loss=0.073, generator_loss=0.505
# 1/1 [==============================] - 0s 17ms/step
# epoch 1993 - batch 4/5, discriminator_loss=0.148, generator_loss=0.655
# 1/1 [==============================] - 0s 17ms/step
# epoch 1993 - batch 5/5, discriminator_loss=0.255, generator_loss=0.483
# 1/1 [==============================] - 0s 15ms/step
# epoch 1994 - batch 1/5, discriminator_loss=0.224, generator_loss=0.230
# 1/1 [==============================] - 0s 15ms/step
# epoch 1994 - batch 2/5, discriminator_loss=0.157, generator_loss=0.067
# 1/1 [==============================] - 0s 15ms/step
# epoch 1994 - batch 3/5, discriminator_loss=0.124, generator_loss=0.177
# 1/1 [==============================] - 0s 17ms/step
# epoch 1994 - batch 4/5, discriminator_loss=0.129, generator_loss=0.113
# 1/1 [==============================] - 0s 20ms/step
# epoch 1994 - batch 5/5, discriminator_loss=0.254, generator_loss=0.027
# 1/1 [==============================] - 0s 14ms/step
# epoch 1995 - batch 1/5, discriminator_loss=0.141, generator_loss=0.131
# 1/1 [==============================] - 0s 15ms/step
# epoch 1995 - batch 2/5, discriminator_loss=0.147, generator_loss=0.174
# 1/1 [==============================] - 0s 16ms/step
# epoch 1995 - batch 3/5, discriminator_loss=0.332, generator_loss=0.117
# 1/1 [==============================] - 0s 16ms/step
# epoch 1995 - batch 4/5, discriminator_loss=0.061, generator_loss=0.078
# 1/1 [==============================] - 0s 16ms/step
# epoch 1995 - batch 5/5, discriminator_loss=0.207, generator_loss=0.064
# 1/1 [==============================] - 0s 15ms/step
# epoch 1996 - batch 1/5, discriminator_loss=0.132, generator_loss=0.146
# 1/1 [==============================] - 0s 17ms/step
# epoch 1996 - batch 2/5, discriminator_loss=0.044, generator_loss=0.037
# 1/1 [==============================] - 0s 16ms/step
# epoch 1996 - batch 3/5, discriminator_loss=0.084, generator_loss=0.149
# 1/1 [==============================] - 0s 24ms/step
# epoch 1996 - batch 4/5, discriminator_loss=0.260, generator_loss=0.072
# 1/1 [==============================] - 0s 17ms/step
# epoch 1996 - batch 5/5, discriminator_loss=0.126, generator_loss=0.164
# 1/1 [==============================] - 0s 15ms/step
# epoch 1997 - batch 1/5, discriminator_loss=0.233, generator_loss=0.123
# 1/1 [==============================] - 0s 16ms/step
# epoch 1997 - batch 2/5, discriminator_loss=0.076, generator_loss=0.362
# 1/1 [==============================] - 0s 16ms/step
# epoch 1997 - batch 3/5, discriminator_loss=0.246, generator_loss=0.341
# 1/1 [==============================] - 0s 15ms/step
# epoch 1997 - batch 4/5, discriminator_loss=0.175, generator_loss=0.422
# 1/1 [==============================] - 0s 22ms/step
# epoch 1997 - batch 5/5, discriminator_loss=0.141, generator_loss=0.147
# 1/1 [==============================] - 0s 16ms/step
# epoch 1998 - batch 1/5, discriminator_loss=0.292, generator_loss=0.032
# 1/1 [==============================] - 0s 22ms/step
# epoch 1998 - batch 2/5, discriminator_loss=0.074, generator_loss=0.135
# 1/1 [==============================] - 0s 14ms/step
# epoch 1998 - batch 3/5, discriminator_loss=0.121, generator_loss=0.073
# 1/1 [==============================] - 0s 15ms/step
# epoch 1998 - batch 4/5, discriminator_loss=0.102, generator_loss=0.103
# 1/1 [==============================] - 0s 17ms/step
# epoch 1998 - batch 5/5, discriminator_loss=0.164, generator_loss=0.052
# 1/1 [==============================] - 0s 14ms/step
# epoch 1999 - batch 1/5, discriminator_loss=0.171, generator_loss=0.065
# 1/1 [==============================] - 0s 14ms/step
# epoch 1999 - batch 2/5, discriminator_loss=0.118, generator_loss=0.196
# 1/1 [==============================] - 0s 16ms/step
# epoch 1999 - batch 3/5, discriminator_loss=0.068, generator_loss=0.163
# 1/1 [==============================] - 0s 15ms/step
# epoch 1999 - batch 4/5, discriminator_loss=0.220, generator_loss=0.047
# 1/1 [==============================] - 0s 16ms/step
# epoch 1999 - batch 5/5, discriminator_loss=0.228, generator_loss=0.313
# 1/1 [==============================] - 0s 16ms/step
# epoch 2000 - batch 1/5, discriminator_loss=0.127, generator_loss=0.337
# 1/1 [==============================] - 0s 17ms/step
# epoch 2000 - batch 2/5, discriminator_loss=0.153, generator_loss=0.162
# 1/1 [==============================] - 0s 15ms/step
# epoch 2000 - batch 3/5, discriminator_loss=0.078, generator_loss=0.089
# 1/1 [==============================] - 0s 16ms/step
# epoch 2000 - batch 4/5, discriminator_loss=0.089, generator_loss=0.178
# 1/1 [==============================] - 0s 19ms/step
# epoch 2000 - batch 5/5, discriminator_loss=0.047, generator_loss=0.021

# %%
# Création d'un vecteur aléatoire de taille latent_dim
latent_points = generate_latent_points(100, 1)

# %%
generated_image = gan_model.predict(latent_points)
# Out:
# 1/1 [==============================] - 0s 119ms/step

# %%
plt.imshow (generated_image[0, :, :, 0])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-127-ec62c2892d9e> in <module>
# ----> 1 plt.imshow (generated_image[0, :, :, 0])
#
# IndexError: too many indices for array: array is 2-dimensional, but 4 were indexed
