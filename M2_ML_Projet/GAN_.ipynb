# %% [markdown]
# #GAN

# %% [markdown]
# # 0-Installation des libraire et mise en palce de google drive

# %%
# !pip install pyyaml h5py #pour sauvegarder le modèle
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.8/dist-packages (6.0)
# Requirement already satisfied: h5py in /usr/local/lib/python3.8/dist-packages (3.1.0)
# Requirement already satisfied: numpy>=1.17.5 in /usr/local/lib/python3.8/dist-packages (from h5py) (1.21.6)

# %%
# Importation des différentes librairies utiles pour le notebook
#Pour ignorer les warning.
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

# librairies générales
import pickle 
import pandas as pd
import numpy as np
import string
import time
import base64
import re
import sys
import copy
import random
from numpy import mean
from numpy import std
from numpy.random import randint


# librairie affichage
import matplotlib.pyplot as plt
from matplotlib import pyplot
import seaborn as sns
import plotly.graph_objs as go
import plotly.offline as py
from PIL import Image

#Sklearn
from sklearn.metrics import confusion_matrix
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import StratifiedKFold, train_test_split
from sklearn.pipeline import Pipeline
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score

# TensorFlow et keras
import keras
import tensorflow as tf
from keras import layers
from keras import models
from keras import optimizers
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import to_categorical,img_to_array, load_img #from keras.preprocessing.image import img_to_array, load_img
from tensorflow.keras.optimizers import SGD,Adam
from tensorflow.keras.applications.resnet50 import ResNet50
from keras.callbacks import ModelCheckpoint, EarlyStopping
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import BatchNormalization
from keras.preprocessing import image
from keras.applications.vgg16 import VGG16
from tqdm import tqdm
from keras.models import load_model
from keras.models import Model
from sklearn.model_selection import KFold
from keras.layers import Dense
import os  #pour accéder aux fonctionnalité systèmes
import sys 
from os import listdir
from os.path import isfile, join
import cv2  # Library to solve computer vision problems
import glob  # = global is used to return all file paths that match a specific patter


from numpy import expand_dims
from numpy import zeros
from numpy import ones
from numpy import vstack
from keras.layers import Reshape
from keras.layers import Conv2DTranspose
from keras.layers import LeakyReLU
from keras.layers import Dropout
from tensorflow.keras.layers import Dense, BatchNormalization
from keras.models import load_model

# %%
# pour monter son Google Drive local
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
my_local_drive='/content/gdrive/My Drive/Colab Notebooks/M2_ML_Projet'
# Ajout du path pour les librairies, fonctions et données
sys.path.append(my_local_drive)
# Se positionner sur le répertoire associé
# %cd $my_local_drive

# %pwd
# Out:
# /content/gdrive/.shortcut-targets-by-id/1o7cpJ8SqW-o3QyTUWwS98x2lkk-rKluW/M2_ML_Projet
# '/content/gdrive/.shortcut-targets-by-id/1o7cpJ8SqW-o3QyTUWwS98x2lkk-rKluW/M2_ML_Projet'

# %% [markdown]
# ## Récupération des jeux de données

# %%
#pour télécharger le zip file 
# !wget https://www.lirmm.fr/~poncelet/Ressources/Tiger-Fox-Elephant.zip
# Out:
# --2022-12-06 21:22:50--  https://www.lirmm.fr/~poncelet/Ressources/Tiger-Fox-Elephant.zip
# Resolving www.lirmm.fr (www.lirmm.fr)... 193.49.104.251
# Connecting to www.lirmm.fr (www.lirmm.fr)|193.49.104.251|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 7605545 (7.3M) [application/zip]
# Saving to: ‘Tiger-Fox-Elephant.zip.1’
#
# Tiger-Fox-Elephant. 100%[===================>]   7.25M  7.50MB/s    in 1.0s
#
# 2022-12-06 21:22:52 (7.50 MB/s) - ‘Tiger-Fox-Elephant.zip.1’ saved [7605545/7605545]

# %%
import zipfile
with zipfile.ZipFile("Tiger-Fox-Elephant.zip","r") as zip_ref:
    zip_ref.extractall("Data_Project")

# %% [markdown]
# ##Fonctions Utils

# %% [markdown]
# ##Générateur

# %%
def create_generator(latent_dim=100):
  model = Sequential()
	# 1/4 de l'image (7x7) * nombre d'images possibles
  n_nodes = 256 * 31 * 31
  model.add(Dense(n_nodes, input_dim=latent_dim))
  model.add(LeakyReLU(alpha=0.2))
  model.add(Reshape((31, 31, 256)))
  # upsample to 14x14
  model.add(Conv2DTranspose(128, (3,3), strides=(2,2), padding='same'))		
  model.add(LeakyReLU(alpha=0.2))
  # upsample to 28x28
  model.add(Conv2DTranspose(128, (3,3), strides=(2,2), padding='same'))
  model.add(LeakyReLU(alpha=0.2))
  model.add(Conv2D(3, (3,3), activation='tanh', padding='same'))
  opt = Adam(learning_rate=0.0002, beta_1=0.5)
  model.compile(loss='binary_crossentropy', optimizer=opt, metrics=['accuracy'])
  return model

# %%
generator_model = create_generator()
generator_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 246016)            24847616
#
#  leaky_re_lu (LeakyReLU)     (None, 246016)            0
#
#  reshape (Reshape)           (None, 31, 31, 256)       0
#
#  conv2d_transpose (Conv2DTra  (None, 62, 62, 128)      295040
#  nspose)
#
#  leaky_re_lu_1 (LeakyReLU)   (None, 62, 62, 128)       0
#
#  conv2d_transpose_1 (Conv2DT  (None, 124, 124, 128)    147584
#  ranspose)
#
#  leaky_re_lu_2 (LeakyReLU)   (None, 124, 124, 128)     0
#
#  conv2d (Conv2D)             (None, 124, 124, 3)       3459
#
# =================================================================
# Total params: 25,293,699
# Trainable params: 25,293,699
# Non-trainable params: 0
# _________________________________________________________________

# %%
latent_dim=100
noise = tf.random.normal([1,latent_dim]) # (1,100)
generated_image = generator_model (noise, training=False) ##On passe le vecteur(image) à la générateur
plt.imshow(generated_image[0, :, :, 0])

# %% [markdown]
# ##Discriminateur

# %%
def create_discriminator():
  model = Sequential()
  model.add(Conv2D(64, (3,3), strides=(2, 2), padding='same', input_shape=[124,124,3]))
  model.add(LeakyReLU(alpha=0.2))
  model.add(Conv2D(128, (3,3), strides=(2, 2), padding='same'))
  model.add(LeakyReLU(alpha=0.2))
  model.add(Conv2D(128, (3,3), strides=(2,2), padding='same'))
  model.add(LeakyReLU(alpha=0.2))
  model.add(Conv2D(128, (3,3), strides=(2,2), padding='same'))
  model.add(LeakyReLU(alpha=0.2))
  model.add(Flatten())
  model.add(Dropout(0.4))
  model.add(Dense(1, activation='sigmoid'))
  opt = Adam(learning_rate=0.0002, beta_1=0.5)
  model.compile(loss='binary_crossentropy', optimizer=opt, metrics=['accuracy'])
  return model

# %%
model_discriminator=create_discriminator()
model_discriminator.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_1 (Conv2D)           (None, 62, 62, 64)        1792
#
#  leaky_re_lu_3 (LeakyReLU)   (None, 62, 62, 64)        0
#
#  conv2d_2 (Conv2D)           (None, 31, 31, 128)       73856
#
#  leaky_re_lu_4 (LeakyReLU)   (None, 31, 31, 128)       0
#
#  conv2d_3 (Conv2D)           (None, 16, 16, 128)       147584
#
#  leaky_re_lu_5 (LeakyReLU)   (None, 16, 16, 128)       0
#
#  conv2d_4 (Conv2D)           (None, 8, 8, 128)         147584
#
#  leaky_re_lu_6 (LeakyReLU)   (None, 8, 8, 128)         0
#
#  flatten (Flatten)           (None, 8192)              0
#
#  dropout (Dropout)           (None, 8192)              0
#
#  dense_1 (Dense)             (None, 1)                 8193
#
# =================================================================
# Total params: 379,009
# Trainable params: 379,009
# Non-trainable params: 0
# _________________________________________________________________

# %%
discriminator_model = create_discriminator()
prediction = discriminator_model(generated_image)
print(prediction)
# Out:
# tf.Tensor([[0.49993297]], shape=(1, 1), dtype=float32)

# %%
 IMG_SIZE=124
 COLUMNS = 16
 """
 Téléchargement de jeux d'entrainement 
 @Param path_data: le chemin vers notre répertoire de données 
 @Param list_classes: la liste de nom de classe volue
 @Return training_data
 """
 
 def create_training_data(path_data, list_classes):  
  training_data=[]   #Tableau de retour 
  for classes in list_classes: # tiger et tiger_negative
      path = os.path.join(path_data, classes)
      class_num = list_classes.index(classes)
      for img in os.listdir(path):
        try:
          img_array = cv2.imread(os.path.join(path,img), cv2.IMREAD_UNCHANGED)
          new_array = cv2.resize(img_array, (IMG_SIZE, IMG_SIZE))  
          training_data.append([new_array, class_num])  # on remplit notre tableau 
        except Exception as e:
          pass  
  return training_data   

 """
 Creation de jeux d'entrainement 
 @Param path_data: le chemin vers notre répertoire de données 
 @Param list_classes: la liste de nom de classe volue
 @Return X,y
 """ 
 def create_X_y (path_data, list_classes):
      # récupération des données
      training_data = create_training_data(path_data, list_classes)
      # tri des données
      random.shuffle(training_data)
      # création de X et y
      X=[]
      y=[]
      for features, label in training_data:
        X.append(features)
        y.append(label)
      X=np.array(X).reshape(-1,IMG_SIZE, IMG_SIZE, 3)  #-1 The new shape should be compatible with the original shape.  
      y=np.array(y)
      return X,y 

 """
 Nettoyage de données : conversion en foat et normalisation 
 @Param xtrain 
 @Param xtest
 @Return xtrain_norm, xtest_norm
 """ 
 def clean_data(x): 
    # convertion d'entier en float
    xtrain_norm = x.astype('float32')
    # normalisation entre 0 et 1
    xtrain_norm = xtrain_norm / 255.0
    return xtrain_norm 

 """
 Affichage de données : 
 @Param X 
 @Param y
 """ 
 def plot_examples(X,y):
  plt.figure(figsize=(25,25))
  for i in range(10):
    plt.subplot(4,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    # cv2 lit, met les images en BGR et matplotlib lit du RGB
    #X[i] = cv2.cvtColor(X[i], cv2.COLOR_BGR2RGB)
    X[i]=X[i].astype('float32')
    plt.imshow(X[i],cmap=plt.cm.binary)  
    plt.xlabel('classe ' + str(y[i]))

# %%
# Création d'un faux jeu de données 
# elles seront labélisées avec 0

def generate_fake_samples(nb_images):
  # generation de nombres aléatoires entre 0 et 1
  # attention ici on simplifie en mettant la taille de l'image
  # normalement il faut prendre latent_dim
  X = np.random.rand(3* 124 * 124 * nb_images)
  # reshape en images grises
  X = X.reshape((nb_images, 124, 124, 3))
  # mettre 0 comme label de classe
  y = zeros((nb_images, 1))
  return X, y

# %%
##Ici on génére 10 images 
X_f,y_f= generate_fake_samples(10)

# %%
print(X_f.shape)
print(y_f.shape)
# Out:
# (10, 124, 124, 3)
# (10, 1)

# %%
plot_examples(X_f, y_f)

# %%
# Creation d'un jeu de données de vraies images
# les vraies images sont labélisées avec 1
def generate_real_samples(dataset, nb_images):  ##pour nous 100 max
	# tirage aléatoire
	ix = randint(0, dataset.shape[0], nb_images)
	# sélection des images
	X = dataset[ix]
	# mettre 1 comme label de classe
	y = ones((nb_images, 1))
	return X, y

# %%
my_path = "Data_Project/Tiger-Fox-Elephant/"
my_classes = ['fox']
X, y = create_X_y(my_path, my_classes) 
X = X.astype('float32')/255.0

# %%
 # Normalize the images to [-1, 1]
X.shape
# Out:
# (100, 124, 124, 3)

# %%
X_r,y_r = generate_real_samples(X, 10)

# %%
print(X_r.shape)
print(y_r.shape)
# Out:
# (10, 124, 124, 3)
# (10, 1)

# %%
plot_examples(X_r, y_r)

# %%
# train the discriminator model
def train_discriminator(model, dataset, epochs=100, batchsize=20):
  # on constitue un jeu de données de batchsize/2 images réelles et images fausses
  half_batch = int(batchsize / 2)
  # boucler sur les epochs
  for i in range(epochs):
    # sélection d'images réelles
    X_real, y_real = generate_real_samples(dataset, half_batch) # (X, nb_image) ==>  images de tigre réel
    # mettre à jour le discriminateur avec les images réelles
    _, real_acc = model.train_on_batch(X_real, y_real)  ## il s'entraine sur les réel 

		# generation de fausses images 
    X_fake, y_fake = generate_fake_samples(half_batch) #(nb_images) ==>
		# mise à jour du discriminateur avec de fausses images 
    _, fake_acc = model.train_on_batch(X_fake, y_fake) 

		# Affichage des résultats pour l'accuracy des vraies et des fausses
    print('>%d accuracy_real=%.0f%% accuracy_fake=%.0f%%' % (i+1, real_acc*100, fake_acc*100))

# %%
X.shape
# Out:
# (99, 124, 124, 3)

# %%
##a modifier
epochs= 50
# lancement de l'entrainement du discriminateur
train_discriminator(discriminator_model, X, epochs)
# Out:
# >1 accuracy_real=20% accuracy_fake=10%
# >2 accuracy_real=80% accuracy_fake=0%
# >3 accuracy_real=80% accuracy_fake=30%
# >4 accuracy_real=50% accuracy_fake=70%
# >5 accuracy_real=40% accuracy_fake=100%
# >6 accuracy_real=40% accuracy_fake=100%
# >7 accuracy_real=50% accuracy_fake=100%
# >8 accuracy_real=0% accuracy_fake=100%
# >9 accuracy_real=20% accuracy_fake=100%
# >10 accuracy_real=0% accuracy_fake=100%
# >11 accuracy_real=20% accuracy_fake=100%
# >12 accuracy_real=0% accuracy_fake=100%
# >13 accuracy_real=0% accuracy_fake=100%
# >14 accuracy_real=0% accuracy_fake=100%
# >15 accuracy_real=20% accuracy_fake=100%
# >16 accuracy_real=0% accuracy_fake=100%
# >17 accuracy_real=0% accuracy_fake=100%
# >18 accuracy_real=10% accuracy_fake=100%
# >19 accuracy_real=0% accuracy_fake=100%
# >20 accuracy_real=40% accuracy_fake=100%
# >21 accuracy_real=70% accuracy_fake=100%
# >22 accuracy_real=60% accuracy_fake=100%
# >23 accuracy_real=100% accuracy_fake=100%
# >24 accuracy_real=80% accuracy_fake=100%
# >25 accuracy_real=100% accuracy_fake=100%
# >26 accuracy_real=100% accuracy_fake=100%
# >27 accuracy_real=100% accuracy_fake=100%
# >28 accuracy_real=100% accuracy_fake=100%
# >29 accuracy_real=100% accuracy_fake=100%
# >30 accuracy_real=100% accuracy_fake=100%
# >31 accuracy_real=100% accuracy_fake=100%
# >32 accuracy_real=100% accuracy_fake=100%
# >33 accuracy_real=100% accuracy_fake=100%
# >34 accuracy_real=100% accuracy_fake=100%
# >35 accuracy_real=100% accuracy_fake=100%
# >36 accuracy_real=100% accuracy_fake=100%
# >37 accuracy_real=100% accuracy_fake=100%
# >38 accuracy_real=100% accuracy_fake=100%
# >39 accuracy_real=100% accuracy_fake=100%
# >40 accuracy_real=100% accuracy_fake=100%
# >41 accuracy_real=100% accuracy_fake=100%
# >42 accuracy_real=100% accuracy_fake=100%
# >43 accuracy_real=100% accuracy_fake=100%
# >44 accuracy_real=100% accuracy_fake=100%
# >45 accuracy_real=100% accuracy_fake=100%
# >46 accuracy_real=100% accuracy_fake=100%
# >47 accuracy_real=100% accuracy_fake=100%
# >48 accuracy_real=100% accuracy_fake=100%
# >49 accuracy_real=100% accuracy_fake=100%
# >50 accuracy_real=100% accuracy_fake=100%

# %% [markdown]
# Construire notre GAN

# %%
def create_gan(generator_model, discriminator_model):
  # mettre les poids du discriminateur non entrable
  discriminator_model.trainable = False
  # un seul modele qui regroupe 
  model = Sequential()
  # ajout du générateur
  model.add(generator_model)
  # ajout du discriminateur
  model.add(discriminator_model)

  opt = Adam(learning_rate=0.0003, beta_1=0.5)
  model.compile(loss='binary_crossentropy', optimizer=opt)
  return model

# %% [markdown]
# # Le modèle GAN final ressemble à ceci :

# %%
#latent_dim = 100

# creation du générateur
#generator_model = create_generator(latent_dim)
# creation du discriminateur
#discriminator_model = create_discriminator()

# creation du gan
gan_model = create_gan(generator_model, discriminator_model)

gan_model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential (Sequential)     (None, 124, 124, 3)       25293699
#
#  sequential_2 (Sequential)   (None, 1)                 379009
#
# =================================================================
# Total params: 25,672,708
# Trainable params: 25,293,699
# Non-trainable params: 379,009
# _________________________________________________________________

# %%
# Généer des données, un vecteur aléatoire 
def generate_latent_points (latent_dim, nb_images): #(100, 100)
  X_input = np.random.randn(latent_dim* nb_images)
  X_input = X_input.reshape(nb_images, latent_dim)
  return X_input

# %%
X_input = generate_latent_points(100,100)

# %%
X_input.shape
# Out:
# (100, 100)

# %%
#il générer des images fausses 
#def generate_fake_samples_for_generator(generator_model, latent_dim, nb_images): #(model , 100, 100)
  # generation des points = vecteur 
 # X_input = generate_latent_points (latent_dim,nb_images)
  # prediction de la sortie du générateur
 # X = generator_model.predict(X_input)
 # X = ((X - 127.5) / 127.5 ).astype(np.uint8)
  # A ce niveau on considère que les images sont fausses
  # donc on met 0 comme label. 
 # y = zeros((nb_images, 1))
 # return X, y

# %%
#il générer des images fausses 
def generate_fake_samples_for_generator(generator_model, latent_dim, nb_images): #(model , 100, 100)
  # generation des points = vecteur 
  X_input = generate_latent_points (latent_dim,nb_images)
  # prediction de la sortie du générateur
  X = generator_model.predict(X_input)
  #X = ((X - 127.5) / 127.5 ).astype(np.uint8)
  # A ce niveau on considère que les images sont fausses
  # donc on met 0 comme label. 
  y = zeros((nb_images, 1))
  return X, y   ###image générer par le générateur 

#Pour sauvgarder et afficher les images générer dont l'objectif est à partir de points latent de prédire le résultat,
def plot_and_save_generatedimages(generated_images, epoch, nb_images=10): #(image générer, 15, 10 )
	# Affichage des images
  generated_images = generated_images/2 + 0.5  # con entre 0 et 1
  plt.figure(figsize=(35,35))
  for i in range(25):
    pyplot.subplot(5, 5, 1 + i)
    pyplot.axis('off')
    pyplot.imshow(cv2.cvtColor(generated_images[i], cv2.COLOR_BGR2RGB))#,cmap=plt.cm.binary)
	# sauvegarde de l'image
  filename = 'generated_plot_FoxCNN_withGan%03d.png' % (epoch+1)
  fileDir = 'GanImages/GanImagesTiger/'
  pyplot.savefig(fileDir+filename)
  pyplot.close()
 


def evaluate_model (dataset, epoch, generator_model, discriminator_model, latent_dim, nb_images=100, save_model=False):
  # récupération de vraies images pour le discriminateur
  X_real, y_real = generate_real_samples(dataset, nb_images)
  # Evaluation de l'accuracy pour le discriminateur
  _, acc_real = discriminator_model.evaluate(X_real, y_real, verbose=0)

  # génération de fausses images pour le générateur et donc le gan
  X_fake, y_fake = generate_fake_samples_for_generator(generator_model, latent_dim, nb_images)
  # Evaluation du discriminateur avec des fausses images
  _, acc_fake = discriminator_model.evaluate(X_fake, y_fake, verbose=0)

  print ('Accuracy réelle : %.0f%%, fausse : %.0f%%' % (acc_real*100, acc_fake*100))
  
  plot_and_save_generatedimages(X_fake, epoch)
  if save_model==True:
    # sauvegarde du generateur pour un autre usage
    filename = 'generator_model_FoxGan%03d.h5' % (epoch + 1)
    generator_model.save(filename)

# %%
# train the generator and discriminator
def train(generator_model, discriminator_model, gan_model, dataset, latent_dim, epochs=10, batchsize=100):
  # Pour déterminer combien il y aura de batchs analysés à chaque epoch
  batches_per_epoch = 50 #100/5 = 20 

  # pour récupérer le même nombre d'images fausses et vraies
  half_batch = 100 #int(batchsize / 2) #20/2 =  10 

  for i in range(epochs): #pour 100 tour
    # parcours des batches pour chaque pas d'epoch
    for j in range(batches_per_epoch): # 20 tour

      #----- PARTIE DISCRIMINATOR----- r
      ##X,y = Real + fake 
      #tirage aléatoire de half_batch images vraies
      X_real, y_real = generate_real_samples(dataset, half_batch)  #( X, 10) il prends 10 images au pif 
      # generation de half_size fausses images
      X_fake, y_fake = generate_fake_samples_for_generator(generator_model, latent_dim, half_batch) #genére 10 images fake 
      # vstack permet de concaténer les vraies et fausses images dans X (resp. dans y)
      # on aurait pu utiliser np.concatenate (np.concatenate([X_real, X_fake]))
      X, y = vstack((X_real, X_fake)), vstack((y_real, y_fake))

      # la ligne suivante permet au discriminateur de mettre à jour ses poids
      # attention dans le GAN il ne peut pas aprendre donc il ne peut le faire qu'ici
      discriminator_loss,_  = discriminator_model.train_on_batch(X, y) ##il s'entraine sur les vrai et les fausses 

      #------- PARTIE GENERATOR -------- ET DONC DE L'ENTREE DU GAN
      # Création des points comme entrée du générateur 
      # 
      X_for_gan = generate_latent_points(latent_dim, batchsize)
      # On met un 1 pour les labels des fausses images pour faire croire au discriminateur
      # qu'il s'agit de vraies images
      y_for_gan = ones((batchsize, 1)) #(10,1)

      # mise à jour des poids du générateur par propagation de l'esseur du discriminateur 
      gan_loss = gan_model.train_on_batch(X_for_gan, y_for_gan)
			# Affichage des loss
      print('epoch %d - batch %d/%d, discriminator_loss=%.3f, generator_loss=%.3f'%(i+1, j+1, batches_per_epoch, discriminator_loss, gan_loss))

    # Toutes les 20 epochs evaluation du modèle et sauvegarde du générateur
    if i==1 or i % 20==0:
        evaluate_model (dataset, i, generator_model, discriminator_model, latent_dim)

# %%
latent_dim = 100
epochs= 5000
batchsize= 20#10
# Creation du discriminateur
discriminator_model = create_discriminator()
# Creation du generateur
generator_model = create_generator(latent_dim)
# Creation du GAN
gan_model = create_gan(generator_model, discriminator_model)
# Chargement des données
my_path = "Data_Project/Tiger-Fox-Elephant/"
my_classes = ['fox']
X, y = create_X_y(my_path, my_classes) 
X = clean_data(X)
dataset = X

# train model
train(generator_model, discriminator_model, gan_model, dataset, latent_dim, epochs,batchsize)
# Out:
# 4/4 [==============================] - 6s 1s/step
# epoch 1 - batch 1/50, discriminator_loss=0.711, generator_loss=0.693
# 4/4 [==============================] - 6s 1s/step
# epoch 1 - batch 2/50, discriminator_loss=0.675, generator_loss=0.692
# 4/4 [==============================] - 6s 1s/step
# epoch 1 - batch 3/50, discriminator_loss=0.642, generator_loss=0.689
# 4/4 [==============================] - 6s 1s/step
# epoch 1 - batch 4/50, discriminator_loss=0.608, generator_loss=0.683
# 4/4 [==============================] - 7s 1s/step
# epoch 1 - batch 5/50, discriminator_loss=0.570, generator_loss=0.669
# 4/4 [==============================] - 6s 1s/step
# epoch 1 - batch 6/50, discriminator_loss=0.530, generator_loss=0.644
# 4/4 [==============================] - 6s 1s/step
# epoch 1 - batch 7/50, discriminator_loss=0.502, generator_loss=0.601
# 4/4 [==============================] - 6s 1s/step
# epoch 1 - batch 8/50, discriminator_loss=0.509, generator_loss=0.536
# 4/4 [==============================] - 6s 1s/step
# epoch 1 - batch 9/50, discriminator_loss=0.543, generator_loss=0.502
# 4/4 [==============================] - 6s 1s/step
# epoch 1 - batch 10/50, discriminator_loss=0.592, generator_loss=0.483
# 4/4 [==============================] - 6s 1s/step
# epoch 1 - batch 11/50, discriminator_loss=0.612, generator_loss=0.503
# 4/4 [==============================] - 7s 2s/step
# epoch 1 - batch 12/50, discriminator_loss=0.632, generator_loss=0.543
# 4/4 [==============================] - 6s 1s/step
# epoch 1 - batch 13/50, discriminator_loss=0.631, generator_loss=0.576
# 4/4 [==============================] - 6s 1s/step
# epoch 1 - batch 14/50, discriminator_loss=0.620, generator_loss=0.628
# 4/4 [==============================] - 6s 1s/step
# epoch 1 - batch 15/50, discriminator_loss=0.664, generator_loss=0.668
# 4/4 [==============================] - 6s 1s/step
# epoch 1 - batch 16/50, discriminator_loss=0.694, generator_loss=0.699
# 4/4 [==============================] - 8s 2s/step
# epoch 1 - batch 17/50, discriminator_loss=0.720, generator_loss=0.716
# 4/4 [==============================] - 7s 2s/step
# epoch 1 - batch 18/50, discriminator_loss=0.721, generator_loss=0.694
# 4/4 [==============================] - 6s 1s/step
# epoch 1 - batch 19/50, discriminator_loss=0.700, generator_loss=0.698
# 4/4 [==============================] - 6s 1s/step
# epoch 1 - batch 20/50, discriminator_loss=0.676, generator_loss=0.721
# 4/4 [==============================] - 6s 1s/step
# epoch 1 - batch 21/50, discriminator_loss=0.646, generator_loss=0.743
# 4/4 [==============================] - 6s 1s/step
# epoch 1 - batch 22/50, discriminator_loss=0.627, generator_loss=0.859
# 4/4 [==============================] - 6s 1s/step
# epoch 1 - batch 23/50, discriminator_loss=0.608, generator_loss=0.900
# 4/4 [==============================] - 6s 1s/step
# epoch 1 - batch 24/50, discriminator_loss=0.616, generator_loss=0.838
# 4/4 [==============================] - 8s 2s/step
# epoch 1 - batch 25/50, discriminator_loss=0.702, generator_loss=0.928
# 4/4 [==============================] - 6s 1s/step
# epoch 1 - batch 26/50, discriminator_loss=0.800, generator_loss=0.887
# 4/4 [==============================] - 6s 1s/step
# epoch 1 - batch 27/50, discriminator_loss=0.873, generator_loss=0.780
# 4/4 [==============================] - 6s 1s/step
# epoch 1 - batch 28/50, discriminator_loss=0.795, generator_loss=0.765
# 4/4 [==============================] - 6s 1s/step
# epoch 1 - batch 29/50, discriminator_loss=0.761, generator_loss=0.700
# 4/4 [==============================] - 6s 1s/step
# epoch 1 - batch 30/50, discriminator_loss=0.723, generator_loss=0.690
# 4/4 [==============================] - 6s 1s/step
# epoch 1 - batch 31/50, discriminator_loss=0.690, generator_loss=0.673
# 4/4 [==============================] - 6s 1s/step
# epoch 1 - batch 32/50, discriminator_loss=0.663, generator_loss=0.698
# 4/4 [==============================] - 6s 1s/step
# epoch 1 - batch 33/50, discriminator_loss=0.645, generator_loss=0.735
# 4/4 [==============================] - 6s 1s/step
# epoch 1 - batch 34/50, discriminator_loss=0.616, generator_loss=0.793
# 4/4 [==============================] - 6s 1s/step
# epoch 1 - batch 35/50, discriminator_loss=0.596, generator_loss=0.857
# 4/4 [==============================] - 6s 1s/step
# epoch 1 - batch 36/50, discriminator_loss=0.562, generator_loss=0.898
# 4/4 [==============================] - 6s 1s/step
# epoch 1 - batch 37/50, discriminator_loss=0.568, generator_loss=0.921
# 4/4 [==============================] - 6s 1s/step
# epoch 1 - batch 38/50, discriminator_loss=0.615, generator_loss=0.943
# 4/4 [==============================] - 6s 1s/step
# epoch 1 - batch 39/50, discriminator_loss=0.648, generator_loss=0.819
# 4/4 [==============================] - 6s 1s/step
# epoch 1 - batch 40/50, discriminator_loss=0.725, generator_loss=0.736
# 4/4 [==============================] - 6s 1s/step
# epoch 1 - batch 41/50, discriminator_loss=0.781, generator_loss=0.613
# 4/4 [==============================] - 6s 1s/step
# epoch 1 - batch 42/50, discriminator_loss=0.802, generator_loss=0.629
# 4/4 [==============================] - 6s 1s/step
# epoch 1 - batch 43/50, discriminator_loss=0.755, generator_loss=0.610
# 4/4 [==============================] - 6s 1s/step
# epoch 1 - batch 44/50, discriminator_loss=0.744, generator_loss=0.653
# 4/4 [==============================] - 6s 1s/step
# epoch 1 - batch 45/50, discriminator_loss=0.708, generator_loss=0.657
# 4/4 [==============================] - 6s 1s/step
# epoch 1 - batch 46/50, discriminator_loss=0.705, generator_loss=0.683
# 4/4 [==============================] - 6s 1s/step
# epoch 1 - batch 47/50, discriminator_loss=0.691, generator_loss=0.760
# 4/4 [==============================] - 6s 1s/step
# epoch 1 - batch 48/50, discriminator_loss=0.673, generator_loss=0.811
# 4/4 [==============================] - 6s 1s/step
# epoch 1 - batch 49/50, discriminator_loss=0.654, generator_loss=0.836
# 4/4 [==============================] - 12s 3s/step
# epoch 1 - batch 50/50, discriminator_loss=0.634, generator_loss=0.812
# 4/4 [==============================] - 6s 1s/step
# Accuracy réelle : 93%, fausse : 44%
# 4/4 [==============================] - 6s 1s/step
# epoch 2 - batch 1/50, discriminator_loss=0.630, generator_loss=0.929
# 4/4 [==============================] - 6s 1s/step
# epoch 2 - batch 2/50, discriminator_loss=0.629, generator_loss=0.969
# 4/4 [==============================] - 6s 1s/step
# epoch 2 - batch 3/50, discriminator_loss=0.638, generator_loss=0.934
# 4/4 [==============================] - 6s 1s/step
# epoch 2 - batch 4/50, discriminator_loss=0.652, generator_loss=1.091
# 4/4 [==============================] - 6s 1s/step
# epoch 2 - batch 5/50, discriminator_loss=0.676, generator_loss=0.843
# 4/4 [==============================] - 6s 1s/step
# epoch 2 - batch 6/50, discriminator_loss=0.726, generator_loss=1.465
# 4/4 [==============================] - 6s 1s/step
# epoch 2 - batch 7/50, discriminator_loss=0.777, generator_loss=0.742
# 4/4 [==============================] - 6s 1s/step
# epoch 2 - batch 8/50, discriminator_loss=0.748, generator_loss=0.654
# 4/4 [==============================] - 6s 1s/step
# epoch 2 - batch 9/50, discriminator_loss=0.753, generator_loss=0.767
# 4/4 [==============================] - 6s 1s/step
# epoch 2 - batch 10/50, discriminator_loss=0.731, generator_loss=0.868
# 4/4 [==============================] - 6s 1s/step
# epoch 2 - batch 11/50, discriminator_loss=0.727, generator_loss=0.800
# 4/4 [==============================] - 6s 1s/step
# epoch 2 - batch 12/50, discriminator_loss=0.710, generator_loss=0.793
# 4/4 [==============================] - 6s 1s/step
# epoch 2 - batch 13/50, discriminator_loss=0.688, generator_loss=0.793
# 4/4 [==============================] - 6s 1s/step
# epoch 2 - batch 14/50, discriminator_loss=0.657, generator_loss=0.873
# 4/4 [==============================] - 6s 1s/step
# epoch 2 - batch 15/50, discriminator_loss=0.635, generator_loss=0.908
# 4/4 [==============================] - 6s 1s/step
# epoch 2 - batch 16/50, discriminator_loss=0.624, generator_loss=1.172
# 4/4 [==============================] - 6s 1s/step
# epoch 2 - batch 17/50, discriminator_loss=0.632, generator_loss=0.842
# 4/4 [==============================] - 6s 1s/step
# epoch 2 - batch 18/50, discriminator_loss=0.659, generator_loss=1.059
# 4/4 [==============================] - 6s 1s/step
# epoch 2 - batch 19/50, discriminator_loss=0.661, generator_loss=0.979
# 4/4 [==============================] - 6s 1s/step
# epoch 2 - batch 20/50, discriminator_loss=0.682, generator_loss=0.730
# 4/4 [==============================] - 6s 1s/step
# epoch 2 - batch 21/50, discriminator_loss=0.701, generator_loss=0.877
# 4/4 [==============================] - 6s 1s/step
# epoch 2 - batch 22/50, discriminator_loss=0.700, generator_loss=0.774
# 4/4 [==============================] - 6s 1s/step
# epoch 2 - batch 23/50, discriminator_loss=0.695, generator_loss=0.924
# 4/4 [==============================] - 8s 2s/step
# epoch 2 - batch 24/50, discriminator_loss=0.697, generator_loss=0.779
# 4/4 [==============================] - 6s 1s/step
# epoch 2 - batch 25/50, discriminator_loss=0.700, generator_loss=0.850
# 4/4 [==============================] - 6s 1s/step
# epoch 2 - batch 26/50, discriminator_loss=0.708, generator_loss=0.797
# 4/4 [==============================] - 6s 1s/step
# epoch 2 - batch 27/50, discriminator_loss=0.694, generator_loss=0.696
# 4/4 [==============================] - 6s 1s/step
# epoch 2 - batch 28/50, discriminator_loss=0.676, generator_loss=0.827
# 4/4 [==============================] - 6s 1s/step
# epoch 2 - batch 29/50, discriminator_loss=0.669, generator_loss=1.012
# 4/4 [==============================] - 6s 1s/step
# epoch 2 - batch 30/50, discriminator_loss=0.675, generator_loss=0.800
# 4/4 [==============================] - 6s 1s/step
# epoch 2 - batch 31/50, discriminator_loss=0.660, generator_loss=0.707
# 4/4 [==============================] - 9s 2s/step
# epoch 2 - batch 32/50, discriminator_loss=0.674, generator_loss=0.926
# 4/4 [==============================] - 6s 1s/step
# epoch 2 - batch 33/50, discriminator_loss=0.680, generator_loss=0.890
# 4/4 [==============================] - 6s 1s/step
# epoch 2 - batch 34/50, discriminator_loss=0.684, generator_loss=0.735
# 4/4 [==============================] - 6s 1s/step
# epoch 2 - batch 35/50, discriminator_loss=0.694, generator_loss=0.868
# 4/4 [==============================] - 6s 1s/step
# epoch 2 - batch 36/50, discriminator_loss=0.686, generator_loss=0.852
# 4/4 [==============================] - 6s 1s/step
# epoch 2 - batch 37/50, discriminator_loss=0.674, generator_loss=0.665
# 4/4 [==============================] - 6s 1s/step
# epoch 2 - batch 38/50, discriminator_loss=0.670, generator_loss=0.921
# 4/4 [==============================] - 6s 1s/step
# epoch 2 - batch 39/50, discriminator_loss=0.674, generator_loss=0.899
# 4/4 [==============================] - 6s 1s/step
# epoch 2 - batch 40/50, discriminator_loss=0.656, generator_loss=0.719
# 4/4 [==============================] - 6s 1s/step
# epoch 2 - batch 41/50, discriminator_loss=0.664, generator_loss=0.932
# 4/4 [==============================] - 6s 1s/step
# epoch 2 - batch 42/50, discriminator_loss=0.656, generator_loss=0.876
# 4/4 [==============================] - 6s 1s/step
# epoch 2 - batch 43/50, discriminator_loss=0.663, generator_loss=0.661
# 4/4 [==============================] - 6s 1s/step
# epoch 2 - batch 44/50, discriminator_loss=0.713, generator_loss=1.195
# 4/4 [==============================] - 6s 1s/step
# epoch 2 - batch 45/50, discriminator_loss=0.745, generator_loss=0.678
# 4/4 [==============================] - 6s 1s/step
# epoch 2 - batch 46/50, discriminator_loss=0.713, generator_loss=0.628
# 4/4 [==============================] - 6s 1s/step
# epoch 2 - batch 47/50, discriminator_loss=0.693, generator_loss=0.805
# 4/4 [==============================] - 6s 1s/step
# epoch 2 - batch 48/50, discriminator_loss=0.651, generator_loss=0.973
# 4/4 [==============================] - 6s 1s/step
# epoch 2 - batch 49/50, discriminator_loss=0.645, generator_loss=0.874
# 4/4 [==============================] - 6s 1s/step
# epoch 2 - batch 50/50, discriminator_loss=0.610, generator_loss=0.925
# 4/4 [==============================] - 6s 1s/step
# Accuracy réelle : 79%, fausse : 99%
# 4/4 [==============================] - 6s 1s/step
# epoch 3 - batch 1/50, discriminator_loss=0.582, generator_loss=1.102
# 4/4 [==============================] - 6s 1s/step
# epoch 3 - batch 2/50, discriminator_loss=0.591, generator_loss=0.771
# 4/4 [==============================] - 6s 1s/step
# epoch 3 - batch 3/50, discriminator_loss=0.636, generator_loss=1.759
# 4/4 [==============================] - 6s 1s/step
# epoch 3 - batch 4/50, discriminator_loss=0.711, generator_loss=0.468
# 4/4 [==============================] - 6s 1s/step
# epoch 3 - batch 5/50, discriminator_loss=0.817, generator_loss=1.014
# 4/4 [==============================] - 6s 1s/step
# epoch 3 - batch 6/50, discriminator_loss=0.705, generator_loss=1.034
# 4/4 [==============================] - 6s 1s/step
# epoch 3 - batch 7/50, discriminator_loss=0.706, generator_loss=0.730
# 4/4 [==============================] - 6s 1s/step
# epoch 3 - batch 8/50, discriminator_loss=0.701, generator_loss=0.782
# 4/4 [==============================] - 6s 1s/step
# epoch 3 - batch 9/50, discriminator_loss=0.687, generator_loss=0.825
# 4/4 [==============================] - 6s 1s/step
# epoch 3 - batch 10/50, discriminator_loss=0.704, generator_loss=0.854
# 4/4 [==============================] - 6s 1s/step
# epoch 3 - batch 11/50, discriminator_loss=0.668, generator_loss=0.852
# 4/4 [==============================] - 6s 1s/step
# epoch 3 - batch 12/50, discriminator_loss=0.642, generator_loss=0.853
# 4/4 [==============================] - 6s 1s/step
# epoch 3 - batch 13/50, discriminator_loss=0.606, generator_loss=0.910
# 4/4 [==============================] - 6s 1s/step
# epoch 3 - batch 14/50, discriminator_loss=0.602, generator_loss=1.006
# 4/4 [==============================] - 6s 1s/step
# epoch 3 - batch 15/50, discriminator_loss=0.568, generator_loss=0.953
# 4/4 [==============================] - 6s 1s/step
# epoch 3 - batch 16/50, discriminator_loss=0.556, generator_loss=0.958
# 4/4 [==============================] - 6s 1s/step
# epoch 3 - batch 17/50, discriminator_loss=0.527, generator_loss=0.987
# 4/4 [==============================] - 6s 1s/step
# epoch 3 - batch 18/50, discriminator_loss=0.515, generator_loss=0.979
# 4/4 [==============================] - 6s 1s/step
# epoch 3 - batch 19/50, discriminator_loss=0.531, generator_loss=0.978
# 4/4 [==============================] - 6s 1s/step
# epoch 3 - batch 20/50, discriminator_loss=0.590, generator_loss=0.681
# 4/4 [==============================] - 6s 1s/step
# epoch 3 - batch 21/50, discriminator_loss=0.643, generator_loss=0.978
# 4/4 [==============================] - 6s 1s/step
# epoch 3 - batch 22/50, discriminator_loss=0.721, generator_loss=0.558
# 4/4 [==============================] - 6s 1s/step
# epoch 3 - batch 23/50, discriminator_loss=0.685, generator_loss=0.576
# 4/4 [==============================] - 6s 1s/step
# epoch 3 - batch 24/50, discriminator_loss=0.619, generator_loss=0.760
# 4/4 [==============================] - 7s 2s/step
# epoch 3 - batch 25/50, discriminator_loss=0.560, generator_loss=0.855
# 4/4 [==============================] - 6s 1s/step
# epoch 3 - batch 26/50, discriminator_loss=0.548, generator_loss=0.997
# 4/4 [==============================] - 6s 1s/step
# epoch 3 - batch 27/50, discriminator_loss=0.571, generator_loss=0.927
# 4/4 [==============================] - 6s 1s/step
# epoch 3 - batch 28/50, discriminator_loss=0.638, generator_loss=1.014
# 4/4 [==============================] - 6s 1s/step
# epoch 3 - batch 29/50, discriminator_loss=0.547, generator_loss=1.014
# 4/4 [==============================] - 6s 1s/step
# epoch 3 - batch 30/50, discriminator_loss=0.401, generator_loss=1.082
# 4/4 [==============================] - 6s 1s/step
# epoch 3 - batch 31/50, discriminator_loss=0.482, generator_loss=1.030
# 4/4 [==============================] - 6s 1s/step
# epoch 3 - batch 32/50, discriminator_loss=0.715, generator_loss=1.189
# 4/4 [==============================] - 6s 1s/step
# epoch 3 - batch 33/50, discriminator_loss=1.062, generator_loss=0.845
# 4/4 [==============================] - 6s 1s/step
# epoch 3 - batch 34/50, discriminator_loss=0.988, generator_loss=1.263
# 4/4 [==============================] - 6s 1s/step
# epoch 3 - batch 35/50, discriminator_loss=0.990, generator_loss=0.772
# 4/4 [==============================] - 6s 1s/step
# epoch 3 - batch 36/50, discriminator_loss=0.874, generator_loss=1.467
# 4/4 [==============================] - 6s 1s/step
# epoch 3 - batch 37/50, discriminator_loss=0.682, generator_loss=1.330
# 4/4 [==============================] - 6s 1s/step
# epoch 3 - batch 38/50, discriminator_loss=0.652, generator_loss=1.450
# 4/4 [==============================] - 6s 1s/step
# epoch 3 - batch 39/50, discriminator_loss=0.727, generator_loss=1.143
# 4/4 [==============================] - 6s 1s/step
# epoch 3 - batch 40/50, discriminator_loss=0.784, generator_loss=1.372
# 4/4 [==============================] - 6s 1s/step
# epoch 3 - batch 41/50, discriminator_loss=0.837, generator_loss=0.842
# 4/4 [==============================] - 6s 1s/step
# epoch 3 - batch 42/50, discriminator_loss=0.807, generator_loss=1.542
# 4/4 [==============================] - 6s 1s/step
# epoch 3 - batch 43/50, discriminator_loss=0.785, generator_loss=0.811
# 4/4 [==============================] - 6s 1s/step
# epoch 3 - batch 44/50, discriminator_loss=0.724, generator_loss=1.150
# 4/4 [==============================] - 6s 1s/step
# epoch 3 - batch 45/50, discriminator_loss=0.698, generator_loss=1.025
# 4/4 [==============================] - 6s 1s/step
# epoch 3 - batch 46/50, discriminator_loss=0.695, generator_loss=0.989
# 4/4 [==============================] - 6s 1s/step
# epoch 3 - batch 47/50, discriminator_loss=0.702, generator_loss=0.963
# 4/4 [==============================] - 6s 1s/step
# epoch 3 - batch 48/50, discriminator_loss=0.735, generator_loss=0.971
# 4/4 [==============================] - 6s 1s/step
# epoch 3 - batch 49/50, discriminator_loss=0.744, generator_loss=0.819
# 4/4 [==============================] - 6s 1s/step
# epoch 3 - batch 50/50, discriminator_loss=0.741, generator_loss=0.908
# 4/4 [==============================] - 6s 1s/step
# epoch 4 - batch 1/50, discriminator_loss=0.725, generator_loss=0.878
# 4/4 [==============================] - 6s 1s/step
# epoch 4 - batch 2/50, discriminator_loss=0.699, generator_loss=0.852
# 4/4 [==============================] - 6s 1s/step
# epoch 4 - batch 3/50, discriminator_loss=0.666, generator_loss=0.815
# 4/4 [==============================] - 6s 1s/step
# epoch 4 - batch 4/50, discriminator_loss=0.635, generator_loss=0.831
# 4/4 [==============================] - 6s 1s/step
# epoch 4 - batch 5/50, discriminator_loss=0.626, generator_loss=0.838
# 4/4 [==============================] - 6s 1s/step
# epoch 4 - batch 6/50, discriminator_loss=0.597, generator_loss=1.035
# 4/4 [==============================] - 6s 1s/step
# epoch 4 - batch 7/50, discriminator_loss=0.574, generator_loss=1.118
# 4/4 [==============================] - 6s 1s/step
# epoch 4 - batch 8/50, discriminator_loss=0.592, generator_loss=0.831
# 4/4 [==============================] - 6s 1s/step
# epoch 4 - batch 9/50, discriminator_loss=0.596, generator_loss=1.519
# 4/4 [==============================] - 6s 1s/step
# epoch 4 - batch 10/50, discriminator_loss=0.599, generator_loss=1.286
# 4/4 [==============================] - 6s 1s/step
# epoch 4 - batch 11/50, discriminator_loss=0.618, generator_loss=0.922
# 4/4 [==============================] - 6s 1s/step
# epoch 4 - batch 12/50, discriminator_loss=0.680, generator_loss=1.407
# 4/4 [==============================] - 6s 1s/step
# epoch 4 - batch 13/50, discriminator_loss=0.705, generator_loss=0.910
# 4/4 [==============================] - 6s 1s/step
# epoch 4 - batch 14/50, discriminator_loss=0.653, generator_loss=1.041
# 4/4 [==============================] - 6s 1s/step
# epoch 4 - batch 15/50, discriminator_loss=0.605, generator_loss=1.027
# 4/4 [==============================] - 6s 1s/step
# epoch 4 - batch 16/50, discriminator_loss=0.568, generator_loss=0.912
# 4/4 [==============================] - 6s 1s/step
# epoch 4 - batch 17/50, discriminator_loss=0.607, generator_loss=1.095
# 4/4 [==============================] - 6s 1s/step
# epoch 4 - batch 18/50, discriminator_loss=0.653, generator_loss=1.162
# 4/4 [==============================] - 6s 1s/step
# epoch 4 - batch 19/50, discriminator_loss=0.675, generator_loss=0.804
# 4/4 [==============================] - 6s 1s/step
# epoch 4 - batch 20/50, discriminator_loss=0.749, generator_loss=1.464
# 4/4 [==============================] - 6s 1s/step
# epoch 4 - batch 21/50, discriminator_loss=0.814, generator_loss=0.836
# 4/4 [==============================] - 6s 1s/step
# epoch 4 - batch 22/50, discriminator_loss=0.817, generator_loss=0.741
# 4/4 [==============================] - 6s 2s/step
# epoch 4 - batch 23/50, discriminator_loss=0.800, generator_loss=0.895
# 4/4 [==============================] - 6s 1s/step
# epoch 4 - batch 24/50, discriminator_loss=0.782, generator_loss=0.753
# 4/4 [==============================] - 6s 1s/step
# epoch 4 - batch 25/50, discriminator_loss=0.735, generator_loss=0.737
# 4/4 [==============================] - 6s 1s/step
# epoch 4 - batch 26/50, discriminator_loss=0.708, generator_loss=0.741
# 4/4 [==============================] - 6s 1s/step
# epoch 4 - batch 27/50, discriminator_loss=0.676, generator_loss=0.792
# 4/4 [==============================] - 6s 1s/step
# epoch 4 - batch 28/50, discriminator_loss=0.660, generator_loss=0.862
# 4/4 [==============================] - 6s 1s/step
# epoch 4 - batch 29/50, discriminator_loss=0.638, generator_loss=0.955
# 4/4 [==============================] - 6s 1s/step
# epoch 4 - batch 30/50, discriminator_loss=0.612, generator_loss=0.989
# 4/4 [==============================] - 6s 1s/step
# epoch 4 - batch 31/50, discriminator_loss=0.605, generator_loss=0.942
# 4/4 [==============================] - 6s 1s/step
# epoch 4 - batch 32/50, discriminator_loss=0.590, generator_loss=0.952
# 4/4 [==============================] - 6s 1s/step
# epoch 4 - batch 33/50, discriminator_loss=0.586, generator_loss=1.042
# 4/4 [==============================] - 6s 1s/step
# epoch 4 - batch 34/50, discriminator_loss=0.597, generator_loss=1.013
# 4/4 [==============================] - 6s 1s/step
# epoch 4 - batch 35/50, discriminator_loss=0.631, generator_loss=1.028
# 4/4 [==============================] - 6s 1s/step
# epoch 4 - batch 36/50, discriminator_loss=0.645, generator_loss=0.955
# 4/4 [==============================] - 6s 1s/step
# epoch 4 - batch 37/50, discriminator_loss=0.715, generator_loss=0.854
# 4/4 [==============================] - 6s 1s/step
# epoch 4 - batch 38/50, discriminator_loss=0.816, generator_loss=0.653
# 4/4 [==============================] - 6s 1s/step
# epoch 4 - batch 39/50, discriminator_loss=0.812, generator_loss=0.774
# 4/4 [==============================] - 6s 1s/step
# epoch 4 - batch 40/50, discriminator_loss=0.805, generator_loss=0.894
# 4/4 [==============================] - 6s 1s/step
# epoch 4 - batch 41/50, discriminator_loss=0.757, generator_loss=0.804
# 4/4 [==============================] - 6s 1s/step
# epoch 4 - batch 42/50, discriminator_loss=0.711, generator_loss=0.950
# 4/4 [==============================] - 6s 1s/step
# epoch 4 - batch 43/50, discriminator_loss=0.653, generator_loss=0.953
# 4/4 [==============================] - 6s 1s/step
# epoch 4 - batch 44/50, discriminator_loss=0.617, generator_loss=0.967
# 4/4 [==============================] - 6s 1s/step
