# %% [markdown]
# #Instalation
# ---

# %% [markdown]
# Avant de commencer, il est nécessaire de déjà posséder dans son environnement toutes les librairies utiles. Dans la seconde cellule nous importons toutes les librairies qui seront utiles à ce notebook. Il se peut que, lorsque vous lanciez l'éxecution de cette cellule, une soit absente. Dans ce cas il est nécessaire de l'installer. Pour cela dans la cellule suivante utiliser la commande :
#
# *! pip install nom_librairie*
#
# **Attention :** il est fortement conseillé lorsque l'une des librairies doit être installer de relancer le kernel de votre notebook.
#
# **Remarque :** même si toutes les librairies sont importées dès le début, les librairies utiles pour des fonctions présentées au cours de ce notebook sont ré-importées de manière à indiquer d'où elles viennent et ainsi faciliter la réutilisation de la fonction dans un autre projet.

# %%
# utiliser cette cellule pour installer les librairies manquantes
# pour cela il suffit de taper dans cette cellule : !pip install nom_librairie_manquante
# d'exécuter la cellule et de relancer la cellule suivante pour voir si tout se passe bien
# recommencer tant que toutes les librairies ne sont pas installées ...

# sous Colab il faut déjà intégrer ces deux librairies

#!pip install umap-learn[plot]
#!pip install holoviews
#!pip install -U ipykernel

# eventuellement ne pas oublier de relancer le kernel du notebook

# %%
# Importation des différentes librairies utiles pour le notebook

#Sickit learn met régulièrement à jour des versions et 
#indique des futurs warnings. 
#ces deux lignes permettent de ne pas les afficher.
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

# librairies générales
import pickle 
import pandas as pd
from scipy.stats import randint
import numpy as np
import string
import time
import base64
import re
import sys
import copy
import random
from numpy import mean
from numpy import std


# librairie affichage
import matplotlib.pyplot as plt
import seaborn as sns
from PIL import Image
import plotly.graph_objs as go
import plotly.offline as py

from sklearn.metrics import confusion_matrix
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.pipeline import Pipeline
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score

# TensorFlow et keras
import tensorflow as tf
from keras import layers
from keras import models
from keras import optimizers
from keras.preprocessing.image import ImageDataGenerator
from keras_preprocessing.image import img_to_array
#from keras.preprocessing.image import img_to_array, load_img
from keras.callbacks import ModelCheckpoint, EarlyStopping
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras.preprocessing import image
from tqdm import tqdm
from keras.models import load_model
from sklearn.model_selection import KFold
from keras.datasets import fashion_mnist
from tensorflow.keras.utils import to_categorical
from keras.models import Sequential
from keras.layers import Conv2D
from keras.layers import MaxPooling2D
from keras.layers import Dense
from keras.layers import Flatten
from tensorflow.keras.optimizers import SGD
import os
from os import listdir
from os.path import isfile, join
import cv2
import glob

# %%
def plot_curves_confusion (history,confusion_matrix,class_names):
  plt.figure(1,figsize=(16,6))
  plt.gcf().subplots_adjust(left = 0.125, bottom = 0.2, right = 1,
                          top = 0.9, wspace = 0.25, hspace = 0)

  # division de la fenêtre graphique en 1 ligne, 3 colonnes,
  # graphique en position 1 - loss fonction

  plt.subplot(1,3,1)
  plt.plot(history.history['loss'])
  plt.plot(history.history['val_loss'])
  plt.title('model loss')
  plt.ylabel('loss')
  plt.xlabel('epoch')
  plt.legend(['Training loss', 'Validation loss'], loc='upper left')
  # graphique en position 2 - accuracy
  plt.subplot(1,3,2)
  plt.plot(history.history['accuracy'])
  plt.plot(history.history['val_accuracy'])
  plt.title('model accuracy')
  plt.ylabel('accuracy')
  plt.xlabel('epoch')
  plt.legend(['Training accuracy', 'Validation accuracy'], loc='upper left')
  
  # matrice de correlation
  plt.subplot(1,3,3)
  sns.heatmap(conf,annot=True,fmt="d",cmap='Blues',xticklabels=class_names, yticklabels=class_names)# label=class_names)
  # labels, title and ticks
  plt.xlabel('Predicted', fontsize=12)
  #plt.set_label_position('top') 
  #plt.set_ticklabels(class_names, fontsize = 8)
  #plt.tick_top()
  plt.title("Correlation matrix")
  plt.ylabel('True', fontsize=12)
  #plt.set_ticklabels(class_names, fontsize = 8)
  plt.show()


def plot_curves(histories):
    plt.figure(1,figsize=(16,6))
    plt.gcf().subplots_adjust(left = 0.125, bottom = 0.2, right = 1,
                          top = 0.9, wspace = 0.25, hspace = 0)
    for i in range(len(histories)):
    	# plot loss
    	plt.subplot(121)
    	plt.title('Cross Entropy Loss')
    	plt.plot(histories[i].history['loss'], color='blue', label='train')
    	plt.plot(histories[i].history['val_loss'], color='red', label='test')  
    	plt.ylabel('loss')
    	plt.xlabel('epoch')
    	plt.legend(['Training loss', 'Validation loss'], loc='upper left')
    	# plot accuracy
    	plt.subplot(122)
    	plt.title('Classification Accuracy')
    	plt.ylabel('accuracy')
    	plt.xlabel('epoch')
    	plt.plot(histories[i].history['accuracy'], color='blue', label='train')
    	plt.plot(histories[i].history['val_accuracy'], color='red', 
                 label='test')
    	plt.legend(['Training accuracy', 'Validation accuracy'], loc='upper left')
    plt.show()

# %% [markdown]
# Pour pouvoir sauvegarder sur votre répertoire Google Drive, il est nécessaire de fournir une autorisation. Pour cela il suffit d'éxecuter la ligne suivante et de saisir le code donné par Google.

# %%
# pour monter son drive Google Drive local
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# Corriger éventuellement la ligne ci-dessous pour mettre le chemin vers un répertoire spécifique dans votre répertoire Google Drive :

# %%
import sys
my_local_drive='/content/gdrive/My Drive/Colab Notebooks/ML_FDS'
# Ajout du path pour les librairies, fonctions et données
sys.path.append(my_local_drive)
# Se positionner sur le répertoire associé
# %cd $my_local_drive

# %pwd
# Out:
# [Errno 2] No such file or directory: '/content/gdrive/My Drive/Colab Notebooks/ML_FDS'
# /content
# '/content'

# %% [markdown]
# #Extraction de la dataset

# %% [markdown]
# ##Récupération des jeux de données

# %%
# !wget https://www.lirmm.fr/~poncelet/Ressources/Tiger-Fox-Elephant.zip
# Out:
# --2022-11-25 07:39:22--  https://www.lirmm.fr/~poncelet/Ressources/Tiger-Fox-Elephant.zip
# Resolving www.lirmm.fr (www.lirmm.fr)... 193.49.104.251
# Connecting to www.lirmm.fr (www.lirmm.fr)|193.49.104.251|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 7605545 (7.3M) [application/zip]
# Saving to: ‘Tiger-Fox-Elephant.zip’
#
# Tiger-Fox-Elephant. 100%[===================>]   7.25M  17.1MB/s    in 0.4s
#
# 2022-11-25 07:39:23 (17.1 MB/s) - ‘Tiger-Fox-Elephant.zip’ saved [7605545/7605545]

# %%
import zipfile
with zipfile.ZipFile("Tiger-Fox-Elephant.zip","r") as zip_ref:
    zip_ref.extractall("Data_Project")

# %% [markdown]
# ##Visualisation des images

# %% [markdown]
# Il y a trois jeux de données différents : des tigres, des éléphants et des renards. Pour chacun d'entre eux il y a un ensemble d'images positive et un ensemble d'images négatives. Par exemple dans le répertoire *tiger* il n'y a que des images de tigre et dans le répertoire *Tiger_negative_class* il n'y a que des images d'animaux qui ne correspondent pas à des tigres.
#
# Le code ci-dessous permet de visualiser quelques images contenues dans le répertoire *tiger*.

# %%
mypath='Data_Project/Tiger-Fox-Elephant/tiger'
onlyfiles = [ f for f in listdir(mypath) if isfile(join(mypath,f)) ]
images = np.empty(len(onlyfiles), dtype=object)
for n in range(0, len(onlyfiles)):
  images[n] = cv2.imread( join(mypath,onlyfiles[n]) )


COLUMNS = 25 # Nombre d'images à afficher

plt.figure(figsize=(15,15))
for i in range(COLUMNS):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    # cv2 lit met les images en BGR et matplotlib lit du RGB
    # il faut donc convertir pour afficher les bonnes couleurs
    images[i] = cv2.cvtColor(images[i], cv2.COLOR_BGR2RGB)
    plt.imshow(images[i],cmap=plt.cm.binary)  
    plt.xlabel('taille ' + str(images[i].shape))

# %% [markdown]
# ## Reshpe images

# %% [markdown]
# Nous pouvons constater que les images ne sont pas de la même taille. Il faut donc les convertir. Une manière simple de faire et de faire la conversion lors de la lecture des images : ici nous convertissons toutes les images en 124x124.

# %%
IMG_SIZE=124
mypath='Data_Project/Tiger-Fox-Elephant/tiger'
onlyfiles = [ f for f in listdir(mypath) if isfile(join(mypath,f)) ]
images = np.empty(len(onlyfiles), dtype=object)
for n in range(0, len(onlyfiles)):
  images[n] = cv2.imread( join(mypath,onlyfiles[n]) )
  images[n]  = cv2.resize(images[n], (IMG_SIZE, IMG_SIZE))

plt.figure(figsize=(15,15))
for i in range(COLUMNS):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    # cv2 lit met les images en BGR et matplotlib lit du RGB
    # il faut donc convertir pour afficher les bonnes couleurs
    images[i] = cv2.cvtColor(images[i], cv2.COLOR_BGR2RGB)
    plt.imshow(images[i],cmap=plt.cm.binary)  
    plt.xlabel('taille ' + str(images[i].shape))

# %% [markdown]
# #Création du jeu de données

# %% [markdown]
# **Créer le jeu de données**
#
# Actuellement pour chaque animal nous avons un répertoire qui contient des images positives et un répertoire qui contient des images négatives. Pour pouvoir créer un jeu de données nous devons obtenir X et y. Les fonctions ci-dessous permettent de générer, à partir des répertoires, un jeu de données aléatoire pour X et y.

# %%
def create_training_data(path_data, list_classes):
  training_data=[]
  for classes in list_classes:
      path=os.path.join(path_data, classes)
      class_num=list_classes.index(classes)
      for img in os.listdir(path):
        try:
          img_array = cv2.imread(os.path.join(path,img), cv2.IMREAD_UNCHANGED)
          new_array = cv2.resize(img_array, (IMG_SIZE, IMG_SIZE))
          training_data.append([new_array, class_num])
        except Exception as e:
          pass  
  return training_data    

def create_X_y (path_data, list_classes):
      # récupération des données
      training_data=create_training_data(path_data, list_classes)
      # tri des données
      random.shuffle(training_data)
      # création de X et y
      X=[]
      y=[]
      for features, label in training_data:
        X.append(features)
        y.append(label)
      X=np.array(X).reshape(-1,IMG_SIZE, IMG_SIZE, 3)
      y=np.array(y)
      return X,y

def plot_examples(X,y):
  plt.figure(figsize=(15,15))
  for i in range(COLUMNS):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    # cv2 lit met les images en BGR et matplotlib lit du RGB
    X[i] = cv2.cvtColor(X[i], cv2.COLOR_BGR2RGB)
    plt.imshow(X[i]/255.,cmap=plt.cm.binary)
    plt.xlabel('classe ' + str(y[i]))

# %% [markdown]
# Définition de constante globale

# %%
# constantes globales

IMG_SIZE=124
COLUMNS = 25 # Nombre d'images à afficher

# %% [markdown]
# ##Jeu d'entrainement / Jeu de validation

# %%
from sklearn.model_selection import train_test_split
def load_dataset(X,y):
	# Chargement des données
	X_train, y_train, X_test, y_test = train_test_split(X,y,test_size=0.3,shuffle=True)
	#X_train = X_train.reshape((X_train.shape[0], 124, 124, 3))
	#X_test = X_test.reshape((X_test.shape[0], 124, 124, 3))
	return X_train, y_train, X_test, y_test

# %%
def clean_data(train, test):
	# convertion d'entier en float
	train_norm = train.astype('float32')
	test_norm = test.astype('float32')
	# normalisation entre 0 et 1
	train_norm = train_norm / 255.0
	test_norm = test_norm / 255.0
	return train_norm, test_norm

# %%
def create_training_data(path_data, list_classes):
  training_data=[]
  for classes in list_classes:
      path=os.path.join(path_data, classes)
      class_num=list_classes.index(classes)
      for img in os.listdir(path):
        try:
          img_array = cv2.imread(os.path.join(path,img), cv2.IMREAD_UNCHANGED)
          new_array = cv2.resize(img_array, (IMG_SIZE, IMG_SIZE))
          training_data.append([new_array, class_num])
        except Exception as e:
          pass  
  return training_data    

def create_X_y (path_data, list_classes):
      # récupération des données
      training_data=create_training_data(path_data, list_classes)
      # tri des données
      random.shuffle(training_data)
      # création de X et y
      X=[]
      y=[]
      for features, label in training_data:
        X.append(features)
        y.append(label)
      X=np.array(X).reshape(-1,IMG_SIZE, IMG_SIZE, 3)
      y=np.array(y)
      return X,y

def plot_examples(X,y):
  plt.figure(figsize=(15,15))
  for i in range(COLUMNS):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    # cv2 lit met les images en BGR et matplotlib lit du RGB
    X[i] = cv2.cvtColor(X[i], cv2.COLOR_BGR2RGB)
    plt.imshow(X[i]/255.,cmap=plt.cm.binary)
    plt.xlabel('classe ' + str(y[i]))

# %% [markdown]
# ## Validation croisée

# %%
# Evaluation avec un k-fold
def evaluate_model(model, dataX, dataY, n_folds=5, epochs=10):
    scores, histories = list(), list()
    kfold = KFold(n_folds, shuffle=True, random_state=1)
    # parcourir les splits du k-fold
    for train_ix, test_ix in kfold.split(dataX):
    	# selection des données
    	model = define_model()
    	X_train, y_train, X_test, y_test = dataX[train_ix], dataY[train_ix], dataX[test_ix], dataY[test_ix]
    	# fit du modele
    	history = model.fit(X_train, y_train, epochs=epochs, batch_size=32, 
                         validation_data=(X_test, y_test), verbose=1)
    	# evaluate du modele
    	loss, acc = model.evaluate(X_test, y_test, verbose=0)
    	print('accuracy %.3f' % (acc * 100.0))
    	scores.append(acc)
    	histories.append(history)
    return scores, histories

# %% [markdown]
# ##Evaluation et affichage des courbes et résultats

# %%
# fonction pour charger, transformer et évaluer le modele
# elle lance n-folds fois l'évaluation et affiche les courbes et résultats
def run_evaluation(n_folds,epochs):
	# load dataset
	X_train, y_train, X_test, y_test = load_dataset()
	# Nettoyage et normalisation
	X_train, X_test = clean_data(X_train, X_test)
	# define model
	model = define_model()
	print (model.summary())
	# evaluate model
	scores, histories = evaluate_model(model, X_train, y_train, n_folds,epochs)
	plot_curves(histories)
	print('Accuracy: mean=%.3f std=%.3f, n=%d' % (mean(scores)*100, std(scores)*100, len(scores)))

# %% [markdown]
# ## Modèle baseline

# %%
# definition du premier modèle baseline
def define_model():
    model = Sequential()
    # Convolution and pooling
    model.add(Conv2D(filters=32, kernel_size=(3, 3), 
                     activation='relu', input_shape=(124, 124, 3), 
                     name="Conv2D_1"))
    model.add(MaxPooling2D(pool_size=(2, 2), 
                           name="Maxpooling2D_1"))
    
		# flatten
    model.add(Flatten(name="flatten") )
    
    # Partie classification 
    model.add(Dense(1, activation='sigmoid'))

    # compile model
    opt = SGD(learning_rate=0.01, momentum=0.9)
    model.compile(optimizer=opt, loss='binary_crossentropy', 
                  metrics=['accuracy'])
    
    return model

# %% [markdown]
# ##Tigres

# %%
my_path="Data_Project/Tiger-Fox-Elephant/"
my_classes=['tiger','Tiger_negative_class']
X,y=create_X_y (my_path,my_classes)


# Surtout ne pas oublier de normaliser les données avec :
X=X.astype('float')
X=X/255.0

from sklearn.model_selection import train_test_split

def load_dataset(X,y):
	# Chargement des données
	X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3,shuffle=True)
	#X_train = X_train.reshape((X_train.shape[0], 124, 124, 3))
	#X_test = X_test.reshape((X_test.shape[0], 124, 124, 3))
	return X_train, y_train, X_test, y_test

def run_evaluation2(X,y,n_folds,epochs):
	# load dataset
	X_train, y_train, X_test, y_test = load_dataset(X,y)
	# Nettoyage et normalisation
	#X_train, X_test = clean_data(X_train, X_test)
	# define model
	model = define_model()
	print (model.summary())
	# evaluate model
	scores, histories = evaluate_model(model, X_train, y_train, n_folds,epochs)
	plot_curves(histories)
	print('Accuracy: mean=%.3f std=%.3f, n=%d' % (mean(scores)*100, std(scores)*100, len(scores)))

# %%
n_folds=3
epochs=50
run_evaluation2(X,y,n_folds,epochs)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Conv2D_1 (Conv2D)           (None, 122, 122, 32)      896
#
#  Maxpooling2D_1 (MaxPooling2  (None, 61, 61, 32)       0
#  D)
#
#  flatten (Flatten)           (None, 119072)            0
#
#  dense (Dense)               (None, 1)                 119073
#
# =================================================================
# Total params: 119,969
# Trainable params: 119,969
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/50
# 3/3 [==============================] - 8s 179ms/step - loss: 0.6951 - accuracy: 0.6022 - val_loss: 1.5666 - val_accuracy: 0.4894
# Epoch 2/50
# 3/3 [==============================] - 0s 24ms/step - loss: 1.5493 - accuracy: 0.5806 - val_loss: 1.6476 - val_accuracy: 0.4894
# Epoch 3/50
# 3/3 [==============================] - 0s 23ms/step - loss: 0.9852 - accuracy: 0.5376 - val_loss: 0.6814 - val_accuracy: 0.6809
# Epoch 4/50
# 3/3 [==============================] - 0s 22ms/step - loss: 0.6746 - accuracy: 0.6129 - val_loss: 0.6816 - val_accuracy: 0.5532
# Epoch 5/50
# 3/3 [==============================] - 0s 23ms/step - loss: 0.6609 - accuracy: 0.6882 - val_loss: 0.6737 - val_accuracy: 0.6170
# Epoch 6/50
# 3/3 [==============================] - 0s 22ms/step - loss: 0.6334 - accuracy: 0.7419 - val_loss: 0.6543 - val_accuracy: 0.6383
# Epoch 7/50
# 3/3 [==============================] - 0s 25ms/step - loss: 0.5944 - accuracy: 0.7312 - val_loss: 0.6320 - val_accuracy: 0.5957
# Epoch 8/50
# 3/3 [==============================] - 0s 28ms/step - loss: 0.5598 - accuracy: 0.6989 - val_loss: 0.8470 - val_accuracy: 0.4894
# Epoch 9/50
# 3/3 [==============================] - 0s 26ms/step - loss: 0.5857 - accuracy: 0.6989 - val_loss: 0.7224 - val_accuracy: 0.5532
# Epoch 10/50
# 3/3 [==============================] - 0s 26ms/step - loss: 0.5535 - accuracy: 0.7097 - val_loss: 0.6190 - val_accuracy: 0.6809
# Epoch 11/50
# 3/3 [==============================] - 0s 24ms/step - loss: 0.4530 - accuracy: 0.7634 - val_loss: 0.6443 - val_accuracy: 0.6383
# Epoch 12/50
# 3/3 [==============================] - 0s 23ms/step - loss: 0.4295 - accuracy: 0.7957 - val_loss: 0.6482 - val_accuracy: 0.6170
# Epoch 13/50
# 3/3 [==============================] - 0s 23ms/step - loss: 0.4021 - accuracy: 0.8495 - val_loss: 0.6723 - val_accuracy: 0.6596
# Epoch 14/50
# 3/3 [==============================] - 0s 25ms/step - loss: 0.3484 - accuracy: 0.8387 - val_loss: 0.7111 - val_accuracy: 0.6596
# Epoch 15/50
# 3/3 [==============================] - 0s 23ms/step - loss: 0.3469 - accuracy: 0.8925 - val_loss: 0.7212 - val_accuracy: 0.6596
# Epoch 16/50
# 3/3 [==============================] - 0s 23ms/step - loss: 0.3154 - accuracy: 0.8817 - val_loss: 0.7039 - val_accuracy: 0.6383
# Epoch 17/50
# 3/3 [==============================] - 0s 23ms/step - loss: 0.3325 - accuracy: 0.8817 - val_loss: 0.7167 - val_accuracy: 0.6596
# Epoch 18/50
# 3/3 [==============================] - 0s 24ms/step - loss: 0.2854 - accuracy: 0.8925 - val_loss: 0.6723 - val_accuracy: 0.6596
# Epoch 19/50
# 3/3 [==============================] - 0s 22ms/step - loss: 0.2139 - accuracy: 0.9677 - val_loss: 0.6991 - val_accuracy: 0.7021
# Epoch 20/50
# 3/3 [==============================] - 0s 25ms/step - loss: 0.1844 - accuracy: 0.9677 - val_loss: 0.7414 - val_accuracy: 0.6809
# Epoch 21/50
# 3/3 [==============================] - 0s 23ms/step - loss: 0.1546 - accuracy: 0.9785 - val_loss: 0.8050 - val_accuracy: 0.6809
# Epoch 22/50
# 3/3 [==============================] - 0s 23ms/step - loss: 0.1325 - accuracy: 0.9677 - val_loss: 0.8988 - val_accuracy: 0.6809
# Epoch 23/50
# 3/3 [==============================] - 0s 23ms/step - loss: 0.1120 - accuracy: 0.9892 - val_loss: 0.9408 - val_accuracy: 0.6170
# Epoch 24/50
# 3/3 [==============================] - 0s 27ms/step - loss: 0.0965 - accuracy: 0.9892 - val_loss: 1.1652 - val_accuracy: 0.6170
# Epoch 25/50
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0977 - accuracy: 0.9892 - val_loss: 1.1039 - val_accuracy: 0.5957
# Epoch 26/50
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0981 - accuracy: 0.9677 - val_loss: 1.1160 - val_accuracy: 0.6596
# Epoch 27/50
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0698 - accuracy: 0.9785 - val_loss: 0.9422 - val_accuracy: 0.6596
# Epoch 28/50
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0638 - accuracy: 1.0000 - val_loss: 0.9251 - val_accuracy: 0.6383
# Epoch 29/50
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0599 - accuracy: 0.9892 - val_loss: 0.9677 - val_accuracy: 0.6809
# Epoch 30/50
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0415 - accuracy: 1.0000 - val_loss: 1.0342 - val_accuracy: 0.6170
# Epoch 31/50
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0486 - accuracy: 1.0000 - val_loss: 1.0966 - val_accuracy: 0.6596
# Epoch 32/50
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0396 - accuracy: 1.0000 - val_loss: 1.0083 - val_accuracy: 0.6170
# Epoch 33/50
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0259 - accuracy: 1.0000 - val_loss: 1.0552 - val_accuracy: 0.6383
# Epoch 34/50
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0222 - accuracy: 1.0000 - val_loss: 1.0641 - val_accuracy: 0.6170
# Epoch 35/50
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0176 - accuracy: 1.0000 - val_loss: 1.1142 - val_accuracy: 0.6809
# Epoch 36/50
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0175 - accuracy: 1.0000 - val_loss: 1.0917 - val_accuracy: 0.6170
# Epoch 37/50
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0136 - accuracy: 1.0000 - val_loss: 1.1142 - val_accuracy: 0.6170
# Epoch 38/50
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0113 - accuracy: 1.0000 - val_loss: 1.1400 - val_accuracy: 0.6383
# Epoch 39/50
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0106 - accuracy: 1.0000 - val_loss: 1.1588 - val_accuracy: 0.6383
# Epoch 40/50
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0084 - accuracy: 1.0000 - val_loss: 1.1684 - val_accuracy: 0.6170
# Epoch 41/50
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0083 - accuracy: 1.0000 - val_loss: 1.1863 - val_accuracy: 0.6170
# Epoch 42/50
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0075 - accuracy: 1.0000 - val_loss: 1.2018 - val_accuracy: 0.6383
# Epoch 43/50
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0068 - accuracy: 1.0000 - val_loss: 1.2209 - val_accuracy: 0.6383
# Epoch 44/50
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0065 - accuracy: 1.0000 - val_loss: 1.2305 - val_accuracy: 0.6170
# Epoch 45/50
# 3/3 [==============================] - 0s 62ms/step - loss: 0.0060 - accuracy: 1.0000 - val_loss: 1.2433 - val_accuracy: 0.6170
# Epoch 46/50
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0057 - accuracy: 1.0000 - val_loss: 1.2562 - val_accuracy: 0.6170
# Epoch 47/50
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0053 - accuracy: 1.0000 - val_loss: 1.2674 - val_accuracy: 0.6170
# Epoch 48/50
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0051 - accuracy: 1.0000 - val_loss: 1.2780 - val_accuracy: 0.6170
# Epoch 49/50
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0048 - accuracy: 1.0000 - val_loss: 1.2881 - val_accuracy: 0.6170
# Epoch 50/50
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0046 - accuracy: 1.0000 - val_loss: 1.2973 - val_accuracy: 0.6170
# accuracy 61.702
# Epoch 1/50
# 3/3 [==============================] - 1s 86ms/step - loss: 0.7440 - accuracy: 0.4839 - val_loss: 0.7699 - val_accuracy: 0.5106
# Epoch 2/50
# 3/3 [==============================] - 0s 25ms/step - loss: 0.6799 - accuracy: 0.5376 - val_loss: 0.6482 - val_accuracy: 0.5957
# Epoch 3/50
# 3/3 [==============================] - 0s 24ms/step - loss: 0.5557 - accuracy: 0.7419 - val_loss: 0.6021 - val_accuracy: 0.6170
# Epoch 4/50
# 3/3 [==============================] - 0s 25ms/step - loss: 0.5140 - accuracy: 0.7419 - val_loss: 0.5850 - val_accuracy: 0.6596
# Epoch 5/50
# 3/3 [==============================] - 0s 25ms/step - loss: 0.4844 - accuracy: 0.7204 - val_loss: 0.6667 - val_accuracy: 0.6170
# Epoch 6/50
# 3/3 [==============================] - 0s 26ms/step - loss: 0.4009 - accuracy: 0.8495 - val_loss: 0.5811 - val_accuracy: 0.6170
# Epoch 7/50
# 3/3 [==============================] - 0s 24ms/step - loss: 0.4435 - accuracy: 0.7419 - val_loss: 0.4992 - val_accuracy: 0.8298
# Epoch 8/50
# 3/3 [==============================] - 0s 24ms/step - loss: 0.3164 - accuracy: 0.8495 - val_loss: 0.5294 - val_accuracy: 0.8298
# Epoch 9/50
# 3/3 [==============================] - 0s 26ms/step - loss: 0.2696 - accuracy: 0.9140 - val_loss: 0.5914 - val_accuracy: 0.6809
# Epoch 10/50
# 3/3 [==============================] - 0s 24ms/step - loss: 0.2268 - accuracy: 0.9032 - val_loss: 0.6974 - val_accuracy: 0.6809
# Epoch 11/50
# 3/3 [==============================] - 0s 26ms/step - loss: 0.2548 - accuracy: 0.8925 - val_loss: 0.6178 - val_accuracy: 0.7234
# Epoch 12/50
# 3/3 [==============================] - 0s 27ms/step - loss: 0.1600 - accuracy: 0.9462 - val_loss: 0.7411 - val_accuracy: 0.6383
# Epoch 13/50
# 3/3 [==============================] - 0s 25ms/step - loss: 0.2168 - accuracy: 0.9140 - val_loss: 0.6762 - val_accuracy: 0.7234
# Epoch 14/50
# 3/3 [==============================] - 0s 25ms/step - loss: 0.1143 - accuracy: 0.9892 - val_loss: 0.6371 - val_accuracy: 0.7021
# Epoch 15/50
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0977 - accuracy: 1.0000 - val_loss: 0.6582 - val_accuracy: 0.6809
# Epoch 16/50
# 3/3 [==============================] - 0s 26ms/step - loss: 0.1173 - accuracy: 0.9892 - val_loss: 0.8035 - val_accuracy: 0.7021
# Epoch 17/50
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0666 - accuracy: 1.0000 - val_loss: 0.7760 - val_accuracy: 0.6596
# Epoch 18/50
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0648 - accuracy: 0.9892 - val_loss: 0.8399 - val_accuracy: 0.6383
# Epoch 19/50
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0656 - accuracy: 1.0000 - val_loss: 0.8073 - val_accuracy: 0.6383
# Epoch 20/50
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0521 - accuracy: 1.0000 - val_loss: 0.8781 - val_accuracy: 0.6383
# Epoch 21/50
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0629 - accuracy: 0.9892 - val_loss: 0.8121 - val_accuracy: 0.6383
# Epoch 22/50
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0551 - accuracy: 0.9892 - val_loss: 0.8642 - val_accuracy: 0.6596
# Epoch 23/50
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0474 - accuracy: 1.0000 - val_loss: 0.7930 - val_accuracy: 0.6809
# Epoch 24/50
# 3/3 [==============================] - 0s 27ms/step - loss: 0.0523 - accuracy: 0.9892 - val_loss: 0.8228 - val_accuracy: 0.7234
# Epoch 25/50
# 3/3 [==============================] - 0s 29ms/step - loss: 0.0417 - accuracy: 1.0000 - val_loss: 0.8881 - val_accuracy: 0.6809
# Epoch 26/50
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0309 - accuracy: 1.0000 - val_loss: 0.8793 - val_accuracy: 0.6596
# Epoch 27/50
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0358 - accuracy: 1.0000 - val_loss: 1.0144 - val_accuracy: 0.6383
# Epoch 28/50
# 3/3 [==============================] - 0s 27ms/step - loss: 0.0234 - accuracy: 1.0000 - val_loss: 0.8594 - val_accuracy: 0.6596
# Epoch 29/50
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0206 - accuracy: 1.0000 - val_loss: 0.8537 - val_accuracy: 0.6596
# Epoch 30/50
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0126 - accuracy: 1.0000 - val_loss: 0.9423 - val_accuracy: 0.6596
# Epoch 31/50
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0155 - accuracy: 1.0000 - val_loss: 0.8738 - val_accuracy: 0.6809
# Epoch 32/50
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0094 - accuracy: 1.0000 - val_loss: 0.8781 - val_accuracy: 0.7021
# Epoch 33/50
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0106 - accuracy: 1.0000 - val_loss: 0.8796 - val_accuracy: 0.7021
# Epoch 34/50
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0081 - accuracy: 1.0000 - val_loss: 0.9331 - val_accuracy: 0.6809
# Epoch 35/50
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0086 - accuracy: 1.0000 - val_loss: 0.9227 - val_accuracy: 0.7021
# Epoch 36/50
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0067 - accuracy: 1.0000 - val_loss: 0.9140 - val_accuracy: 0.7021
# Epoch 37/50
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0070 - accuracy: 1.0000 - val_loss: 0.9272 - val_accuracy: 0.7021
# Epoch 38/50
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0061 - accuracy: 1.0000 - val_loss: 0.9544 - val_accuracy: 0.7021
# Epoch 39/50
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0057 - accuracy: 1.0000 - val_loss: 0.9728 - val_accuracy: 0.7021
# Epoch 40/50
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0054 - accuracy: 1.0000 - val_loss: 0.9682 - val_accuracy: 0.7021
# Epoch 41/50
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0051 - accuracy: 1.0000 - val_loss: 0.9727 - val_accuracy: 0.7021
# Epoch 42/50
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0048 - accuracy: 1.0000 - val_loss: 0.9864 - val_accuracy: 0.7021
# Epoch 43/50
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0045 - accuracy: 1.0000 - val_loss: 1.0033 - val_accuracy: 0.7021
# Epoch 44/50
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0044 - accuracy: 1.0000 - val_loss: 1.0149 - val_accuracy: 0.7021
# Epoch 45/50
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0042 - accuracy: 1.0000 - val_loss: 1.0140 - val_accuracy: 0.7021
# Epoch 46/50
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 1.0194 - val_accuracy: 0.7021
# Epoch 47/50
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 1.0304 - val_accuracy: 0.7021
# Epoch 48/50
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 1.0412 - val_accuracy: 0.7021
# Epoch 49/50
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 1.0476 - val_accuracy: 0.7021
# Epoch 50/50
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 1.0497 - val_accuracy: 0.7021
# accuracy 70.213
# Epoch 1/50
# 3/3 [==============================] - 1s 165ms/step - loss: 1.8190 - accuracy: 0.4043 - val_loss: 0.9231 - val_accuracy: 0.5000
# Epoch 2/50
# 3/3 [==============================] - 0s 24ms/step - loss: 0.7692 - accuracy: 0.5106 - val_loss: 0.6752 - val_accuracy: 0.5000
# Epoch 3/50
# 3/3 [==============================] - 0s 24ms/step - loss: 0.6639 - accuracy: 0.5000 - val_loss: 0.6677 - val_accuracy: 0.5000
# Epoch 4/50
# 3/3 [==============================] - 0s 25ms/step - loss: 0.6556 - accuracy: 0.5851 - val_loss: 0.6494 - val_accuracy: 0.6739
# Epoch 5/50
# 3/3 [==============================] - 0s 26ms/step - loss: 0.6100 - accuracy: 0.7872 - val_loss: 0.6034 - val_accuracy: 0.6957
# Epoch 6/50
# 3/3 [==============================] - 0s 26ms/step - loss: 0.5404 - accuracy: 0.7660 - val_loss: 0.6955 - val_accuracy: 0.5870
# Epoch 7/50
# 3/3 [==============================] - 0s 31ms/step - loss: 0.7934 - accuracy: 0.5957 - val_loss: 1.0609 - val_accuracy: 0.5000
# Epoch 8/50
# 3/3 [==============================] - 0s 24ms/step - loss: 0.6717 - accuracy: 0.6277 - val_loss: 0.6892 - val_accuracy: 0.5000
# Epoch 9/50
# 3/3 [==============================] - 0s 24ms/step - loss: 0.6282 - accuracy: 0.6383 - val_loss: 0.6572 - val_accuracy: 0.6739
# Epoch 10/50
# 3/3 [==============================] - 0s 24ms/step - loss: 0.6123 - accuracy: 0.8085 - val_loss: 0.6281 - val_accuracy: 0.6304
# Epoch 11/50
# 3/3 [==============================] - 0s 25ms/step - loss: 0.5575 - accuracy: 0.7447 - val_loss: 0.6089 - val_accuracy: 0.6957
# Epoch 12/50
# 3/3 [==============================] - 0s 24ms/step - loss: 0.5038 - accuracy: 0.7660 - val_loss: 0.6188 - val_accuracy: 0.6957
# Epoch 13/50
# 3/3 [==============================] - 0s 24ms/step - loss: 0.4613 - accuracy: 0.7553 - val_loss: 0.6712 - val_accuracy: 0.6087
# Epoch 14/50
# 3/3 [==============================] - 0s 25ms/step - loss: 0.4191 - accuracy: 0.8723 - val_loss: 0.6958 - val_accuracy: 0.6087
# Epoch 15/50
# 3/3 [==============================] - 0s 24ms/step - loss: 0.4285 - accuracy: 0.7979 - val_loss: 0.8040 - val_accuracy: 0.6522
# Epoch 16/50
# 3/3 [==============================] - 0s 24ms/step - loss: 0.3944 - accuracy: 0.8191 - val_loss: 0.7424 - val_accuracy: 0.6304
# Epoch 17/50
# 3/3 [==============================] - 0s 29ms/step - loss: 0.2984 - accuracy: 0.9043 - val_loss: 0.9269 - val_accuracy: 0.5870
# Epoch 18/50
# 3/3 [==============================] - 0s 24ms/step - loss: 0.3628 - accuracy: 0.8191 - val_loss: 0.7403 - val_accuracy: 0.6304
# Epoch 19/50
# 3/3 [==============================] - 0s 25ms/step - loss: 0.3336 - accuracy: 0.8085 - val_loss: 0.7600 - val_accuracy: 0.6087
# Epoch 20/50
# 3/3 [==============================] - 0s 24ms/step - loss: 0.2663 - accuracy: 0.8830 - val_loss: 0.6217 - val_accuracy: 0.6522
# Epoch 21/50
# 3/3 [==============================] - 0s 29ms/step - loss: 0.2636 - accuracy: 0.8936 - val_loss: 0.7147 - val_accuracy: 0.6957
# Epoch 22/50
# 3/3 [==============================] - 0s 27ms/step - loss: 0.1790 - accuracy: 0.9574 - val_loss: 0.8240 - val_accuracy: 0.6739
# Epoch 23/50
# 3/3 [==============================] - 0s 24ms/step - loss: 0.1245 - accuracy: 0.9787 - val_loss: 0.8749 - val_accuracy: 0.6087
# Epoch 24/50
# 3/3 [==============================] - 0s 24ms/step - loss: 0.1058 - accuracy: 0.9894 - val_loss: 1.1543 - val_accuracy: 0.6304
# Epoch 25/50
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0916 - accuracy: 0.9681 - val_loss: 1.1069 - val_accuracy: 0.6087
# Epoch 26/50
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0832 - accuracy: 1.0000 - val_loss: 1.4520 - val_accuracy: 0.6087
# Epoch 27/50
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0906 - accuracy: 0.9681 - val_loss: 1.1833 - val_accuracy: 0.5435
# Epoch 28/50
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0673 - accuracy: 1.0000 - val_loss: 1.4300 - val_accuracy: 0.6087
# Epoch 29/50
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0350 - accuracy: 1.0000 - val_loss: 1.1478 - val_accuracy: 0.5870
# Epoch 30/50
# 3/3 [==============================] - 0s 27ms/step - loss: 0.0359 - accuracy: 1.0000 - val_loss: 1.4105 - val_accuracy: 0.6304
# Epoch 31/50
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0340 - accuracy: 1.0000 - val_loss: 1.2362 - val_accuracy: 0.6304
# Epoch 32/50
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0282 - accuracy: 1.0000 - val_loss: 1.2504 - val_accuracy: 0.6304
# Epoch 33/50
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0218 - accuracy: 1.0000 - val_loss: 1.6009 - val_accuracy: 0.6304
# Epoch 34/50
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0175 - accuracy: 1.0000 - val_loss: 1.2872 - val_accuracy: 0.6304
# Epoch 35/50
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0161 - accuracy: 1.0000 - val_loss: 1.3128 - val_accuracy: 0.6304
# Epoch 36/50
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0102 - accuracy: 1.0000 - val_loss: 1.4988 - val_accuracy: 0.5870
# Epoch 37/50
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0118 - accuracy: 1.0000 - val_loss: 1.5632 - val_accuracy: 0.6087
# Epoch 38/50
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0086 - accuracy: 1.0000 - val_loss: 1.4093 - val_accuracy: 0.6304
# Epoch 39/50
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0093 - accuracy: 1.0000 - val_loss: 1.4153 - val_accuracy: 0.6304
# Epoch 40/50
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0075 - accuracy: 1.0000 - val_loss: 1.5875 - val_accuracy: 0.5870
# Epoch 41/50
# 3/3 [==============================] - 0s 29ms/step - loss: 0.0075 - accuracy: 1.0000 - val_loss: 1.5689 - val_accuracy: 0.5870
# Epoch 42/50
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0060 - accuracy: 1.0000 - val_loss: 1.4909 - val_accuracy: 0.6087
# Epoch 43/50
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0061 - accuracy: 1.0000 - val_loss: 1.4943 - val_accuracy: 0.6087
# Epoch 44/50
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0055 - accuracy: 1.0000 - val_loss: 1.5853 - val_accuracy: 0.6087
# Epoch 45/50
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0051 - accuracy: 1.0000 - val_loss: 1.6027 - val_accuracy: 0.6087
# Epoch 46/50
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0049 - accuracy: 1.0000 - val_loss: 1.5833 - val_accuracy: 0.6087
# Epoch 47/50
# 3/3 [==============================] - 0s 27ms/step - loss: 0.0047 - accuracy: 1.0000 - val_loss: 1.5625 - val_accuracy: 0.6087
# Epoch 48/50
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0045 - accuracy: 1.0000 - val_loss: 1.6078 - val_accuracy: 0.6087
# Epoch 49/50
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0042 - accuracy: 1.0000 - val_loss: 1.6242 - val_accuracy: 0.6087
# Epoch 50/50
# 3/3 [==============================] - 0s 27ms/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 1.6138 - val_accuracy: 0.6087
# accuracy 60.870
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:45: MatplotlibDeprecationWarning:
#
# Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:53: MatplotlibDeprecationWarning:
#
# Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
# Accuracy: mean=64.261 std=4.222, n=3

# %% [markdown]
# ###Amélioration des résultats

# %%
def define_model():
  model = models.Sequential()   # pour initializer le modèle
  model.add(Conv2D(filters=32, kernel_size=(3, 3),activation='relu', input_shape=(124, 124, 3),name="Conv2D_1"))
  model.add(MaxPooling2D(pool_size=(2, 2),name="Maxpooling2D_1")) # pour réduire l'échantillonnage

  model.add(layers.Dropout(0.3))

  model.add(layers.Flatten(name="flatten1"))  #applatir la matrice de maxPooling
  model.add(layers.Dense(128,activation='relu'))
  model.add(layers.Dense(1,activation = 'sigmoid'))  #Couche de sortie 


  model.compile(optimizer='adam',loss='binary_crossentropy', metrics=['accuracy']) #to finalise the model and make it completely ready to use.
  
  return model

# %%
n_folds=3
epochs=50
run_evaluation2(X,y,n_folds,epochs)
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Conv2D_1 (Conv2D)           (None, 122, 122, 32)      896
#
#  Maxpooling2D_1 (MaxPooling2  (None, 61, 61, 32)       0
#  D)
#
#  dropout_4 (Dropout)         (None, 61, 61, 32)        0
#
#  flatten1 (Flatten)          (None, 119072)            0
#
#  dense_12 (Dense)            (None, 128)               15241344
#
#  dense_13 (Dense)            (None, 1)                 129
#
# =================================================================
# Total params: 15,242,369
# Trainable params: 15,242,369
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/50
# 3/3 [==============================] - 1s 95ms/step - loss: 5.5838 - accuracy: 0.5161 - val_loss: 1.7269 - val_accuracy: 0.6170
# Epoch 2/50
# 3/3 [==============================] - 0s 30ms/step - loss: 2.6137 - accuracy: 0.4409 - val_loss: 0.6373 - val_accuracy: 0.6809
# Epoch 3/50
# 3/3 [==============================] - 0s 30ms/step - loss: 1.0462 - accuracy: 0.5806 - val_loss: 0.7132 - val_accuracy: 0.6383
# Epoch 4/50
# 3/3 [==============================] - 0s 30ms/step - loss: 0.6913 - accuracy: 0.6129 - val_loss: 1.3904 - val_accuracy: 0.4043
# Epoch 5/50
# 3/3 [==============================] - 0s 30ms/step - loss: 0.6311 - accuracy: 0.6882 - val_loss: 0.5975 - val_accuracy: 0.6170
# Epoch 6/50
# 3/3 [==============================] - 0s 29ms/step - loss: 0.4716 - accuracy: 0.7849 - val_loss: 0.5998 - val_accuracy: 0.6596
# Epoch 7/50
# 3/3 [==============================] - 0s 30ms/step - loss: 0.2800 - accuracy: 0.9140 - val_loss: 0.8504 - val_accuracy: 0.6170
# Epoch 8/50
# 3/3 [==============================] - 0s 32ms/step - loss: 0.3155 - accuracy: 0.8495 - val_loss: 0.5628 - val_accuracy: 0.7234
# Epoch 9/50
# 3/3 [==============================] - 0s 28ms/step - loss: 0.2341 - accuracy: 0.9462 - val_loss: 0.5218 - val_accuracy: 0.7021
# Epoch 10/50
# 3/3 [==============================] - 0s 29ms/step - loss: 0.1974 - accuracy: 0.9785 - val_loss: 0.4851 - val_accuracy: 0.7447
# Epoch 11/50
# 3/3 [==============================] - 0s 31ms/step - loss: 0.1534 - accuracy: 0.9785 - val_loss: 0.4635 - val_accuracy: 0.7660
# Epoch 12/50
# 3/3 [==============================] - 0s 27ms/step - loss: 0.1233 - accuracy: 0.9892 - val_loss: 0.4410 - val_accuracy: 0.8298
# Epoch 13/50
# 3/3 [==============================] - 0s 29ms/step - loss: 0.1042 - accuracy: 0.9892 - val_loss: 0.4463 - val_accuracy: 0.8085
# Epoch 14/50
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0836 - accuracy: 1.0000 - val_loss: 0.4739 - val_accuracy: 0.8085
# Epoch 15/50
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0590 - accuracy: 1.0000 - val_loss: 0.4521 - val_accuracy: 0.8085
# Epoch 16/50
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0483 - accuracy: 1.0000 - val_loss: 0.4330 - val_accuracy: 0.8298
# Epoch 17/50
# 3/3 [==============================] - 0s 29ms/step - loss: 0.0382 - accuracy: 1.0000 - val_loss: 0.4255 - val_accuracy: 0.8085
# Epoch 18/50
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0289 - accuracy: 1.0000 - val_loss: 0.4184 - val_accuracy: 0.8298
# Epoch 19/50
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0246 - accuracy: 1.0000 - val_loss: 0.4623 - val_accuracy: 0.7872
# Epoch 20/50
# 3/3 [==============================] - 0s 27ms/step - loss: 0.0219 - accuracy: 1.0000 - val_loss: 0.4494 - val_accuracy: 0.8298
# Epoch 21/50
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0152 - accuracy: 1.0000 - val_loss: 0.4591 - val_accuracy: 0.7872
# Epoch 22/50
# 3/3 [==============================] - 0s 27ms/step - loss: 0.0138 - accuracy: 1.0000 - val_loss: 0.4817 - val_accuracy: 0.7872
# Epoch 23/50
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0119 - accuracy: 1.0000 - val_loss: 0.4764 - val_accuracy: 0.8085
# Epoch 24/50
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0090 - accuracy: 1.0000 - val_loss: 0.4603 - val_accuracy: 0.8085
# Epoch 25/50
# 3/3 [==============================] - 0s 29ms/step - loss: 0.0088 - accuracy: 1.0000 - val_loss: 0.4573 - val_accuracy: 0.8298
# Epoch 26/50
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0082 - accuracy: 1.0000 - val_loss: 0.4863 - val_accuracy: 0.8085
# Epoch 27/50
# 3/3 [==============================] - 0s 29ms/step - loss: 0.0067 - accuracy: 1.0000 - val_loss: 0.4523 - val_accuracy: 0.8298
# Epoch 28/50
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0058 - accuracy: 1.0000 - val_loss: 0.4445 - val_accuracy: 0.8085
# Epoch 29/50
# 3/3 [==============================] - 0s 29ms/step - loss: 0.0051 - accuracy: 1.0000 - val_loss: 0.4479 - val_accuracy: 0.8298
# Epoch 30/50
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0047 - accuracy: 1.0000 - val_loss: 0.4563 - val_accuracy: 0.8085
# Epoch 31/50
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 0.4471 - val_accuracy: 0.8298
# Epoch 32/50
# 3/3 [==============================] - 0s 29ms/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 0.4487 - val_accuracy: 0.8298
# Epoch 33/50
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.4547 - val_accuracy: 0.8298
# Epoch 34/50
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.4724 - val_accuracy: 0.8085
# Epoch 35/50
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.4607 - val_accuracy: 0.8298
# Epoch 36/50
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.4640 - val_accuracy: 0.8298
# Epoch 37/50
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.4703 - val_accuracy: 0.8298
# Epoch 38/50
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.4825 - val_accuracy: 0.8298
# Epoch 39/50
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.4781 - val_accuracy: 0.8298
# Epoch 40/50
# 3/3 [==============================] - 0s 29ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.4750 - val_accuracy: 0.8298
# Epoch 41/50
# 3/3 [==============================] - 0s 29ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.4759 - val_accuracy: 0.8298
# Epoch 42/50
# 3/3 [==============================] - 0s 29ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.4884 - val_accuracy: 0.8298
# Epoch 43/50
# 3/3 [==============================] - 0s 29ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.4925 - val_accuracy: 0.8298
# Epoch 44/50
# 3/3 [==============================] - 0s 27ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.4841 - val_accuracy: 0.8085
# Epoch 45/50
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.4839 - val_accuracy: 0.8298
# Epoch 46/50
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.4840 - val_accuracy: 0.8298
# Epoch 47/50
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.4893 - val_accuracy: 0.8298
# Epoch 48/50
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.4897 - val_accuracy: 0.8298
# Epoch 49/50
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.4836 - val_accuracy: 0.8085
# Epoch 50/50
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.4827 - val_accuracy: 0.8298
# accuracy 82.979
# Epoch 1/50
# 3/3 [==============================] - 1s 96ms/step - loss: 8.1011 - accuracy: 0.4516 - val_loss: 10.1527 - val_accuracy: 0.5319
# Epoch 2/50
# 3/3 [==============================] - 0s 28ms/step - loss: 11.2434 - accuracy: 0.4516 - val_loss: 5.0932 - val_accuracy: 0.5319
# Epoch 3/50
# 3/3 [==============================] - 0s 28ms/step - loss: 3.1111 - accuracy: 0.5054 - val_loss: 2.1906 - val_accuracy: 0.4681
# Epoch 4/50
# 3/3 [==============================] - 0s 29ms/step - loss: 2.3938 - accuracy: 0.5484 - val_loss: 2.9122 - val_accuracy: 0.4681
# Epoch 5/50
# 3/3 [==============================] - 0s 29ms/step - loss: 2.3319 - accuracy: 0.5484 - val_loss: 1.9153 - val_accuracy: 0.4681
# Epoch 6/50
# 3/3 [==============================] - 0s 29ms/step - loss: 1.3716 - accuracy: 0.5484 - val_loss: 1.0564 - val_accuracy: 0.4681
# Epoch 7/50
# 3/3 [==============================] - 0s 29ms/step - loss: 0.7631 - accuracy: 0.5484 - val_loss: 0.6592 - val_accuracy: 0.6596
# Epoch 8/50
# 3/3 [==============================] - 0s 28ms/step - loss: 0.6796 - accuracy: 0.5914 - val_loss: 0.6820 - val_accuracy: 0.5745
# Epoch 9/50
# 3/3 [==============================] - 0s 29ms/step - loss: 0.6939 - accuracy: 0.4839 - val_loss: 0.6423 - val_accuracy: 0.5957
# Epoch 10/50
# 3/3 [==============================] - 0s 29ms/step - loss: 0.6141 - accuracy: 0.7204 - val_loss: 0.6401 - val_accuracy: 0.6383
# Epoch 11/50
# 3/3 [==============================] - 0s 28ms/step - loss: 0.5747 - accuracy: 0.7419 - val_loss: 0.6683 - val_accuracy: 0.5106
# Epoch 12/50
# 3/3 [==============================] - 0s 28ms/step - loss: 0.5486 - accuracy: 0.7097 - val_loss: 0.6213 - val_accuracy: 0.6596
# Epoch 13/50
# 3/3 [==============================] - 0s 28ms/step - loss: 0.5070 - accuracy: 0.8602 - val_loss: 0.5796 - val_accuracy: 0.7447
# Epoch 14/50
# 3/3 [==============================] - 0s 32ms/step - loss: 0.4692 - accuracy: 0.8925 - val_loss: 0.5712 - val_accuracy: 0.6809
# Epoch 15/50
# 3/3 [==============================] - 0s 27ms/step - loss: 0.4300 - accuracy: 0.8710 - val_loss: 0.5564 - val_accuracy: 0.6596
# Epoch 16/50
# 3/3 [==============================] - 0s 28ms/step - loss: 0.3950 - accuracy: 0.9032 - val_loss: 0.5219 - val_accuracy: 0.7660
# Epoch 17/50
# 3/3 [==============================] - 0s 28ms/step - loss: 0.3523 - accuracy: 0.9247 - val_loss: 0.5536 - val_accuracy: 0.7234
# Epoch 18/50
# 3/3 [==============================] - 0s 29ms/step - loss: 0.3075 - accuracy: 0.9462 - val_loss: 0.4923 - val_accuracy: 0.7447
# Epoch 19/50
# 3/3 [==============================] - 0s 28ms/step - loss: 0.2794 - accuracy: 0.9570 - val_loss: 0.4873 - val_accuracy: 0.7660
# Epoch 20/50
# 3/3 [==============================] - 0s 27ms/step - loss: 0.2351 - accuracy: 0.9785 - val_loss: 0.5158 - val_accuracy: 0.7660
# Epoch 21/50
# 3/3 [==============================] - 0s 28ms/step - loss: 0.2107 - accuracy: 0.9570 - val_loss: 0.4708 - val_accuracy: 0.7872
# Epoch 22/50
# 3/3 [==============================] - 0s 29ms/step - loss: 0.1831 - accuracy: 0.9677 - val_loss: 0.4994 - val_accuracy: 0.7234
# Epoch 23/50
# 3/3 [==============================] - 0s 28ms/step - loss: 0.1495 - accuracy: 0.9892 - val_loss: 0.5409 - val_accuracy: 0.7660
# Epoch 24/50
# 3/3 [==============================] - 0s 28ms/step - loss: 0.1407 - accuracy: 0.9892 - val_loss: 0.5001 - val_accuracy: 0.7234
# Epoch 25/50
# 3/3 [==============================] - 0s 35ms/step - loss: 0.1102 - accuracy: 1.0000 - val_loss: 0.5137 - val_accuracy: 0.7447
# Epoch 26/50
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0986 - accuracy: 1.0000 - val_loss: 0.4943 - val_accuracy: 0.7447
# Epoch 27/50
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0818 - accuracy: 1.0000 - val_loss: 0.5447 - val_accuracy: 0.7234
# Epoch 28/50
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0662 - accuracy: 1.0000 - val_loss: 0.4946 - val_accuracy: 0.7660
# Epoch 29/50
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0610 - accuracy: 1.0000 - val_loss: 0.5483 - val_accuracy: 0.7447
# Epoch 30/50
# 3/3 [==============================] - 0s 29ms/step - loss: 0.0519 - accuracy: 1.0000 - val_loss: 0.5713 - val_accuracy: 0.7447
# Epoch 31/50
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0430 - accuracy: 1.0000 - val_loss: 0.5263 - val_accuracy: 0.7872
# Epoch 32/50
# 3/3 [==============================] - 0s 27ms/step - loss: 0.0409 - accuracy: 1.0000 - val_loss: 0.5914 - val_accuracy: 0.7447
# Epoch 33/50
# 3/3 [==============================] - 0s 29ms/step - loss: 0.0335 - accuracy: 1.0000 - val_loss: 0.5511 - val_accuracy: 0.7660
# Epoch 34/50
# 3/3 [==============================] - 0s 29ms/step - loss: 0.0343 - accuracy: 1.0000 - val_loss: 0.5685 - val_accuracy: 0.7660
# Epoch 35/50
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0286 - accuracy: 1.0000 - val_loss: 0.6703 - val_accuracy: 0.7234
# Epoch 36/50
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0239 - accuracy: 1.0000 - val_loss: 0.5694 - val_accuracy: 0.7872
# Epoch 37/50
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0231 - accuracy: 1.0000 - val_loss: 0.5906 - val_accuracy: 0.7660
# Epoch 38/50
# 3/3 [==============================] - 0s 29ms/step - loss: 0.0186 - accuracy: 1.0000 - val_loss: 0.6355 - val_accuracy: 0.7021
# Epoch 39/50
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0171 - accuracy: 1.0000 - val_loss: 0.6286 - val_accuracy: 0.7234
# Epoch 40/50
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0157 - accuracy: 1.0000 - val_loss: 0.6256 - val_accuracy: 0.7234
# Epoch 41/50
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0139 - accuracy: 1.0000 - val_loss: 0.6277 - val_accuracy: 0.7660
# Epoch 42/50
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0122 - accuracy: 1.0000 - val_loss: 0.6556 - val_accuracy: 0.7234
# Epoch 43/50
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0119 - accuracy: 1.0000 - val_loss: 0.6552 - val_accuracy: 0.7234
# Epoch 44/50
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0115 - accuracy: 1.0000 - val_loss: 0.6466 - val_accuracy: 0.7660
# Epoch 45/50
# 3/3 [==============================] - 0s 29ms/step - loss: 0.0104 - accuracy: 1.0000 - val_loss: 0.6590 - val_accuracy: 0.7660
# Epoch 46/50
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0096 - accuracy: 1.0000 - val_loss: 0.6767 - val_accuracy: 0.7234
# Epoch 47/50
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0094 - accuracy: 1.0000 - val_loss: 0.6817 - val_accuracy: 0.7234
# Epoch 48/50
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0085 - accuracy: 1.0000 - val_loss: 0.6633 - val_accuracy: 0.7660
# Epoch 49/50
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0084 - accuracy: 1.0000 - val_loss: 0.6854 - val_accuracy: 0.7234
# Epoch 50/50
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0075 - accuracy: 1.0000 - val_loss: 0.7264 - val_accuracy: 0.7021
# accuracy 70.213
# Epoch 1/50
# 3/3 [==============================] - 1s 104ms/step - loss: 5.3107 - accuracy: 0.5106 - val_loss: 0.6838 - val_accuracy: 0.5652
# Epoch 2/50
# 3/3 [==============================] - 0s 30ms/step - loss: 0.7797 - accuracy: 0.6064 - val_loss: 1.1965 - val_accuracy: 0.5217
# Epoch 3/50
# 3/3 [==============================] - 0s 32ms/step - loss: 0.7323 - accuracy: 0.6064 - val_loss: 1.4131 - val_accuracy: 0.4783
# Epoch 4/50
# 3/3 [==============================] - 0s 29ms/step - loss: 0.6170 - accuracy: 0.7234 - val_loss: 0.9988 - val_accuracy: 0.6739
# Epoch 5/50
# 3/3 [==============================] - 0s 29ms/step - loss: 0.4405 - accuracy: 0.7660 - val_loss: 0.9948 - val_accuracy: 0.5870
# Epoch 6/50
# 3/3 [==============================] - 0s 29ms/step - loss: 0.3262 - accuracy: 0.8298 - val_loss: 0.5832 - val_accuracy: 0.7609
# Epoch 7/50
# 3/3 [==============================] - 0s 29ms/step - loss: 0.2931 - accuracy: 0.8617 - val_loss: 0.5668 - val_accuracy: 0.7609
# Epoch 8/50
# 3/3 [==============================] - 0s 28ms/step - loss: 0.1494 - accuracy: 0.9362 - val_loss: 0.8474 - val_accuracy: 0.5870
# Epoch 9/50
# 3/3 [==============================] - 0s 28ms/step - loss: 0.1665 - accuracy: 0.9574 - val_loss: 0.5215 - val_accuracy: 0.7826
# Epoch 10/50
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0972 - accuracy: 0.9787 - val_loss: 0.5305 - val_accuracy: 0.7609
# Epoch 11/50
# 3/3 [==============================] - 0s 29ms/step - loss: 0.0558 - accuracy: 0.9894 - val_loss: 0.7280 - val_accuracy: 0.6739
# Epoch 12/50
# 3/3 [==============================] - 0s 27ms/step - loss: 0.0498 - accuracy: 0.9894 - val_loss: 0.5405 - val_accuracy: 0.7391
# Epoch 13/50
# 3/3 [==============================] - 0s 29ms/step - loss: 0.0256 - accuracy: 1.0000 - val_loss: 0.5600 - val_accuracy: 0.7609
# Epoch 14/50
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0191 - accuracy: 1.0000 - val_loss: 0.6084 - val_accuracy: 0.7609
# Epoch 15/50
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0193 - accuracy: 1.0000 - val_loss: 0.7000 - val_accuracy: 0.7391
# Epoch 16/50
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0091 - accuracy: 1.0000 - val_loss: 0.6066 - val_accuracy: 0.7826
# Epoch 17/50
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0091 - accuracy: 1.0000 - val_loss: 0.6210 - val_accuracy: 0.7609
# Epoch 18/50
# 3/3 [==============================] - 0s 29ms/step - loss: 0.0058 - accuracy: 1.0000 - val_loss: 0.6697 - val_accuracy: 0.8043
# Epoch 19/50
# 3/3 [==============================] - 0s 29ms/step - loss: 0.0047 - accuracy: 1.0000 - val_loss: 0.7418 - val_accuracy: 0.7174
# Epoch 20/50
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 0.6890 - val_accuracy: 0.7609
# Epoch 21/50
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.6384 - val_accuracy: 0.8043
# Epoch 22/50
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.6393 - val_accuracy: 0.7391
# Epoch 23/50
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.6538 - val_accuracy: 0.7391
# Epoch 24/50
# 3/3 [==============================] - 0s 29ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.6940 - val_accuracy: 0.7826
# Epoch 25/50
# 3/3 [==============================] - 0s 29ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.7622 - val_accuracy: 0.7174
# Epoch 26/50
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.7755 - val_accuracy: 0.7391
# Epoch 27/50
# 3/3 [==============================] - 0s 29ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.7233 - val_accuracy: 0.7609
# Epoch 28/50
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.6943 - val_accuracy: 0.7609
# Epoch 29/50
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.6906 - val_accuracy: 0.7609
# Epoch 30/50
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.7066 - val_accuracy: 0.7609
# Epoch 31/50
# 3/3 [==============================] - 0s 29ms/step - loss: 9.3787e-04 - accuracy: 1.0000 - val_loss: 0.7272 - val_accuracy: 0.7609
# Epoch 32/50
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.7375 - val_accuracy: 0.7391
# Epoch 33/50
# 3/3 [==============================] - 0s 29ms/step - loss: 8.6646e-04 - accuracy: 1.0000 - val_loss: 0.7360 - val_accuracy: 0.7391
# Epoch 34/50
# 3/3 [==============================] - 0s 28ms/step - loss: 8.4843e-04 - accuracy: 1.0000 - val_loss: 0.7278 - val_accuracy: 0.7609
# Epoch 35/50
# 3/3 [==============================] - 0s 28ms/step - loss: 7.5243e-04 - accuracy: 1.0000 - val_loss: 0.7287 - val_accuracy: 0.7609
# Epoch 36/50
# 3/3 [==============================] - 0s 29ms/step - loss: 7.4312e-04 - accuracy: 1.0000 - val_loss: 0.7341 - val_accuracy: 0.7609
# Epoch 37/50
# 3/3 [==============================] - 0s 30ms/step - loss: 7.3446e-04 - accuracy: 1.0000 - val_loss: 0.7384 - val_accuracy: 0.7609
# Epoch 38/50
# 3/3 [==============================] - 0s 29ms/step - loss: 6.9730e-04 - accuracy: 1.0000 - val_loss: 0.7361 - val_accuracy: 0.7609
# Epoch 39/50
# 3/3 [==============================] - 0s 28ms/step - loss: 6.3975e-04 - accuracy: 1.0000 - val_loss: 0.7376 - val_accuracy: 0.7609
# Epoch 40/50
# 3/3 [==============================] - 0s 30ms/step - loss: 6.1606e-04 - accuracy: 1.0000 - val_loss: 0.7490 - val_accuracy: 0.7609
# Epoch 41/50
# 3/3 [==============================] - 0s 29ms/step - loss: 6.2432e-04 - accuracy: 1.0000 - val_loss: 0.7451 - val_accuracy: 0.7826
# Epoch 42/50
# 3/3 [==============================] - 0s 28ms/step - loss: 5.4549e-04 - accuracy: 1.0000 - val_loss: 0.7450 - val_accuracy: 0.7609
# Epoch 43/50
# 3/3 [==============================] - 0s 29ms/step - loss: 4.6857e-04 - accuracy: 1.0000 - val_loss: 0.7532 - val_accuracy: 0.7609
# Epoch 44/50
# 3/3 [==============================] - 0s 30ms/step - loss: 4.7385e-04 - accuracy: 1.0000 - val_loss: 0.7391 - val_accuracy: 0.7391
# Epoch 45/50
# 3/3 [==============================] - 0s 29ms/step - loss: 4.9963e-04 - accuracy: 1.0000 - val_loss: 0.7445 - val_accuracy: 0.7391
# Epoch 46/50
# 3/3 [==============================] - 0s 28ms/step - loss: 4.5254e-04 - accuracy: 1.0000 - val_loss: 0.7592 - val_accuracy: 0.7609
# Epoch 47/50
# 3/3 [==============================] - 0s 28ms/step - loss: 3.7694e-04 - accuracy: 1.0000 - val_loss: 0.7470 - val_accuracy: 0.7391
# Epoch 48/50
# 3/3 [==============================] - 0s 29ms/step - loss: 3.6788e-04 - accuracy: 1.0000 - val_loss: 0.7441 - val_accuracy: 0.7391
# Epoch 49/50
# 3/3 [==============================] - 0s 29ms/step - loss: 3.1237e-04 - accuracy: 1.0000 - val_loss: 0.7690 - val_accuracy: 0.7391
# Epoch 50/50
# 3/3 [==============================] - 0s 28ms/step - loss: 2.7834e-04 - accuracy: 1.0000 - val_loss: 0.8123 - val_accuracy: 0.8043
# accuracy 80.435
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:45: MatplotlibDeprecationWarning:
#
# Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:53: MatplotlibDeprecationWarning:
#
# Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
# Accuracy: mean=77.875 std=5.517, n=3

# %% [markdown]
# ###Augmentation des données

# %%
X_train, y_train, X_test, y_test = load_dataset(X,y)
# nettoyage et normlisation des données
X_train, X_test = clean_data(X_train, X_test)

# %%
from keras.layers import BatchNormalization
def define_model():
  model = models.Sequential()   # pour initializer le modèle
  model.add(Conv2D(filters=32, kernel_size=(3, 3),activation='relu', input_shape=(124, 124, 3)))
  model.add(Conv2D(filters=32, kernel_size=(3, 3),activation='relu', input_shape=(124, 124, 3))) 
  model.add(MaxPooling2D(pool_size=(2, 2))) # pour réduire l'échantillonnage

  model.add(layers.Dropout(0.3))

  model.add(Conv2D(filters=64, kernel_size=(3, 3),activation='relu', input_shape=(124, 124, 3)))
  model.add(Conv2D(filters=64, kernel_size=(3, 3),activation='relu', input_shape=(124, 124, 3)))
  model.add(MaxPooling2D(pool_size=(2, 2))) # pour réduire l'échantillonnage
  model.add(layers.Dropout(0.3))

  model.add(Conv2D(filters=128, kernel_size=(3, 3),activation='relu', input_shape=(124, 124, 3)))
  model.add(Conv2D(filters=128, kernel_size=(3, 3),activation='relu', input_shape=(124, 124, 3)))
  model.add(MaxPooling2D(pool_size=(2, 2))) # pour réduire l'échantillonnage
  model.add(layers.Dropout(0.3))

  model.add(layers.Flatten(name="flatten1"))  #applatir la matrice de maxPooling
  model.add(layers.Dense(128,activation='relu'))
  model.add(layers.Dense(1,activation = 'sigmoid'))  #Couche de sortie 


  model.compile(optimizer='adam',loss='binary_crossentropy', metrics=['accuracy']) #to finalise the model and make it completely ready to use.
  
  return model

# %%
model = define_model()
# compile model
epochs= 200
batch_size=32
datagen = ImageDataGenerator(width_shift_range=0.2, height_shift_range=0.2, horizontal_flip=True)
it_train = datagen.flow(X_train, y_train, batch_size=batch_size)
history = model.fit(it_train,batch_size=batch_size,epochs=epochs,verbose=1,validation_data=(X_train, y_train))
#history=fashion_model.fit(train_images, train_labels, validation_data=(test_images, test_labels), epochs=epochs, batch_size=batch_size) 
plt.figure(1,figsize=(16,6))
plt.gcf().subplots_adjust(left = 0.125, bottom = 0.2, right = 1,
                          top = 0.9, wspace = 0.25, hspace = 0)
plt.subplot(1,3,1)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['Training loss', 'Validation loss'], loc='upper left')
# graphique en position 2 - accuracy
plt.subplot(1,3,2)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['Training accuracy', 'Validation accuracy'], loc='upper left')
plt.xlabel('Predicted', fontsize=12)
plt.ylabel('True', fontsize=12)
plt.show()
# Out:
# Epoch 1/200
# 5/5 [==============================] - 2s 170ms/step - loss: 0.6934 - accuracy: 0.5357 - val_loss: 0.6942 - val_accuracy: 0.5143
# Epoch 2/200
# 5/5 [==============================] - 1s 139ms/step - loss: 0.6986 - accuracy: 0.5143 - val_loss: 0.6937 - val_accuracy: 0.5143
# Epoch 3/200
# 5/5 [==============================] - 1s 132ms/step - loss: 0.6938 - accuracy: 0.5143 - val_loss: 0.6929 - val_accuracy: 0.5143
# Epoch 4/200
# 5/5 [==============================] - 1s 122ms/step - loss: 0.6931 - accuracy: 0.5143 - val_loss: 0.6930 - val_accuracy: 0.5143
# Epoch 5/200
# 5/5 [==============================] - 1s 114ms/step - loss: 0.6931 - accuracy: 0.5143 - val_loss: 0.6930 - val_accuracy: 0.5143
# Epoch 6/200
# 5/5 [==============================] - 1s 115ms/step - loss: 0.6931 - accuracy: 0.5143 - val_loss: 0.6931 - val_accuracy: 0.5143
# Epoch 7/200
# 5/5 [==============================] - 1s 115ms/step - loss: 0.6931 - accuracy: 0.5143 - val_loss: 0.6930 - val_accuracy: 0.5143
# Epoch 8/200
# 5/5 [==============================] - 1s 121ms/step - loss: 0.6930 - accuracy: 0.5143 - val_loss: 0.6930 - val_accuracy: 0.5143
# Epoch 9/200
# 5/5 [==============================] - 1s 113ms/step - loss: 0.6929 - accuracy: 0.5143 - val_loss: 0.6929 - val_accuracy: 0.5143
# Epoch 10/200
# 5/5 [==============================] - 1s 118ms/step - loss: 0.6930 - accuracy: 0.5143 - val_loss: 0.6929 - val_accuracy: 0.5143
# Epoch 11/200
# 5/5 [==============================] - 1s 113ms/step - loss: 0.6931 - accuracy: 0.5143 - val_loss: 0.6929 - val_accuracy: 0.5143
# Epoch 12/200
# 5/5 [==============================] - 1s 118ms/step - loss: 0.6929 - accuracy: 0.5143 - val_loss: 0.6930 - val_accuracy: 0.5143
# Epoch 13/200
# 5/5 [==============================] - 1s 112ms/step - loss: 0.6930 - accuracy: 0.5143 - val_loss: 0.6930 - val_accuracy: 0.5143
# Epoch 14/200
# 5/5 [==============================] - 1s 137ms/step - loss: 0.6930 - accuracy: 0.5143 - val_loss: 0.6930 - val_accuracy: 0.5143
# Epoch 15/200
# 5/5 [==============================] - 1s 115ms/step - loss: 0.6930 - accuracy: 0.5143 - val_loss: 0.6930 - val_accuracy: 0.5143
# Epoch 16/200
# 5/5 [==============================] - 1s 111ms/step - loss: 0.6930 - accuracy: 0.5143 - val_loss: 0.6930 - val_accuracy: 0.5143
# Epoch 17/200
# 5/5 [==============================] - 1s 116ms/step - loss: 0.6930 - accuracy: 0.5143 - val_loss: 0.6929 - val_accuracy: 0.5143
# Epoch 18/200
# 5/5 [==============================] - 1s 115ms/step - loss: 0.6930 - accuracy: 0.5143 - val_loss: 0.6929 - val_accuracy: 0.5143
# Epoch 19/200
# 5/5 [==============================] - 1s 120ms/step - loss: 0.6929 - accuracy: 0.5143 - val_loss: 0.6929 - val_accuracy: 0.5143
# Epoch 20/200
# 5/5 [==============================] - 1s 133ms/step - loss: 0.6929 - accuracy: 0.5143 - val_loss: 0.6929 - val_accuracy: 0.5143
# Epoch 21/200
# 5/5 [==============================] - 1s 134ms/step - loss: 0.6929 - accuracy: 0.5143 - val_loss: 0.6928 - val_accuracy: 0.5143
# Epoch 22/200
# 5/5 [==============================] - 1s 116ms/step - loss: 0.6928 - accuracy: 0.5143 - val_loss: 0.6928 - val_accuracy: 0.5143
# Epoch 23/200
# 5/5 [==============================] - 1s 136ms/step - loss: 0.6928 - accuracy: 0.5143 - val_loss: 0.6928 - val_accuracy: 0.5143
# Epoch 24/200
# 5/5 [==============================] - 1s 117ms/step - loss: 0.6927 - accuracy: 0.5143 - val_loss: 0.6928 - val_accuracy: 0.5143
# Epoch 25/200
# 5/5 [==============================] - 1s 140ms/step - loss: 0.6928 - accuracy: 0.5143 - val_loss: 0.6928 - val_accuracy: 0.5143
# Epoch 26/200
# 5/5 [==============================] - 1s 134ms/step - loss: 0.6929 - accuracy: 0.5143 - val_loss: 0.6928 - val_accuracy: 0.5143
# Epoch 27/200
# 5/5 [==============================] - 1s 132ms/step - loss: 0.6930 - accuracy: 0.5143 - val_loss: 0.6928 - val_accuracy: 0.5143
# Epoch 28/200
# 5/5 [==============================] - 1s 115ms/step - loss: 0.6929 - accuracy: 0.5143 - val_loss: 0.6928 - val_accuracy: 0.5143
# Epoch 29/200
# 5/5 [==============================] - 1s 136ms/step - loss: 0.6929 - accuracy: 0.5143 - val_loss: 0.6928 - val_accuracy: 0.5143
# Epoch 30/200
# 5/5 [==============================] - 1s 112ms/step - loss: 0.6928 - accuracy: 0.5143 - val_loss: 0.6928 - val_accuracy: 0.5143
# Epoch 31/200
# 5/5 [==============================] - 1s 135ms/step - loss: 0.6928 - accuracy: 0.5143 - val_loss: 0.6928 - val_accuracy: 0.5143
# Epoch 32/200
# 5/5 [==============================] - 1s 112ms/step - loss: 0.6928 - accuracy: 0.5143 - val_loss: 0.6928 - val_accuracy: 0.5143
# Epoch 33/200
# 5/5 [==============================] - 1s 161ms/step - loss: 0.6928 - accuracy: 0.5143 - val_loss: 0.6928 - val_accuracy: 0.5143
# Epoch 34/200
# 5/5 [==============================] - 1s 134ms/step - loss: 0.6928 - accuracy: 0.5143 - val_loss: 0.6928 - val_accuracy: 0.5143
# Epoch 35/200
# 5/5 [==============================] - 1s 113ms/step - loss: 0.6927 - accuracy: 0.5143 - val_loss: 0.6928 - val_accuracy: 0.5143
# Epoch 36/200
# 5/5 [==============================] - 1s 116ms/step - loss: 0.6928 - accuracy: 0.5143 - val_loss: 0.6927 - val_accuracy: 0.5143
# Epoch 37/200
# 5/5 [==============================] - 1s 112ms/step - loss: 0.6927 - accuracy: 0.5143 - val_loss: 0.6928 - val_accuracy: 0.5143
# Epoch 38/200
# 5/5 [==============================] - 1s 114ms/step - loss: 0.6929 - accuracy: 0.5143 - val_loss: 0.6928 - val_accuracy: 0.5143
# Epoch 39/200
# 5/5 [==============================] - 1s 114ms/step - loss: 0.6930 - accuracy: 0.5143 - val_loss: 0.6928 - val_accuracy: 0.5143
# Epoch 40/200
# 5/5 [==============================] - 1s 115ms/step - loss: 0.6928 - accuracy: 0.5143 - val_loss: 0.6928 - val_accuracy: 0.5143
# Epoch 41/200
# 5/5 [==============================] - 1s 116ms/step - loss: 0.6928 - accuracy: 0.5143 - val_loss: 0.6928 - val_accuracy: 0.5143
# Epoch 42/200
# 5/5 [==============================] - 1s 134ms/step - loss: 0.6928 - accuracy: 0.5143 - val_loss: 0.6928 - val_accuracy: 0.5143
# Epoch 43/200
# 5/5 [==============================] - 1s 133ms/step - loss: 0.6928 - accuracy: 0.5143 - val_loss: 0.6928 - val_accuracy: 0.5143
# Epoch 44/200
# 5/5 [==============================] - 1s 138ms/step - loss: 0.6928 - accuracy: 0.5143 - val_loss: 0.6928 - val_accuracy: 0.5143
# Epoch 45/200
# 5/5 [==============================] - 1s 114ms/step - loss: 0.6928 - accuracy: 0.5143 - val_loss: 0.6928 - val_accuracy: 0.5143
# Epoch 46/200
# 5/5 [==============================] - 1s 114ms/step - loss: 0.6928 - accuracy: 0.5143 - val_loss: 0.6928 - val_accuracy: 0.5143
# Epoch 47/200
# 5/5 [==============================] - 1s 116ms/step - loss: 0.6928 - accuracy: 0.5143 - val_loss: 0.6928 - val_accuracy: 0.5143
# Epoch 48/200
# 5/5 [==============================] - 1s 118ms/step - loss: 0.6928 - accuracy: 0.5143 - val_loss: 0.6928 - val_accuracy: 0.5143
# Epoch 49/200
# 5/5 [==============================] - 1s 136ms/step - loss: 0.6928 - accuracy: 0.5143 - val_loss: 0.6928 - val_accuracy: 0.5143
# Epoch 50/200
# 5/5 [==============================] - 1s 118ms/step - loss: 0.6928 - accuracy: 0.5143 - val_loss: 0.6928 - val_accuracy: 0.5143
# Epoch 51/200
# 5/5 [==============================] - 1s 136ms/step - loss: 0.6929 - accuracy: 0.5143 - val_loss: 0.6928 - val_accuracy: 0.5143
# Epoch 52/200
# 5/5 [==============================] - 1s 138ms/step - loss: 0.6929 - accuracy: 0.5143 - val_loss: 0.6928 - val_accuracy: 0.5143
# Epoch 53/200
# 5/5 [==============================] - 1s 116ms/step - loss: 0.6929 - accuracy: 0.5143 - val_loss: 0.6928 - val_accuracy: 0.5143
# Epoch 54/200
# 5/5 [==============================] - 1s 138ms/step - loss: 0.6928 - accuracy: 0.5143 - val_loss: 0.6928 - val_accuracy: 0.5143
# Epoch 55/200
# 5/5 [==============================] - 1s 137ms/step - loss: 0.6928 - accuracy: 0.5143 - val_loss: 0.6928 - val_accuracy: 0.5143
# Epoch 56/200
# 5/5 [==============================] - 1s 123ms/step - loss: 0.6929 - accuracy: 0.5143 - val_loss: 0.6928 - val_accuracy: 0.5143
# Epoch 57/200
# 5/5 [==============================] - 1s 117ms/step - loss: 0.6929 - accuracy: 0.5143 - val_loss: 0.6928 - val_accuracy: 0.5143
# Epoch 58/200
# 5/5 [==============================] - 1s 140ms/step - loss: 0.6929 - accuracy: 0.5143 - val_loss: 0.6928 - val_accuracy: 0.5143
# Epoch 59/200
# 5/5 [==============================] - 1s 136ms/step - loss: 0.6929 - accuracy: 0.5143 - val_loss: 0.6928 - val_accuracy: 0.5143
# Epoch 60/200
# 5/5 [==============================] - 1s 133ms/step - loss: 0.6928 - accuracy: 0.5143 - val_loss: 0.6928 - val_accuracy: 0.5143
# Epoch 61/200
# 5/5 [==============================] - 1s 117ms/step - loss: 0.6928 - accuracy: 0.5143 - val_loss: 0.6928 - val_accuracy: 0.5143
# Epoch 62/200
# 5/5 [==============================] - 1s 136ms/step - loss: 0.6929 - accuracy: 0.5143 - val_loss: 0.6928 - val_accuracy: 0.5143
# Epoch 63/200
# 5/5 [==============================] - 1s 134ms/step - loss: 0.6928 - accuracy: 0.5143 - val_loss: 0.6928 - val_accuracy: 0.5143
# Epoch 64/200
# 5/5 [==============================] - 1s 116ms/step - loss: 0.6928 - accuracy: 0.5143 - val_loss: 0.6928 - val_accuracy: 0.5143
# Epoch 65/200
# 5/5 [==============================] - 1s 116ms/step - loss: 0.6928 - accuracy: 0.5143 - val_loss: 0.6928 - val_accuracy: 0.5143
# Epoch 66/200
# 5/5 [==============================] - 1s 136ms/step - loss: 0.6928 - accuracy: 0.5143 - val_loss: 0.6928 - val_accuracy: 0.5143
# Epoch 67/200
# 5/5 [==============================] - 1s 139ms/step - loss: 0.6927 - accuracy: 0.5143 - val_loss: 0.6928 - val_accuracy: 0.5143
# Epoch 68/200
# 5/5 [==============================] - 1s 113ms/step - loss: 0.6928 - accuracy: 0.5143 - val_loss: 0.6928 - val_accuracy: 0.5143
# Epoch 69/200
# 5/5 [==============================] - 1s 118ms/step - loss: 0.6928 - accuracy: 0.5143 - val_loss: 0.6928 - val_accuracy: 0.5143
# Epoch 70/200
# 5/5 [==============================] - 1s 119ms/step - loss: 0.6928 - accuracy: 0.5143 - val_loss: 0.6928 - val_accuracy: 0.5143
# Epoch 71/200
# 5/5 [==============================] - 1s 137ms/step - loss: 0.6928 - accuracy: 0.5143 - val_loss: 0.6927 - val_accuracy: 0.5143
# Epoch 72/200
# 5/5 [==============================] - 1s 140ms/step - loss: 0.6928 - accuracy: 0.5143 - val_loss: 0.6927 - val_accuracy: 0.5143
# Epoch 73/200
# 5/5 [==============================] - 1s 111ms/step - loss: 0.6928 - accuracy: 0.5143 - val_loss: 0.6927 - val_accuracy: 0.5143
# Epoch 74/200
# 5/5 [==============================] - 1s 120ms/step - loss: 0.6927 - accuracy: 0.5143 - val_loss: 0.6927 - val_accuracy: 0.5143
# Epoch 75/200
# 5/5 [==============================] - 1s 133ms/step - loss: 0.6929 - accuracy: 0.5143 - val_loss: 0.6927 - val_accuracy: 0.5143
# Epoch 76/200
# 5/5 [==============================] - 1s 135ms/step - loss: 0.6928 - accuracy: 0.5143 - val_loss: 0.6927 - val_accuracy: 0.5143
# Epoch 77/200
# 5/5 [==============================] - 1s 119ms/step - loss: 0.6927 - accuracy: 0.5143 - val_loss: 0.6927 - val_accuracy: 0.5143
# Epoch 78/200
# 5/5 [==============================] - 1s 138ms/step - loss: 0.6928 - accuracy: 0.5143 - val_loss: 0.6927 - val_accuracy: 0.5143
# Epoch 79/200
# 5/5 [==============================] - 1s 116ms/step - loss: 0.6928 - accuracy: 0.5143 - val_loss: 0.6927 - val_accuracy: 0.5143
# Epoch 80/200
# 5/5 [==============================] - 1s 116ms/step - loss: 0.6928 - accuracy: 0.5143 - val_loss: 0.6927 - val_accuracy: 0.5143
# Epoch 81/200
# 5/5 [==============================] - 1s 140ms/step - loss: 0.6929 - accuracy: 0.5143 - val_loss: 0.6927 - val_accuracy: 0.5143
# Epoch 82/200
# 5/5 [==============================] - 1s 116ms/step - loss: 0.6928 - accuracy: 0.5143 - val_loss: 0.6927 - val_accuracy: 0.5143
# Epoch 83/200
# 5/5 [==============================] - 1s 110ms/step - loss: 0.6928 - accuracy: 0.5143 - val_loss: 0.6928 - val_accuracy: 0.5143
# Epoch 84/200
# 5/5 [==============================] - 1s 136ms/step - loss: 0.6929 - accuracy: 0.5143 - val_loss: 0.6927 - val_accuracy: 0.5143
# Epoch 85/200
# 5/5 [==============================] - 1s 117ms/step - loss: 0.6928 - accuracy: 0.5143 - val_loss: 0.6927 - val_accuracy: 0.5143
# Epoch 86/200
# 5/5 [==============================] - 1s 116ms/step - loss: 0.6928 - accuracy: 0.5143 - val_loss: 0.6927 - val_accuracy: 0.5143
# Epoch 87/200
# 5/5 [==============================] - 1s 116ms/step - loss: 0.6928 - accuracy: 0.5143 - val_loss: 0.6928 - val_accuracy: 0.5143
# Epoch 88/200
# 5/5 [==============================] - 1s 131ms/step - loss: 0.6928 - accuracy: 0.5143 - val_loss: 0.6927 - val_accuracy: 0.5143
# Epoch 89/200
# 5/5 [==============================] - 1s 112ms/step - loss: 0.6928 - accuracy: 0.5143 - val_loss: 0.6927 - val_accuracy: 0.5143
# Epoch 90/200
# 5/5 [==============================] - 1s 116ms/step - loss: 0.6927 - accuracy: 0.5143 - val_loss: 0.6927 - val_accuracy: 0.5143
# Epoch 91/200
# 5/5 [==============================] - 1s 135ms/step - loss: 0.6927 - accuracy: 0.5143 - val_loss: 0.6927 - val_accuracy: 0.5143
# Epoch 92/200
# 5/5 [==============================] - 1s 137ms/step - loss: 0.6927 - accuracy: 0.5143 - val_loss: 0.6927 - val_accuracy: 0.5143
# Epoch 93/200
# 5/5 [==============================] - 1s 115ms/step - loss: 0.6928 - accuracy: 0.5143 - val_loss: 0.6927 - val_accuracy: 0.5143
# Epoch 94/200
# 5/5 [==============================] - 1s 112ms/step - loss: 0.6928 - accuracy: 0.5143 - val_loss: 0.6927 - val_accuracy: 0.5143
# Epoch 95/200
# 5/5 [==============================] - 1s 136ms/step - loss: 0.6927 - accuracy: 0.5143 - val_loss: 0.6927 - val_accuracy: 0.5143
# Epoch 96/200
# 5/5 [==============================] - 1s 116ms/step - loss: 0.6928 - accuracy: 0.5143 - val_loss: 0.6927 - val_accuracy: 0.5143
# Epoch 97/200
# 5/5 [==============================] - 1s 114ms/step - loss: 0.6928 - accuracy: 0.5143 - val_loss: 0.6927 - val_accuracy: 0.5143
# Epoch 98/200
# 5/5 [==============================] - 1s 114ms/step - loss: 0.6927 - accuracy: 0.5143 - val_loss: 0.6927 - val_accuracy: 0.5143
# Epoch 99/200
# 5/5 [==============================] - 1s 132ms/step - loss: 0.6927 - accuracy: 0.5143 - val_loss: 0.6927 - val_accuracy: 0.5143
# Epoch 100/200
# 5/5 [==============================] - 1s 121ms/step - loss: 0.6928 - accuracy: 0.5143 - val_loss: 0.6927 - val_accuracy: 0.5143
# Epoch 101/200
# 5/5 [==============================] - 1s 141ms/step - loss: 0.6927 - accuracy: 0.5143 - val_loss: 0.6927 - val_accuracy: 0.5143
# Epoch 102/200
# 5/5 [==============================] - 1s 122ms/step - loss: 0.6927 - accuracy: 0.5143 - val_loss: 0.6927 - val_accuracy: 0.5143
# Epoch 103/200
# 5/5 [==============================] - 1s 143ms/step - loss: 0.6928 - accuracy: 0.5143 - val_loss: 0.6927 - val_accuracy: 0.5143
# Epoch 104/200
# 5/5 [==============================] - 1s 116ms/step - loss: 0.6928 - accuracy: 0.5143 - val_loss: 0.6927 - val_accuracy: 0.5143
# Epoch 105/200
# 5/5 [==============================] - 1s 115ms/step - loss: 0.6928 - accuracy: 0.5143 - val_loss: 0.6927 - val_accuracy: 0.5143
# Epoch 106/200
# 5/5 [==============================] - 1s 112ms/step - loss: 0.6928 - accuracy: 0.5143 - val_loss: 0.6928 - val_accuracy: 0.5143
# Epoch 107/200
# 5/5 [==============================] - 1s 133ms/step - loss: 0.6930 - accuracy: 0.5143 - val_loss: 0.6927 - val_accuracy: 0.5143
# Epoch 108/200
# 5/5 [==============================] - 1s 115ms/step - loss: 0.6927 - accuracy: 0.5143 - val_loss: 0.6927 - val_accuracy: 0.5143
# Epoch 109/200
# 5/5 [==============================] - 1s 135ms/step - loss: 0.6928 - accuracy: 0.5143 - val_loss: 0.6927 - val_accuracy: 0.5143
# Epoch 110/200
# 5/5 [==============================] - 1s 116ms/step - loss: 0.6928 - accuracy: 0.5143 - val_loss: 0.6927 - val_accuracy: 0.5143
# Epoch 111/200
# 5/5 [==============================] - 1s 121ms/step - loss: 0.6928 - accuracy: 0.5143 - val_loss: 0.6927 - val_accuracy: 0.5143
# Epoch 112/200
# 5/5 [==============================] - 1s 116ms/step - loss: 0.6928 - accuracy: 0.5143 - val_loss: 0.6927 - val_accuracy: 0.5143
# Epoch 113/200
# 5/5 [==============================] - 1s 116ms/step - loss: 0.6928 - accuracy: 0.5143 - val_loss: 0.6927 - val_accuracy: 0.5143
# Epoch 114/200
# 5/5 [==============================] - 1s 140ms/step - loss: 0.6928 - accuracy: 0.5143 - val_loss: 0.6927 - val_accuracy: 0.5143
# Epoch 115/200
# 5/5 [==============================] - 1s 138ms/step - loss: 0.6928 - accuracy: 0.5143 - val_loss: 0.6927 - val_accuracy: 0.5143
# Epoch 116/200
# 5/5 [==============================] - 1s 120ms/step - loss: 0.6928 - accuracy: 0.5143 - val_loss: 0.6927 - val_accuracy: 0.5143
# Epoch 117/200
# 5/5 [==============================] - 1s 140ms/step - loss: 0.6928 - accuracy: 0.5143 - val_loss: 0.6927 - val_accuracy: 0.5143
# Epoch 118/200
# 5/5 [==============================] - 1s 118ms/step - loss: 0.6927 - accuracy: 0.5143 - val_loss: 0.6927 - val_accuracy: 0.5143
# Epoch 119/200
# 5/5 [==============================] - 1s 136ms/step - loss: 0.6928 - accuracy: 0.5143 - val_loss: 0.6927 - val_accuracy: 0.5143
# Epoch 120/200
# 5/5 [==============================] - 1s 112ms/step - loss: 0.6928 - accuracy: 0.5143 - val_loss: 0.6927 - val_accuracy: 0.5143
# Epoch 121/200
# 5/5 [==============================] - 1s 157ms/step - loss: 0.6928 - accuracy: 0.5143 - val_loss: 0.6927 - val_accuracy: 0.5143
# Epoch 122/200
# 5/5 [==============================] - 1s 138ms/step - loss: 0.6928 - accuracy: 0.5143 - val_loss: 0.6927 - val_accuracy: 0.5143
# Epoch 123/200
# 5/5 [==============================] - 1s 116ms/step - loss: 0.6928 - accuracy: 0.5143 - val_loss: 0.6927 - val_accuracy: 0.5143
# Epoch 124/200
# 5/5 [==============================] - 1s 137ms/step - loss: 0.6927 - accuracy: 0.5143 - val_loss: 0.6927 - val_accuracy: 0.5143
# Epoch 125/200
# 5/5 [==============================] - 1s 137ms/step - loss: 0.6928 - accuracy: 0.5143 - val_loss: 0.6927 - val_accuracy: 0.5143
# Epoch 126/200
# 5/5 [==============================] - 1s 137ms/step - loss: 0.6928 - accuracy: 0.5143 - val_loss: 0.6928 - val_accuracy: 0.5143
# Epoch 127/200
# 5/5 [==============================] - 1s 140ms/step - loss: 0.6929 - accuracy: 0.5143 - val_loss: 0.6927 - val_accuracy: 0.5143
# Epoch 128/200
# 5/5 [==============================] - 1s 117ms/step - loss: 0.6928 - accuracy: 0.5143 - val_loss: 0.6927 - val_accuracy: 0.5143
# Epoch 129/200
# 5/5 [==============================] - 1s 120ms/step - loss: 0.6928 - accuracy: 0.5143 - val_loss: 0.6927 - val_accuracy: 0.5143
# Epoch 130/200
# 5/5 [==============================] - 1s 162ms/step - loss: 0.6927 - accuracy: 0.5143 - val_loss: 0.6927 - val_accuracy: 0.5143
# Epoch 131/200
# 5/5 [==============================] - 1s 118ms/step - loss: 0.6928 - accuracy: 0.5143 - val_loss: 0.6927 - val_accuracy: 0.5143
# Epoch 132/200
# 5/5 [==============================] - 1s 123ms/step - loss: 0.6927 - accuracy: 0.5143 - val_loss: 0.6927 - val_accuracy: 0.5143
# Epoch 133/200
# 5/5 [==============================] - 1s 126ms/step - loss: 0.6928 - accuracy: 0.5143 - val_loss: 0.6927 - val_accuracy: 0.5143
# Epoch 134/200
# 5/5 [==============================] - 1s 140ms/step - loss: 0.6927 - accuracy: 0.5143 - val_loss: 0.6927 - val_accuracy: 0.5143
# Epoch 135/200
# 5/5 [==============================] - 1s 117ms/step - loss: 0.6927 - accuracy: 0.5143 - val_loss: 0.6927 - val_accuracy: 0.5143
# Epoch 136/200
# 5/5 [==============================] - 1s 120ms/step - loss: 0.6927 - accuracy: 0.5143 - val_loss: 0.6927 - val_accuracy: 0.5143
# Epoch 137/200
# 5/5 [==============================] - 1s 136ms/step - loss: 0.6927 - accuracy: 0.5143 - val_loss: 0.6927 - val_accuracy: 0.5143
# Epoch 138/200
# 5/5 [==============================] - 1s 118ms/step - loss: 0.6927 - accuracy: 0.5143 - val_loss: 0.6927 - val_accuracy: 0.5143
# Epoch 139/200
# 5/5 [==============================] - 1s 123ms/step - loss: 0.6927 - accuracy: 0.5143 - val_loss: 0.6927 - val_accuracy: 0.5143
# Epoch 140/200
# 5/5 [==============================] - 1s 154ms/step - loss: 0.6927 - accuracy: 0.5143 - val_loss: 0.6927 - val_accuracy: 0.5143
# Epoch 141/200
# 5/5 [==============================] - 2s 337ms/step - loss: 0.6927 - accuracy: 0.5143 - val_loss: 0.6927 - val_accuracy: 0.5143
# Epoch 142/200
# 5/5 [==============================] - 1s 126ms/step - loss: 0.6928 - accuracy: 0.5143 - val_loss: 0.6927 - val_accuracy: 0.5143
# Epoch 143/200
# 5/5 [==============================] - 1s 130ms/step - loss: 0.6928 - accuracy: 0.5143 - val_loss: 0.6927 - val_accuracy: 0.5143
# Epoch 144/200
# 5/5 [==============================] - 1s 125ms/step - loss: 0.6928 - accuracy: 0.5143 - val_loss: 0.6928 - val_accuracy: 0.5143
# Epoch 145/200
# 5/5 [==============================] - 1s 200ms/step - loss: 0.6928 - accuracy: 0.5143 - val_loss: 0.6927 - val_accuracy: 0.5143
# Epoch 146/200
# 5/5 [==============================] - 1s 204ms/step - loss: 0.6928 - accuracy: 0.5143 - val_loss: 0.6927 - val_accuracy: 0.5143
# Epoch 147/200
# 5/5 [==============================] - 1s 234ms/step - loss: 0.6928 - accuracy: 0.5143 - val_loss: 0.6927 - val_accuracy: 0.5143
# Epoch 148/200
# 5/5 [==============================] - 1s 194ms/step - loss: 0.6927 - accuracy: 0.5143 - val_loss: 0.6928 - val_accuracy: 0.5143
# Epoch 149/200
# 5/5 [==============================] - 1s 231ms/step - loss: 0.6928 - accuracy: 0.5143 - val_loss: 0.6928 - val_accuracy: 0.5143
# Epoch 150/200
# 5/5 [==============================] - 1s 188ms/step - loss: 0.6928 - accuracy: 0.5143 - val_loss: 0.6928 - val_accuracy: 0.5143
# Epoch 151/200
# 5/5 [==============================] - 1s 119ms/step - loss: 0.6928 - accuracy: 0.5143 - val_loss: 0.6928 - val_accuracy: 0.5143
# Epoch 152/200
# 5/5 [==============================] - 1s 144ms/step - loss: 0.6928 - accuracy: 0.5143 - val_loss: 0.6928 - val_accuracy: 0.5143
# Epoch 153/200
# 5/5 [==============================] - 1s 141ms/step - loss: 0.6928 - accuracy: 0.5143 - val_loss: 0.6928 - val_accuracy: 0.5143
# Epoch 154/200
# 5/5 [==============================] - 1s 113ms/step - loss: 0.6928 - accuracy: 0.5143 - val_loss: 0.6928 - val_accuracy: 0.5143
# Epoch 155/200
# 5/5 [==============================] - 1s 117ms/step - loss: 0.6929 - accuracy: 0.5143 - val_loss: 0.6928 - val_accuracy: 0.5143
# Epoch 156/200
# 5/5 [==============================] - 1s 116ms/step - loss: 0.6928 - accuracy: 0.5143 - val_loss: 0.6928 - val_accuracy: 0.5143
# Epoch 157/200
# 5/5 [==============================] - 1s 113ms/step - loss: 0.6928 - accuracy: 0.5143 - val_loss: 0.6928 - val_accuracy: 0.5143
# Epoch 158/200
# 5/5 [==============================] - 1s 140ms/step - loss: 0.6928 - accuracy: 0.5143 - val_loss: 0.6928 - val_accuracy: 0.5143
# Epoch 159/200
# 5/5 [==============================] - 1s 116ms/step - loss: 0.6929 - accuracy: 0.5143 - val_loss: 0.6928 - val_accuracy: 0.5143
# Epoch 160/200
# 5/5 [==============================] - 1s 132ms/step - loss: 0.6928 - accuracy: 0.5143 - val_loss: 0.6928 - val_accuracy: 0.5143
# Epoch 161/200
# 5/5 [==============================] - 1s 120ms/step - loss: 0.6929 - accuracy: 0.5143 - val_loss: 0.6928 - val_accuracy: 0.5143
# Epoch 162/200
# 5/5 [==============================] - 1s 114ms/step - loss: 0.6928 - accuracy: 0.5143 - val_loss: 0.6928 - val_accuracy: 0.5143
# Epoch 163/200
# 5/5 [==============================] - 1s 137ms/step - loss: 0.6928 - accuracy: 0.5143 - val_loss: 0.6928 - val_accuracy: 0.5143
# Epoch 164/200
# 5/5 [==============================] - 1s 139ms/step - loss: 0.6929 - accuracy: 0.5143 - val_loss: 0.6928 - val_accuracy: 0.5143
# Epoch 165/200
# 5/5 [==============================] - 1s 116ms/step - loss: 0.6929 - accuracy: 0.5143 - val_loss: 0.6928 - val_accuracy: 0.5143
# Epoch 166/200
# 5/5 [==============================] - 1s 118ms/step - loss: 0.6929 - accuracy: 0.5143 - val_loss: 0.6928 - val_accuracy: 0.5143
# Epoch 167/200
# 5/5 [==============================] - 1s 134ms/step - loss: 0.6929 - accuracy: 0.5143 - val_loss: 0.6928 - val_accuracy: 0.5143
# Epoch 168/200
# 5/5 [==============================] - 1s 115ms/step - loss: 0.6929 - accuracy: 0.5143 - val_loss: 0.6929 - val_accuracy: 0.5143
# Epoch 169/200
# 5/5 [==============================] - 1s 120ms/step - loss: 0.6929 - accuracy: 0.5143 - val_loss: 0.6928 - val_accuracy: 0.5143
# Epoch 170/200
# 5/5 [==============================] - 1s 136ms/step - loss: 0.6928 - accuracy: 0.5143 - val_loss: 0.6928 - val_accuracy: 0.5143
# Epoch 171/200
# 5/5 [==============================] - 1s 134ms/step - loss: 0.6928 - accuracy: 0.5143 - val_loss: 0.6928 - val_accuracy: 0.5143
# Epoch 172/200
# 5/5 [==============================] - 1s 119ms/step - loss: 0.6929 - accuracy: 0.5143 - val_loss: 0.6928 - val_accuracy: 0.5143
# Epoch 173/200
# 5/5 [==============================] - 1s 118ms/step - loss: 0.6929 - accuracy: 0.5143 - val_loss: 0.6928 - val_accuracy: 0.5143
# Epoch 174/200
# 5/5 [==============================] - 1s 116ms/step - loss: 0.6928 - accuracy: 0.5143 - val_loss: 0.6928 - val_accuracy: 0.5143
# Epoch 175/200
# 5/5 [==============================] - 1s 119ms/step - loss: 0.6927 - accuracy: 0.5143 - val_loss: 0.6928 - val_accuracy: 0.5143
# Epoch 176/200
# 5/5 [==============================] - 1s 122ms/step - loss: 0.6927 - accuracy: 0.5143 - val_loss: 0.6928 - val_accuracy: 0.5143
# Epoch 177/200
# 5/5 [==============================] - 1s 114ms/step - loss: 0.6928 - accuracy: 0.5143 - val_loss: 0.6928 - val_accuracy: 0.5143
# Epoch 178/200
# 5/5 [==============================] - 1s 111ms/step - loss: 0.6928 - accuracy: 0.5143 - val_loss: 0.6928 - val_accuracy: 0.5143
# Epoch 179/200
# 5/5 [==============================] - 1s 139ms/step - loss: 0.6928 - accuracy: 0.5143 - val_loss: 0.6928 - val_accuracy: 0.5143
# Epoch 180/200
# 5/5 [==============================] - 1s 116ms/step - loss: 0.6928 - accuracy: 0.5143 - val_loss: 0.6928 - val_accuracy: 0.5143
# Epoch 181/200
# 5/5 [==============================] - 1s 116ms/step - loss: 0.6928 - accuracy: 0.5143 - val_loss: 0.6928 - val_accuracy: 0.5143
# Epoch 182/200
# 5/5 [==============================] - 1s 115ms/step - loss: 0.6928 - accuracy: 0.5143 - val_loss: 0.6928 - val_accuracy: 0.5143
# Epoch 183/200
# 5/5 [==============================] - 1s 117ms/step - loss: 0.6928 - accuracy: 0.5143 - val_loss: 0.6928 - val_accuracy: 0.5143
# Epoch 184/200
# 5/5 [==============================] - 1s 136ms/step - loss: 0.6928 - accuracy: 0.5143 - val_loss: 0.6928 - val_accuracy: 0.5143
# Epoch 185/200
# 5/5 [==============================] - 1s 120ms/step - loss: 0.6928 - accuracy: 0.5143 - val_loss: 0.6928 - val_accuracy: 0.5143
# Epoch 186/200
# 5/5 [==============================] - 1s 122ms/step - loss: 0.6928 - accuracy: 0.5143 - val_loss: 0.6928 - val_accuracy: 0.5143
# Epoch 187/200
# 5/5 [==============================] - 1s 128ms/step - loss: 0.6928 - accuracy: 0.5143 - val_loss: 0.6928 - val_accuracy: 0.5143
# Epoch 188/200
# 5/5 [==============================] - 1s 120ms/step - loss: 0.6928 - accuracy: 0.5143 - val_loss: 0.6928 - val_accuracy: 0.5143
# Epoch 189/200
# 5/5 [==============================] - 1s 145ms/step - loss: 0.6928 - accuracy: 0.5143 - val_loss: 0.6928 - val_accuracy: 0.5143
# Epoch 190/200
# 5/5 [==============================] - 1s 123ms/step - loss: 0.6928 - accuracy: 0.5143 - val_loss: 0.6928 - val_accuracy: 0.5143
# Epoch 191/200
# 5/5 [==============================] - 1s 114ms/step - loss: 0.6928 - accuracy: 0.5143 - val_loss: 0.6928 - val_accuracy: 0.5143
# Epoch 192/200
# 5/5 [==============================] - 1s 119ms/step - loss: 0.6928 - accuracy: 0.5143 - val_loss: 0.6928 - val_accuracy: 0.5143
# Epoch 193/200
# 5/5 [==============================] - 1s 121ms/step - loss: 0.6928 - accuracy: 0.5143 - val_loss: 0.6928 - val_accuracy: 0.5143
# Epoch 194/200
# 5/5 [==============================] - 1s 142ms/step - loss: 0.6928 - accuracy: 0.5143 - val_loss: 0.6928 - val_accuracy: 0.5143
# Epoch 195/200
# 5/5 [==============================] - 1s 120ms/step - loss: 0.6928 - accuracy: 0.5143 - val_loss: 0.6928 - val_accuracy: 0.5143
# Epoch 196/200
# 5/5 [==============================] - 1s 118ms/step - loss: 0.6928 - accuracy: 0.5143 - val_loss: 0.6928 - val_accuracy: 0.5143
# Epoch 197/200
# 5/5 [==============================] - 1s 134ms/step - loss: 0.6928 - accuracy: 0.5143 - val_loss: 0.6928 - val_accuracy: 0.5143
# Epoch 198/200
# 5/5 [==============================] - 1s 139ms/step - loss: 0.6928 - accuracy: 0.5143 - val_loss: 0.6928 - val_accuracy: 0.5143
# Epoch 199/200
# 5/5 [==============================] - 1s 122ms/step - loss: 0.6928 - accuracy: 0.5143 - val_loss: 0.6928 - val_accuracy: 0.5143
# Epoch 200/200
# 5/5 [==============================] - 1s 123ms/step - loss: 0.6928 - accuracy: 0.5143 - val_loss: 0.6928 - val_accuracy: 0.5143
